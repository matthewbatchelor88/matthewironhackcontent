# %%
conda install -c anaconda beautifulsoup4
# Out:
# Retrieving notices: ...working... done
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.1.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/matthewbatchelor/anaconda3
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     beautifulsoup4-4.12.2      |  py311hecd8cb5_0         264 KB  anaconda
#     ca-certificates-2023.08.22 |       hecd8cb5_0         131 KB  anaconda
#     certifi-2023.11.17         |  py311hecd8cb5_0         161 KB  anaconda
#     openssl-3.0.12             |       hca72f7f_0         4.7 MB  anaconda
# ...

# %%
import requests

# %%
conda install -c anaconda requests
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.1.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/matthewbatchelor/anaconda3
#
#   added / updated specs:
#     - requests
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     requests-2.31.0            |  py311hecd8cb5_0         118 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         118 KB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   requests                                        pkgs/main --> anaconda
#
#
#
# ...
#
# ...
