# %% [markdown]
# # Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File ~/anaconda3/lib/python3.11/socket.py:962, in getaddrinfo(host, port, family, type, proto, flags)
#     961 addrlist = []
# --> 962 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     963     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:415, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414     else:
# --> 415         conn.request(method, url, **httplib_request_kw)
#     417 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     418 # legitimately able to close the connection after sending a valid response.
#     419 # With this behaviour, the received response is still readable.
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:244, in HTTPConnection.request(self, method, url, body, headers)
#     243     headers["User-Agent"] = _get_default_user_agent()
# --> 244 super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# -> 1332 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#
# File ~/anaconda3/lib/python3.11/http/client.py:979, in HTTPConnection.send(self, data)
#     978 if self.auto_open:
# --> 979     self.connect()
#     980 else:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:205, in HTTPConnection.connect(self)
#     204 def connect(self):
# --> 205     conn = self._new_conn()
#     206     self._prepare_conn(conn)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x10a802410>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/util/retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='api.rottentomatoes.com', port=80): Max retries exceeded with url: /api/public/v1.0/lists/movies/box_office.json (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10a802410>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 9
#       6 NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
#       7 print("NBA:", NBA.status_code)
# ----> 9 rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
#      10 print("Rotten Tomatoes:", rotten_tomato.status_code)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='api.rottentomatoes.com', port=80): Max retries exceeded with url: /api/public/v1.0/lists/movies/box_office.json (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10a802410>: Failed to establish a new connection: [Errno 8] nodename nor servname provided, or not known'))

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
results # this is a list of dictionaries with keys and values
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
#   'completed': True},
#  {'userId': 1,
#   'id': 11,
#   'title': 'vero rerum temporibus dolor',
#   'completed': True},
#  {'userId': 1,
#   'id': 12,
#   'title': 'ipsa repellendus fugit nisi',
#   'completed': True},
#  {'userId': 1, 'id': 13, 'title': 'et doloremque nulla', 'completed': False},
#  {'userId': 1,
#   'id': 14,
#   'title': 'repellendus sunt dolores architecto voluptatum',
#   'completed': True},
#  {'userId': 1,
#   'id': 15,
#   'title': 'ab voluptatum amet voluptas',
#   'completed': True},
#  {'userId': 1,
#   'id': 16,
#   'title': 'accusamus eos facilis sint et aut voluptatem',
#   'completed': True},
#  {'userId': 1,
#   'id': 17,
#   'title': 'quo laboriosam deleniti aut qui',
#   'completed': True},
#  {'userId': 1,
#   'id': 18,
#   'title': 'dolorum est consequatur ea mollitia in culpa',
#   'completed': False},
#  {'userId': 1,
#   'id': 19,
#   'title': 'molestiae ipsa aut voluptatibus pariatur dolor nihil',
#   'completed': True},
#  {'userId': 1,
#   'id': 20,
#   'title': 'ullam nobis libero sapiente ad optio sint',
#   'completed': True},
#  {'userId': 2,
#   'id': 21,
#   'title': 'suscipit repellat esse quibusdam voluptatem incidunt',
#   'completed': False},
#  {'userId': 2,
#   'id': 22,
#   'title': 'distinctio vitae autem nihil ut molestias quo',
#   'completed': True},
#  {'userId': 2,
#   'id': 23,
#   'title': 'et itaque necessitatibus maxime molestiae qui quas velit',
#   'completed': False},
#  {'userId': 2,
#   'id': 24,
#   'title': 'adipisci non ad dicta qui amet quaerat doloribus ea',
#   'completed': False},
#  {'userId': 2,
#   'id': 25,
#   'title': 'voluptas quo tenetur perspiciatis explicabo natus',
#   'completed': True},
#  {'userId': 2, 'id': 26, 'title': 'aliquam aut quasi', 'completed': True},
#  {'userId': 2,
#   'id': 27,
#   'title': 'veritatis pariatur delectus',
#   'completed': True},
#  {'userId': 2,
#   'id': 28,
#   'title': 'nesciunt totam sit blanditiis sit',
#   'completed': False},
#  {'userId': 2, 'id': 29, 'title': 'laborum aut in quam', 'completed': False},
#  {'userId': 2,
#   'id': 30,
#   'title': 'nemo perspiciatis repellat ut dolor libero commodi blanditiis omnis',
#   'completed': True},
#  {'userId': 2,
#   'id': 31,
#   'title': 'repudiandae totam in est sint facere fuga',
#   'completed': False},
#  {'userId': 2,
#   'id': 32,
#   'title': 'earum doloribus ea doloremque quis',
#   'completed': False},
#  {'userId': 2, 'id': 33, 'title': 'sint sit aut vero', 'completed': False},
#  {'userId': 2,
#   'id': 34,
#   'title': 'porro aut necessitatibus eaque distinctio',
#   'completed': False},
#  {'userId': 2,
#   'id': 35,
#   'title': 'repellendus veritatis molestias dicta incidunt',
#   'completed': True},
#  {'userId': 2,
#   'id': 36,
#   'title': 'excepturi deleniti adipisci voluptatem et neque optio illum ad',
#   'completed': True},
#  {'userId': 2, 'id': 37, 'title': 'sunt cum tempora', 'completed': False},
#  {'userId': 2, 'id': 38, 'title': 'totam quia non', 'completed': False},
#  {'userId': 2,
#   'id': 39,
#   'title': 'doloremque quibusdam asperiores libero corrupti illum qui omnis',
#   'completed': False},
#  {'userId': 2,
#   'id': 40,
#   'title': 'totam atque quo nesciunt',
#   'completed': True},
#  {'userId': 3,
#   'id': 41,
#   'title': 'aliquid amet impedit consequatur aspernatur placeat eaque fugiat suscipit',
#   'completed': False},
#  {'userId': 3,
#   'id': 42,
#   'title': 'rerum perferendis error quia ut eveniet',
#   'completed': False},
#  {'userId': 3,
#   'id': 43,
#   'title': 'tempore ut sint quis recusandae',
#   'completed': True},
#  {'userId': 3,
#   'id': 44,
#   'title': 'cum debitis quis accusamus doloremque ipsa natus sapiente omnis',
#   'completed': True},
#  {'userId': 3,
#   'id': 45,
#   'title': 'velit soluta adipisci molestias reiciendis harum',
#   'completed': False},
#  {'userId': 3,
#   'id': 46,
#   'title': 'vel voluptatem repellat nihil placeat corporis',
#   'completed': False},
#  {'userId': 3,
#   'id': 47,
#   'title': 'nam qui rerum fugiat accusamus',
#   'completed': False},
#  {'userId': 3,
#   'id': 48,
#   'title': 'sit reprehenderit omnis quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 49,
#   'title': 'ut necessitatibus aut maiores debitis officia blanditiis velit et',
#   'completed': False},
#  {'userId': 3,
#   'id': 50,
#   'title': 'cupiditate necessitatibus ullam aut quis dolor voluptate',
#   'completed': True},
#  {'userId': 3,
#   'id': 51,
#   'title': 'distinctio exercitationem ab doloribus',
#   'completed': False},
#  {'userId': 3,
#   'id': 52,
#   'title': 'nesciunt dolorum quis recusandae ad pariatur ratione',
#   'completed': False},
#  {'userId': 3,
#   'id': 53,
#   'title': 'qui labore est occaecati recusandae aliquid quam',
#   'completed': False},
#  {'userId': 3,
#   'id': 54,
#   'title': 'quis et est ut voluptate quam dolor',
#   'completed': True},
#  {'userId': 3,
#   'id': 55,
#   'title': 'voluptatum omnis minima qui occaecati provident nulla voluptatem ratione',
#   'completed': True},
#  {'userId': 3,
#   'id': 56,
#   'title': 'deleniti ea temporibus enim',
#   'completed': True},
#  {'userId': 3,
#   'id': 57,
#   'title': 'pariatur et magnam ea doloribus similique voluptatem rerum quia',
#   'completed': False},
#  {'userId': 3,
#   'id': 58,
#   'title': 'est dicta totam qui explicabo doloribus qui dignissimos',
#   'completed': False},
#  {'userId': 3,
#   'id': 59,
#   'title': 'perspiciatis velit id laborum placeat iusto et aliquam odio',
#   'completed': False},
#  {'userId': 3,
#   'id': 60,
#   'title': 'et sequi qui architecto ut adipisci',
#   'completed': True},
#  {'userId': 4,
#   'id': 61,
#   'title': 'odit optio omnis qui sunt',
#   'completed': True},
#  {'userId': 4,
#   'id': 62,
#   'title': 'et placeat et tempore aspernatur sint numquam',
#   'completed': False},
#  {'userId': 4,
#   'id': 63,
#   'title': 'doloremque aut dolores quidem fuga qui nulla',
#   'completed': True},
#  {'userId': 4,
#   'id': 64,
#   'title': 'voluptas consequatur qui ut quia magnam nemo esse',
#   'completed': False},
#  {'userId': 4,
#   'id': 65,
#   'title': 'fugiat pariatur ratione ut asperiores necessitatibus magni',
#   'completed': False},
#  {'userId': 4,
#   'id': 66,
#   'title': 'rerum eum molestias autem voluptatum sit optio',
#   'completed': False},
#  {'userId': 4,
#   'id': 67,
#   'title': 'quia voluptatibus voluptatem quos similique maiores repellat',
#   'completed': False},
#  {'userId': 4,
#   'id': 68,
#   'title': 'aut id perspiciatis voluptatem iusto',
#   'completed': False},
#  {'userId': 4,
#   'id': 69,
#   'title': 'doloribus sint dolorum ab adipisci itaque dignissimos aliquam suscipit',
#   'completed': False},
#  {'userId': 4,
#   'id': 70,
#   'title': 'ut sequi accusantium et mollitia delectus sunt',
#   'completed': False},
#  {'userId': 4, 'id': 71, 'title': 'aut velit saepe ullam', 'completed': False},
#  {'userId': 4,
#   'id': 72,
#   'title': 'praesentium facilis facere quis harum voluptatibus voluptatem eum',
#   'completed': False},
#  {'userId': 4,
#   'id': 73,
#   'title': 'sint amet quia totam corporis qui exercitationem commodi',
#   'completed': True},
#  {'userId': 4,
#   'id': 74,
#   'title': 'expedita tempore nobis eveniet laborum maiores',
#   'completed': False},
#  {'userId': 4,
#   'id': 75,
#   'title': 'occaecati adipisci est possimus totam',
#   'completed': False},
#  {'userId': 4, 'id': 76, 'title': 'sequi dolorem sed', 'completed': True},
#  {'userId': 4,
#   'id': 77,
#   'title': 'maiores aut nesciunt delectus exercitationem vel assumenda eligendi at',
#   'completed': False},
#  {'userId': 4,
#   'id': 78,
#   'title': 'reiciendis est magnam amet nemo iste recusandae impedit quaerat',
#   'completed': False},
#  {'userId': 4, 'id': 79, 'title': 'eum ipsa maxime ut', 'completed': True},
#  {'userId': 4,
#   'id': 80,
#   'title': 'tempore molestias dolores rerum sequi voluptates ipsum consequatur',
#   'completed': True},
#  {'userId': 5, 'id': 81, 'title': 'suscipit qui totam', 'completed': True},
#  {'userId': 5,
#   'id': 82,
#   'title': 'voluptates eum voluptas et dicta',
#   'completed': False},
#  {'userId': 5,
#   'id': 83,
#   'title': 'quidem at rerum quis ex aut sit quam',
#   'completed': True},
#  {'userId': 5,
#   'id': 84,
#   'title': 'sunt veritatis ut voluptate',
#   'completed': False},
#  {'userId': 5, 'id': 85, 'title': 'et quia ad iste a', 'completed': True},
#  {'userId': 5,
#   'id': 86,
#   'title': 'incidunt ut saepe autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 87,
#   'title': 'laudantium quae eligendi consequatur quia et vero autem',
#   'completed': True},
#  {'userId': 5,
#   'id': 88,
#   'title': 'vitae aut excepturi laboriosam sint aliquam et et accusantium',
#   'completed': False},
#  {'userId': 5, 'id': 89, 'title': 'sequi ut omnis et', 'completed': True},
#  {'userId': 5,
#   'id': 90,
#   'title': 'molestiae nisi accusantium tenetur dolorem et',
#   'completed': True},
#  {'userId': 5,
#   'id': 91,
#   'title': 'nulla quis consequatur saepe qui id expedita',
#   'completed': True},
#  {'userId': 5, 'id': 92, 'title': 'in omnis laboriosam', 'completed': True},
#  {'userId': 5,
#   'id': 93,
#   'title': 'odio iure consequatur molestiae quibusdam necessitatibus quia sint',
#   'completed': True},
#  {'userId': 5,
#   'id': 94,
#   'title': 'facilis modi saepe mollitia',
#   'completed': False},
#  {'userId': 5,
#   'id': 95,
#   'title': 'vel nihil et molestiae iusto assumenda nemo quo ut',
#   'completed': True},
#  {'userId': 5,
#   'id': 96,
#   'title': 'nobis suscipit ducimus enim asperiores voluptas',
#   'completed': False},
#  {'userId': 5,
#   'id': 97,
#   'title': 'dolorum laboriosam eos qui iure aliquam',
#   'completed': False},
#  {'userId': 5,
#   'id': 98,
#   'title': 'debitis accusantium ut quo facilis nihil quis sapiente necessitatibus',
#   'completed': True},
#  {'userId': 5,
#   'id': 99,
#   'title': 'neque voluptates ratione',
#   'completed': False},
#  {'userId': 5,
#   'id': 100,
#   'title': 'excepturi a et neque qui expedita vel voluptate',
#   'completed': False},
#  {'userId': 6,
#   'id': 101,
#   'title': 'explicabo enim cumque porro aperiam occaecati minima',
#   'completed': False},
#  {'userId': 6, 'id': 102, 'title': 'sed ab consequatur', 'completed': False},
#  {'userId': 6,
#   'id': 103,
#   'title': 'non sunt delectus illo nulla tenetur enim omnis',
#   'completed': False},
#  {'userId': 6,
#   'id': 104,
#   'title': 'excepturi non laudantium quo',
#   'completed': False},
#  {'userId': 6,
#   'id': 105,
#   'title': 'totam quia dolorem et illum repellat voluptas optio',
#   'completed': True},
#  {'userId': 6,
#   'id': 106,
#   'title': 'ad illo quis voluptatem temporibus',
#   'completed': True},
#  {'userId': 6,
#   'id': 107,
#   'title': 'praesentium facilis omnis laudantium fugit ad iusto nihil nesciunt',
#   'completed': False},
#  {'userId': 6,
#   'id': 108,
#   'title': 'a eos eaque nihil et exercitationem incidunt delectus',
#   'completed': True},
#  {'userId': 6,
#   'id': 109,
#   'title': 'autem temporibus harum quisquam in culpa',
#   'completed': True},
#  {'userId': 6, 'id': 110, 'title': 'aut aut ea corporis', 'completed': True},
#  {'userId': 6,
#   'id': 111,
#   'title': 'magni accusantium labore et id quis provident',
#   'completed': False},
#  {'userId': 6,
#   'id': 112,
#   'title': 'consectetur impedit quisquam qui deserunt non rerum consequuntur eius',
#   'completed': False},
#  {'userId': 6,
#   'id': 113,
#   'title': 'quia atque aliquam sunt impedit voluptatum rerum assumenda nisi',
#   'completed': False},
#  {'userId': 6,
#   'id': 114,
#   'title': 'cupiditate quos possimus corporis quisquam exercitationem beatae',
#   'completed': False},
#  {'userId': 6, 'id': 115, 'title': 'sed et ea eum', 'completed': False},
#  {'userId': 6,
#   'id': 116,
#   'title': 'ipsa dolores vel facilis ut',
#   'completed': True},
#  {'userId': 6,
#   'id': 117,
#   'title': 'sequi quae est et qui qui eveniet asperiores',
#   'completed': False},
#  {'userId': 6,
#   'id': 118,
#   'title': 'quia modi consequatur vero fugiat',
#   'completed': False},
#  {'userId': 6,
#   'id': 119,
#   'title': 'corporis ducimus ea perspiciatis iste',
#   'completed': False},
#  {'userId': 6,
#   'id': 120,
#   'title': 'dolorem laboriosam vel voluptas et aliquam quasi',
#   'completed': False},
#  {'userId': 7,
#   'id': 121,
#   'title': 'inventore aut nihil minima laudantium hic qui omnis',
#   'completed': True},
#  {'userId': 7,
#   'id': 122,
#   'title': 'provident aut nobis culpa',
#   'completed': True},
#  {'userId': 7,
#   'id': 123,
#   'title': 'esse et quis iste est earum aut impedit',
#   'completed': False},
#  {'userId': 7, 'id': 124, 'title': 'qui consectetur id', 'completed': False},
#  {'userId': 7,
#   'id': 125,
#   'title': 'aut quasi autem iste tempore illum possimus',
#   'completed': False},
#  {'userId': 7,
#   'id': 126,
#   'title': 'ut asperiores perspiciatis veniam ipsum rerum saepe',
#   'completed': True},
#  {'userId': 7,
#   'id': 127,
#   'title': 'voluptatem libero consectetur rerum ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 128,
#   'title': 'eius omnis est qui voluptatem autem',
#   'completed': False},
#  {'userId': 7,
#   'id': 129,
#   'title': 'rerum culpa quis harum',
#   'completed': False},
#  {'userId': 7,
#   'id': 130,
#   'title': 'nulla aliquid eveniet harum laborum libero alias ut unde',
#   'completed': True},
#  {'userId': 7, 'id': 131, 'title': 'qui ea incidunt quis', 'completed': False},
#  {'userId': 7,
#   'id': 132,
#   'title': 'qui molestiae voluptatibus velit iure harum quisquam',
#   'completed': True},
#  {'userId': 7,
#   'id': 133,
#   'title': 'et labore eos enim rerum consequatur sunt',
#   'completed': True},
#  {'userId': 7,
#   'id': 134,
#   'title': 'molestiae doloribus et laborum quod ea',
#   'completed': False},
#  {'userId': 7,
#   'id': 135,
#   'title': 'facere ipsa nam eum voluptates reiciendis vero qui',
#   'completed': False},
#  {'userId': 7,
#   'id': 136,
#   'title': 'asperiores illo tempora fuga sed ut quasi adipisci',
#   'completed': False},
#  {'userId': 7, 'id': 137, 'title': 'qui sit non', 'completed': False},
#  {'userId': 7,
#   'id': 138,
#   'title': 'placeat minima consequatur rem qui ut',
#   'completed': True},
#  {'userId': 7,
#   'id': 139,
#   'title': 'consequatur doloribus id possimus voluptas a voluptatem',
#   'completed': False},
#  {'userId': 7,
#   'id': 140,
#   'title': 'aut consectetur in blanditiis deserunt quia sed laboriosam',
#   'completed': True},
#  {'userId': 8,
#   'id': 141,
#   'title': 'explicabo consectetur debitis voluptates quas quae culpa rerum non',
#   'completed': True},
#  {'userId': 8,
#   'id': 142,
#   'title': 'maiores accusantium architecto necessitatibus reiciendis ea aut',
#   'completed': True},
#  {'userId': 8,
#   'id': 143,
#   'title': 'eum non recusandae cupiditate animi',
#   'completed': False},
#  {'userId': 8,
#   'id': 144,
#   'title': 'ut eum exercitationem sint',
#   'completed': False},
#  {'userId': 8,
#   'id': 145,
#   'title': 'beatae qui ullam incidunt voluptatem non nisi aliquam',
#   'completed': False},
#  {'userId': 8,
#   'id': 146,
#   'title': 'molestiae suscipit ratione nihil odio libero impedit vero totam',
#   'completed': True},
#  {'userId': 8,
#   'id': 147,
#   'title': 'eum itaque quod reprehenderit et facilis dolor autem ut',
#   'completed': True},
#  {'userId': 8,
#   'id': 148,
#   'title': 'esse quas et quo quasi exercitationem',
#   'completed': False},
#  {'userId': 8,
#   'id': 149,
#   'title': 'animi voluptas quod perferendis est',
#   'completed': False},
#  {'userId': 8,
#   'id': 150,
#   'title': 'eos amet tempore laudantium fugit a',
#   'completed': False},
#  {'userId': 8,
#   'id': 151,
#   'title': 'accusamus adipisci dicta qui quo ea explicabo sed vero',
#   'completed': True},
#  {'userId': 8,
#   'id': 152,
#   'title': 'odit eligendi recusandae doloremque cumque non',
#   'completed': False},
#  {'userId': 8,
#   'id': 153,
#   'title': 'ea aperiam consequatur qui repellat eos',
#   'completed': False},
#  {'userId': 8, 'id': 154, 'title': 'rerum non ex sapiente', 'completed': True},
#  {'userId': 8,
#   'id': 155,
#   'title': 'voluptatem nobis consequatur et assumenda magnam',
#   'completed': True},
#  {'userId': 8,
#   'id': 156,
#   'title': 'nam quia quia nulla repellat assumenda quibusdam sit nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 157,
#   'title': 'dolorem veniam quisquam deserunt repellendus',
#   'completed': True},
#  {'userId': 8,
#   'id': 158,
#   'title': 'debitis vitae delectus et harum accusamus aut deleniti a',
#   'completed': True},
#  {'userId': 8,
#   'id': 159,
#   'title': 'debitis adipisci quibusdam aliquam sed dolore ea praesentium nobis',
#   'completed': True},
#  {'userId': 8,
#   'id': 160,
#   'title': 'et praesentium aliquam est',
#   'completed': False},
#  {'userId': 9,
#   'id': 161,
#   'title': 'ex hic consequuntur earum omnis alias ut occaecati culpa',
#   'completed': True},
#  {'userId': 9,
#   'id': 162,
#   'title': 'omnis laboriosam molestias animi sunt dolore',
#   'completed': True},
#  {'userId': 9,
#   'id': 163,
#   'title': 'natus corrupti maxime laudantium et voluptatem laboriosam odit',
#   'completed': False},
#  {'userId': 9,
#   'id': 164,
#   'title': 'reprehenderit quos aut aut consequatur est sed',
#   'completed': False},
#  {'userId': 9,
#   'id': 165,
#   'title': 'fugiat perferendis sed aut quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 166,
#   'title': 'quos quo possimus suscipit minima ut',
#   'completed': False},
#  {'userId': 9,
#   'id': 167,
#   'title': 'et quis minus quo a asperiores molestiae',
#   'completed': False},
#  {'userId': 9,
#   'id': 168,
#   'title': 'recusandae quia qui sunt libero',
#   'completed': False},
#  {'userId': 9,
#   'id': 169,
#   'title': 'ea odio perferendis officiis',
#   'completed': True},
#  {'userId': 9,
#   'id': 170,
#   'title': 'quisquam aliquam quia doloribus aut',
#   'completed': False},
#  {'userId': 9,
#   'id': 171,
#   'title': 'fugiat aut voluptatibus corrupti deleniti velit iste odio',
#   'completed': True},
#  {'userId': 9,
#   'id': 172,
#   'title': 'et provident amet rerum consectetur et voluptatum',
#   'completed': False},
#  {'userId': 9,
#   'id': 173,
#   'title': 'harum ad aperiam quis',
#   'completed': False},
#  {'userId': 9, 'id': 174, 'title': 'similique aut quo', 'completed': False},
#  {'userId': 9,
#   'id': 175,
#   'title': 'laudantium eius officia perferendis provident perspiciatis asperiores',
#   'completed': True},
#  {'userId': 9,
#   'id': 176,
#   'title': 'magni soluta corrupti ut maiores rem quidem',
#   'completed': False},
#  {'userId': 9,
#   'id': 177,
#   'title': 'et placeat temporibus voluptas est tempora quos quibusdam',
#   'completed': False},
#  {'userId': 9,
#   'id': 178,
#   'title': 'nesciunt itaque commodi tempore',
#   'completed': True},
#  {'userId': 9,
#   'id': 179,
#   'title': 'omnis consequuntur cupiditate impedit itaque ipsam quo',
#   'completed': True},
#  {'userId': 9,
#   'id': 180,
#   'title': 'debitis nisi et dolorem repellat et',
#   'completed': True},
#  {'userId': 10,
#   'id': 181,
#   'title': 'ut cupiditate sequi aliquam fuga maiores',
#   'completed': False},
#  {'userId': 10,
#   'id': 182,
#   'title': 'inventore saepe cumque et aut illum enim',
#   'completed': True},
#  {'userId': 10,
#   'id': 183,
#   'title': 'omnis nulla eum aliquam distinctio',
#   'completed': True},
#  {'userId': 10,
#   'id': 184,
#   'title': 'molestias modi perferendis perspiciatis',
#   'completed': False},
#  {'userId': 10,
#   'id': 185,
#   'title': 'voluptates dignissimos sed doloribus animi quaerat aut',
#   'completed': False},
#  {'userId': 10,
#   'id': 186,
#   'title': 'explicabo odio est et',
#   'completed': False},
#  {'userId': 10,
#   'id': 187,
#   'title': 'consequuntur animi possimus',
#   'completed': False},
#  {'userId': 10, 'id': 188, 'title': 'vel non beatae est', 'completed': True},
#  {'userId': 10,
#   'id': 189,
#   'title': 'culpa eius et voluptatem et',
#   'completed': True},
#  {'userId': 10,
#   'id': 190,
#   'title': 'accusamus sint iusto et voluptatem exercitationem',
#   'completed': True},
#  {'userId': 10,
#   'id': 191,
#   'title': 'temporibus atque distinctio omnis eius impedit tempore molestias pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 192,
#   'title': 'ut quas possimus exercitationem sint voluptates',
#   'completed': False},
#  {'userId': 10,
#   'id': 193,
#   'title': 'rerum debitis voluptatem qui eveniet tempora distinctio a',
#   'completed': True},
#  {'userId': 10,
#   'id': 194,
#   'title': 'sed ut vero sit molestiae',
#   'completed': False},
#  {'userId': 10,
#   'id': 195,
#   'title': 'rerum ex veniam mollitia voluptatibus pariatur',
#   'completed': True},
#  {'userId': 10,
#   'id': 196,
#   'title': 'consequuntur aut ut fugit similique',
#   'completed': True},
#  {'userId': 10,
#   'id': 197,
#   'title': 'dignissimos quo nobis earum saepe',
#   'completed': True},
#  {'userId': 10,
#   'id': 198,
#   'title': 'quis eius est sint explicabo',
#   'completed': True},
#  {'userId': 10,
#   'id': 199,
#   'title': 'numquam repellendus a magnam',
#   'completed': True},
#  {'userId': 10,
#   'id': 200,
#   'title': 'ipsam aperiam voluptates qui',
#   'completed': False}]

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(results)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '35665348045',
#   'type': 'PushEvent',
#   'actor': {'id': 66976984,
#    'login': 'NilleSnille',
#    'display_login': 'NilleSnille',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NilleSnille',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66976984?'},
#   'repo': {'id': 757153299,
#    'name': 'NilleSnille/collection',
#    'url': 'https://api.github.com/repos/NilleSnille/collection'},
#   'payload': {'repository_id': 757153299,
#    'push_id': 17085919026,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8c53d95df6f4581a5ab3c362f6efc497486dc631',
#    'before': '9fde2802733e1ff65188b5064b7261eccb62e94a',
#    'commits': [{'sha': '8c53d95df6f4581a5ab3c362f6efc497486dc631',
#      'author': {'email': '66976984+NilleSnille@users.noreply.github.com',
#       'name': 'NilleSnille'},
#      'message': 'Update Variational Auto Encoder.ipynb',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/NilleSnille/collection/commits/8c53d95df6f4581a5ab3c362f6efc497486dc631'}]},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z'},
#  {'id': '35665348017',
#   'type': 'PushEvent',
#   'actor': {'id': 106912404,
#    'login': 'DimitrisDavidGerokonstantis',
#    'display_login': 'DimitrisDavidGerokonstantis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DimitrisDavidGerokonstantis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/106912404?'},
#   'repo': {'id': 755607266,
#    'name': 'DimitrisDavidGerokonstantis/PolLar',
#    'url': 'https://api.github.com/repos/DimitrisDavidGerokonstantis/PolLar'},
#   'payload': {'repository_id': 755607266,
#    'push_id': 17085918987,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7be2f7788b49199d10b6d25ee285a812801f7a2d',
#    'before': '6c70f7650de8431116e89eaa68b0ebfd6cf82762',
#    'commits': [{'sha': '7be2f7788b49199d10b6d25ee285a812801f7a2d',
#      'author': {'email': 'dimitrisger2@gmail.com', 'name': 'Dimitris'},
#      'message': 'message',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DimitrisDavidGerokonstantis/PolLar/commits/7be2f7788b49199d10b6d25ee285a812801f7a2d'}]},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z'},
#  {'id': '35665348090',
#   'type': 'PushEvent',
#   'actor': {'id': 8376748,
#    'login': 'Arjoo',
#    'display_login': 'Arjoo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Arjoo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8376748?'},
#   'repo': {'id': 757005237,
#    'name': 'Arjoo/spring-boot-mongodb-docker-compose',
#    'url': 'https://api.github.com/repos/Arjoo/spring-boot-mongodb-docker-compose'},
#   'payload': {'repository_id': 757005237,
#    'push_id': 17085919029,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5a5e9b0edc351462d9530dc116115f9086a2d155',
#    'before': '3948da64f5325ff6b849d323c81153101c357466',
#    'commits': [{'sha': '5a5e9b0edc351462d9530dc116115f9086a2d155',
#      'author': {'email': '2009arjoo@gmail.com', 'name': 'arjoo'},
#      'message': 'added login and signup',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Arjoo/spring-boot-mongodb-docker-compose/commits/5a5e9b0edc351462d9530dc116115f9086a2d155'}]},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z'},
#  {'id': '35665348042',
#   'type': 'PushEvent',
#   'actor': {'id': 157866528,
#    'login': 'ttgds3asu',
#    'display_login': 'ttgds3asu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ttgds3asu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/157866528?'},
#   'repo': {'id': 752900181,
#    'name': 'udnsenattinndgi/repo19',
#    'url': 'https://api.github.com/repos/udnsenattinndgi/repo19'},
#   'payload': {'repository_id': 752900181,
#    'push_id': 17085919007,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '24e40bf274080c154178e62c70668aa514f8b57e',
#    'before': '086b6a084aa10e5fe47792d50438a8194b25129a',
#    'commits': [{'sha': '24e40bf274080c154178e62c70668aa514f8b57e',
#      'author': {'email': 'you@example.com', 'name': 'Your Name'},
#      'message': 'Empty Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/udnsenattinndgi/repo19/commits/24e40bf274080c154178e62c70668aa514f8b57e'}]},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z',
#   'org': {'id': 158984731,
#    'login': 'udnsenattinndgi',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/udnsenattinndgi',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/158984731?'}},
#  {'id': '35665348075',
#   'type': 'CreateEvent',
#   'actor': {'id': 105236673,
#    'login': 'scalr-autotester8',
#    'display_login': 'scalr-autotester8',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/scalr-autotester8',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/105236673?'},
#   'repo': {'id': 492878833,
#    'name': 'scalr-automation/terraform-scalr-flat-mirror1',
#    'url': 'https://api.github.com/repos/scalr-automation/terraform-scalr-flat-mirror1'},
#   'payload': {'ref': 'abase-operation-feeling',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'The repository with flat terraform code for auto-tests',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z',
#   'org': {'id': 103308247,
#    'login': 'scalr-automation',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/scalr-automation',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103308247?'}},
#  {'id': '35665348065',
#   'type': 'PushEvent',
#   'actor': {'id': 137176738,
#    'login': 'ashish-egov',
#    'display_login': 'ashish-egov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ashish-egov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/137176738?'},
#   'repo': {'id': 690467910,
#    'name': 'egovernments/DIGIT-Frontend',
#    'url': 'https://api.github.com/repos/egovernments/DIGIT-Frontend'},
#   'payload': {'repository_id': 690467910,
#    'push_id': 17085919004,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/stable-bff',
#    'head': '5f8bc274ad355e440da3d7d63a38eff917235a82',
#    'before': 'c537b080ba1f05ae19eaacf5d3947fbbab1278dd',
#    'commits': [{'sha': '29d987c7fec9752de83f70257f1a61a6363ca814',
#      'author': {'email': 'ashish.tiwari@egovernments.org',
#       'name': 'ashish-egov'},
#      'message': 'Feat : Added integration for error scenarios for activity details',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/egovernments/DIGIT-Frontend/commits/29d987c7fec9752de83f70257f1a61a6363ca814'},
#     {'sha': '5f8bc274ad355e440da3d7d63a38eff917235a82',
#      'author': {'email': 'ashish.tiwari@egovernments.org',
#       'name': 'ashish-egov'},
#      'message': "Merge branch 'stable-bff' of https://github.com/egovernments/DIGIT-Frontend into stable-bff",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/egovernments/DIGIT-Frontend/commits/5f8bc274ad355e440da3d7d63a38eff917235a82'}]},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z',
#   'org': {'id': 6940476,
#    'login': 'egovernments',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/egovernments',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6940476?'}},
#  {'id': '35665348086',
#   'type': 'CreateEvent',
#   'actor': {'id': 148450933,
#    'login': 'seankennelly',
#    'display_login': 'seankennelly',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/seankennelly',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/148450933?'},
#   'repo': {'id': 757351581,
#    'name': 'seankennelly/kreativstorm_jumping_game',
#    'url': 'https://api.github.com/repos/seankennelly/kreativstorm_jumping_game'},
#   'payload': {'ref': 'sean_branch',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z'},
#  {'id': '35665348018',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 31882754,
#    'login': 'Jihed525',
#    'display_login': 'Jihed525',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Jihed525',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31882754?'},
#   'repo': {'id': 205883930,
#    'name': 'exoplatform/news',
#    'url': 'https://api.github.com/repos/exoplatform/news'},
#   'payload': {'action': 'created',
#    'review': {'id': 1879884927,
#     'node_id': 'PRR_kwDODEWKGs5wDMR_',
#     'user': {'login': 'Jihed525',
#      'id': 31882754,
#      'node_id': 'MDQ6VXNlcjMxODgyNzU0',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/31882754?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Jihed525',
#      'html_url': 'https://github.com/Jihed525',
#      'followers_url': 'https://api.github.com/users/Jihed525/followers',
#      'following_url': 'https://api.github.com/users/Jihed525/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Jihed525/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Jihed525/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Jihed525/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Jihed525/orgs',
#      'repos_url': 'https://api.github.com/users/Jihed525/repos',
#      'events_url': 'https://api.github.com/users/Jihed525/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Jihed525/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'commit_id': '937294eb694b6e37a962e87b81a9dd08a0ece2c5',
#     'submitted_at': '2024-02-14T10:18:46Z',
#     'state': 'approved',
#     'html_url': 'https://github.com/exoplatform/news/pull/1102#pullrequestreview-1879884927',
#     'pull_request_url': 'https://api.github.com/repos/exoplatform/news/pulls/1102',
#     'author_association': 'MEMBER',
#     '_links': {'html': {'href': 'https://github.com/exoplatform/news/pull/1102#pullrequestreview-1879884927'},
#      'pull_request': {'href': 'https://api.github.com/repos/exoplatform/news/pulls/1102'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/exoplatform/news/pulls/1102',
#     'id': 1725371736,
#     'node_id': 'PR_kwDODEWKGs5m1xVY',
#     'html_url': 'https://github.com/exoplatform/news/pull/1102',
#     'diff_url': 'https://github.com/exoplatform/news/pull/1102.diff',
#     'patch_url': 'https://github.com/exoplatform/news/pull/1102.patch',
#     'issue_url': 'https://api.github.com/repos/exoplatform/news/issues/1102',
#     'number': 1102,
#     'state': 'open',
#     'locked': False,
#     'title': 'fix: fix deleted news figure in missed activities counter - EXO-69288',
#     'user': {'login': 'GouadriaHanen',
#      'id': 49310007,
#      'node_id': 'MDQ6VXNlcjQ5MzEwMDA3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/49310007?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/GouadriaHanen',
#      'html_url': 'https://github.com/GouadriaHanen',
#      'followers_url': 'https://api.github.com/users/GouadriaHanen/followers',
#      'following_url': 'https://api.github.com/users/GouadriaHanen/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/GouadriaHanen/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/GouadriaHanen/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/GouadriaHanen/subscriptions',
#      'organizations_url': 'https://api.github.com/users/GouadriaHanen/orgs',
#      'repos_url': 'https://api.github.com/users/GouadriaHanen/repos',
#      'events_url': 'https://api.github.com/users/GouadriaHanen/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/GouadriaHanen/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': 'before this change, after deleting news, it appears in the missed activities counter since its metadata item still exists After this change, when deleting news its unread metadata items and all related metaDataItems are deleted and the counter of missed activities is displayed correctly',
#     'created_at': '2024-02-14T10:11:08Z',
#     'updated_at': '2024-02-14T10:18:46Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '5bce45d816e0a854c305cffba9f2cd70cf45ffc5',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/exoplatform/news/pulls/1102/commits',
#     'review_comments_url': 'https://api.github.com/repos/exoplatform/news/pulls/1102/comments',
#     'review_comment_url': 'https://api.github.com/repos/exoplatform/news/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/exoplatform/news/issues/1102/comments',
#     'statuses_url': 'https://api.github.com/repos/exoplatform/news/statuses/937294eb694b6e37a962e87b81a9dd08a0ece2c5',
#     'head': {'label': 'exoplatform:tobackport',
#      'ref': 'tobackport',
#      'sha': '937294eb694b6e37a962e87b81a9dd08a0ece2c5',
#      'user': {'login': 'exoplatform',
#       'id': 259384,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1OTM4NA==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/259384?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/exoplatform',
#       'html_url': 'https://github.com/exoplatform',
#       'followers_url': 'https://api.github.com/users/exoplatform/followers',
#       'following_url': 'https://api.github.com/users/exoplatform/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/exoplatform/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/exoplatform/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/exoplatform/subscriptions',
#       'organizations_url': 'https://api.github.com/users/exoplatform/orgs',
#       'repos_url': 'https://api.github.com/users/exoplatform/repos',
#       'events_url': 'https://api.github.com/users/exoplatform/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/exoplatform/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 205883930,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDU4ODM5MzA=',
#       'name': 'news',
#       'full_name': 'exoplatform/news',
#       'private': False,
#       'owner': {'login': 'exoplatform',
#        'id': 259384,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1OTM4NA==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/259384?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/exoplatform',
#        'html_url': 'https://github.com/exoplatform',
#        'followers_url': 'https://api.github.com/users/exoplatform/followers',
#        'following_url': 'https://api.github.com/users/exoplatform/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/exoplatform/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/exoplatform/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/exoplatform/subscriptions',
#        'organizations_url': 'https://api.github.com/users/exoplatform/orgs',
#        'repos_url': 'https://api.github.com/users/exoplatform/repos',
#        'events_url': 'https://api.github.com/users/exoplatform/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/exoplatform/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/exoplatform/news',
#       'description': 'News addon',
#       'fork': False,
#       'url': 'https://api.github.com/repos/exoplatform/news',
#       'forks_url': 'https://api.github.com/repos/exoplatform/news/forks',
#       'keys_url': 'https://api.github.com/repos/exoplatform/news/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/exoplatform/news/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/exoplatform/news/teams',
#       'hooks_url': 'https://api.github.com/repos/exoplatform/news/hooks',
#       'issue_events_url': 'https://api.github.com/repos/exoplatform/news/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/exoplatform/news/events',
#       'assignees_url': 'https://api.github.com/repos/exoplatform/news/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/exoplatform/news/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/exoplatform/news/tags',
#       'blobs_url': 'https://api.github.com/repos/exoplatform/news/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/exoplatform/news/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/exoplatform/news/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/exoplatform/news/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/exoplatform/news/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/exoplatform/news/languages',
#       'stargazers_url': 'https://api.github.com/repos/exoplatform/news/stargazers',
#       'contributors_url': 'https://api.github.com/repos/exoplatform/news/contributors',
#       'subscribers_url': 'https://api.github.com/repos/exoplatform/news/subscribers',
#       'subscription_url': 'https://api.github.com/repos/exoplatform/news/subscription',
#       'commits_url': 'https://api.github.com/repos/exoplatform/news/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/exoplatform/news/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/exoplatform/news/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/exoplatform/news/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/exoplatform/news/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/exoplatform/news/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/exoplatform/news/merges',
#       'archive_url': 'https://api.github.com/repos/exoplatform/news/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/exoplatform/news/downloads',
#       'issues_url': 'https://api.github.com/repos/exoplatform/news/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/exoplatform/news/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/exoplatform/news/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/exoplatform/news/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/exoplatform/news/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/exoplatform/news/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/exoplatform/news/deployments',
#       'created_at': '2019-09-02T15:17:47Z',
#       'updated_at': '2023-03-14T10:09:40Z',
#       'pushed_at': '2024-02-14T10:18:34Z',
#       'git_url': 'git://github.com/exoplatform/news.git',
#       'ssh_url': 'git@github.com:exoplatform/news.git',
#       'clone_url': 'https://github.com/exoplatform/news.git',
#       'svn_url': 'https://github.com/exoplatform/news',
#       'homepage': '',
#       'size': 9624,
#       'stargazers_count': 3,
#       'watchers_count': 3,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 3,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 3,
#       'open_issues': 5,
#       'watchers': 3,
#       'default_branch': 'develop'}},
#     'base': {'label': 'exoplatform:stable/2.5.x',
#      'ref': 'stable/2.5.x',
#      'sha': '4d5bafe2c3fa1ad771e9539edebb3b3d6bc6bfe3',
#      'user': {'login': 'exoplatform',
#       'id': 259384,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1OTM4NA==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/259384?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/exoplatform',
#       'html_url': 'https://github.com/exoplatform',
#       'followers_url': 'https://api.github.com/users/exoplatform/followers',
#       'following_url': 'https://api.github.com/users/exoplatform/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/exoplatform/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/exoplatform/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/exoplatform/subscriptions',
#       'organizations_url': 'https://api.github.com/users/exoplatform/orgs',
#       'repos_url': 'https://api.github.com/users/exoplatform/repos',
#       'events_url': 'https://api.github.com/users/exoplatform/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/exoplatform/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 205883930,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMDU4ODM5MzA=',
#       'name': 'news',
#       'full_name': 'exoplatform/news',
#       'private': False,
#       'owner': {'login': 'exoplatform',
#        'id': 259384,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjI1OTM4NA==',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/259384?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/exoplatform',
#        'html_url': 'https://github.com/exoplatform',
#        'followers_url': 'https://api.github.com/users/exoplatform/followers',
#        'following_url': 'https://api.github.com/users/exoplatform/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/exoplatform/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/exoplatform/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/exoplatform/subscriptions',
#        'organizations_url': 'https://api.github.com/users/exoplatform/orgs',
#        'repos_url': 'https://api.github.com/users/exoplatform/repos',
#        'events_url': 'https://api.github.com/users/exoplatform/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/exoplatform/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/exoplatform/news',
#       'description': 'News addon',
#       'fork': False,
#       'url': 'https://api.github.com/repos/exoplatform/news',
#       'forks_url': 'https://api.github.com/repos/exoplatform/news/forks',
#       'keys_url': 'https://api.github.com/repos/exoplatform/news/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/exoplatform/news/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/exoplatform/news/teams',
#       'hooks_url': 'https://api.github.com/repos/exoplatform/news/hooks',
#       'issue_events_url': 'https://api.github.com/repos/exoplatform/news/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/exoplatform/news/events',
#       'assignees_url': 'https://api.github.com/repos/exoplatform/news/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/exoplatform/news/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/exoplatform/news/tags',
#       'blobs_url': 'https://api.github.com/repos/exoplatform/news/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/exoplatform/news/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/exoplatform/news/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/exoplatform/news/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/exoplatform/news/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/exoplatform/news/languages',
#       'stargazers_url': 'https://api.github.com/repos/exoplatform/news/stargazers',
#       'contributors_url': 'https://api.github.com/repos/exoplatform/news/contributors',
#       'subscribers_url': 'https://api.github.com/repos/exoplatform/news/subscribers',
#       'subscription_url': 'https://api.github.com/repos/exoplatform/news/subscription',
#       'commits_url': 'https://api.github.com/repos/exoplatform/news/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/exoplatform/news/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/exoplatform/news/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/exoplatform/news/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/exoplatform/news/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/exoplatform/news/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/exoplatform/news/merges',
#       'archive_url': 'https://api.github.com/repos/exoplatform/news/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/exoplatform/news/downloads',
#       'issues_url': 'https://api.github.com/repos/exoplatform/news/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/exoplatform/news/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/exoplatform/news/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/exoplatform/news/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/exoplatform/news/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/exoplatform/news/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/exoplatform/news/deployments',
#       'created_at': '2019-09-02T15:17:47Z',
#       'updated_at': '2023-03-14T10:09:40Z',
#       'pushed_at': '2024-02-14T10:18:34Z',
#       'git_url': 'git://github.com/exoplatform/news.git',
#       'ssh_url': 'git@github.com:exoplatform/news.git',
#       'clone_url': 'https://github.com/exoplatform/news.git',
#       'svn_url': 'https://github.com/exoplatform/news',
#       'homepage': '',
#       'size': 9624,
#       'stargazers_count': 3,
#       'watchers_count': 3,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 3,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': {'key': 'agpl-3.0',
#        'name': 'GNU Affero General Public License v3.0',
#        'spdx_id': 'AGPL-3.0',
#        'url': 'https://api.github.com/licenses/agpl-3.0',
#        'node_id': 'MDc6TGljZW5zZTE='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 3,
#       'open_issues': 5,
#       'watchers': 3,
#       'default_branch': 'develop'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/exoplatform/news/pulls/1102'},
#      'html': {'href': 'https://github.com/exoplatform/news/pull/1102'},
#      'issue': {'href': 'https://api.github.com/repos/exoplatform/news/issues/1102'},
#      'comments': {'href': 'https://api.github.com/repos/exoplatform/news/issues/1102/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/exoplatform/news/pulls/1102/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/exoplatform/news/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/exoplatform/news/pulls/1102/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/exoplatform/news/statuses/937294eb694b6e37a962e87b81a9dd08a0ece2c5'}},
#     'author_association': 'MEMBER',
#     'auto_merge': {'enabled_by': {'login': 'GouadriaHanen',
#       'id': 49310007,
#       'node_id': 'MDQ6VXNlcjQ5MzEwMDA3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/49310007?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GouadriaHanen',
#       'html_url': 'https://github.com/GouadriaHanen',
#       'followers_url': 'https://api.github.com/users/GouadriaHanen/followers',
#       'following_url': 'https://api.github.com/users/GouadriaHanen/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GouadriaHanen/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GouadriaHanen/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GouadriaHanen/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GouadriaHanen/orgs',
#       'repos_url': 'https://api.github.com/users/GouadriaHanen/repos',
#       'events_url': 'https://api.github.com/users/GouadriaHanen/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GouadriaHanen/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'merge_method': 'squash',
#      'commit_title': 'fix: fix deleted news figure in missed activities counter - EXO-69288  (#1102)',
#      'commit_message': 'before this change, after deleting news, it appears in the missed activities counter since its metadata item still exists\r\nAfter this change, when deleting news its unread metadata items and all related metaDataItems are deleted and the counter of missed activities is displayed correctly'},
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z',
#   'org': {'id': 259384,
#    'login': 'exoplatform',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/exoplatform',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/259384?'}},
#  {'id': '35665348059',
#   'type': 'PushEvent',
#   'actor': {'id': 157866528,
#    'login': 'ttgds3asu',
#    'display_login': 'ttgds3asu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ttgds3asu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/157866528?'},
#   'repo': {'id': 751736860,
#    'name': '235wgdf/repo4',
#    'url': 'https://api.github.com/repos/235wgdf/repo4'},
#   'payload': {'repository_id': 751736860,
#    'push_id': 17085919013,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '156ac84a12943b50e1b909a7e67e32232e8f0b82',
#    'before': '40242277665d8bc12c673caaca97cfb7b49b39c9',
#    'commits': [{'sha': '156ac84a12943b50e1b909a7e67e32232e8f0b82',
#      'author': {'email': 'you@example.com', 'name': 'Your Name'},
#      'message': 'Empty Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/235wgdf/repo4/commits/156ac84a12943b50e1b909a7e67e32232e8f0b82'}]},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z',
#   'org': {'id': 158556802,
#    'login': '235wgdf',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/235wgdf',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/158556802?'}},
#  {'id': '35665348034',
#   'type': 'PushEvent',
#   'actor': {'id': 11218275,
#    'login': 'tmmlaarhoven',
#    'display_login': 'tmmlaarhoven',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tmmlaarhoven',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11218275?'},
#   'repo': {'id': 702186019,
#    'name': 'tmmlaarhoven/lichess-knockout',
#    'url': 'https://api.github.com/repos/tmmlaarhoven/lichess-knockout'},
#   'payload': {'repository_id': 702186019,
#    'push_id': 17085919015,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'dc557c7d629c800ed01a7baf964117c528e09ec3',
#    'before': 'b5fd02e88cd2c2f898bf9180c26f73be3de326de',
#    'commits': [{'sha': 'dc557c7d629c800ed01a7baf964117c528e09ec3',
#      'author': {'email': 'mail@thijs.com', 'name': 'Thijs Laarhoven'},
#      'message': 'Updating bracket Dn1DIJUM.png before tournament start',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tmmlaarhoven/lichess-knockout/commits/dc557c7d629c800ed01a7baf964117c528e09ec3'}]},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z'},
#  {'id': '35665348004',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 7905502,
#    'login': 'baywet',
#    'display_login': 'baywet',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baywet',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7905502?'},
#   'repo': {'id': 438045872,
#    'name': 'microsoft/kiota-typescript',
#    'url': 'https://api.github.com/repos/microsoft/kiota-typescript'},
#   'payload': {'action': 'created',
#    'review': {'id': 1879884919,
#     'node_id': 'PRR_kwDOGhwMsM5wDMR3',
#     'user': {'login': 'baywet',
#      'id': 7905502,
#      'node_id': 'MDQ6VXNlcjc5MDU1MDI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/7905502?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/baywet',
#      'html_url': 'https://github.com/baywet',
#      'followers_url': 'https://api.github.com/users/baywet/followers',
#      'following_url': 'https://api.github.com/users/baywet/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/baywet/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/baywet/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/baywet/subscriptions',
#      'organizations_url': 'https://api.github.com/users/baywet/orgs',
#      'repos_url': 'https://api.github.com/users/baywet/repos',
#      'events_url': 'https://api.github.com/users/baywet/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/baywet/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'commit_id': 'ac3afd2553984ce2329f2b41a276e519e1566808',
#     'submitted_at': '2024-02-14T10:18:46Z',
#     'state': 'approved',
#     'html_url': 'https://github.com/microsoft/kiota-typescript/pull/964#pullrequestreview-1879884919',
#     'pull_request_url': 'https://api.github.com/repos/microsoft/kiota-typescript/pulls/964',
#     'author_association': 'MEMBER',
#     '_links': {'html': {'href': 'https://github.com/microsoft/kiota-typescript/pull/964#pullrequestreview-1879884919'},
#      'pull_request': {'href': 'https://api.github.com/repos/microsoft/kiota-typescript/pulls/964'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/microsoft/kiota-typescript/pulls/964',
#     'id': 1612988333,
#     'node_id': 'PR_kwDOGhwMsM5gJD-t',
#     'html_url': 'https://github.com/microsoft/kiota-typescript/pull/964',
#     'diff_url': 'https://github.com/microsoft/kiota-typescript/pull/964.diff',
#     'patch_url': 'https://github.com/microsoft/kiota-typescript/pull/964.patch',
#     'issue_url': 'https://api.github.com/repos/microsoft/kiota-typescript/issues/964',
#     'number': 964,
#     'state': 'open',
#     'locked': False,
#     'title': 'auto dependabot: bump @microsoft/sp-http from 1.15.2 to 1.18.2',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [@microsoft/sp-http](http://aka.ms/spfx) from 1.15.2 to 1.18.2.\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=@microsoft/sp-http&package-manager=npm_and_yarn&previous-version=1.15.2&new-version=1.18.2)](https://docs.github.com/en/github/managing-security-vulnerabilities/about-dependabot-security-updates#about-compatibility-scores)\n\nYou can trigger a rebase of this PR by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot show <dependency name> ignore conditions` will show all of the ignore conditions of the specified dependency\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the PR or upgrade to it yourself)\n\n\n</details>\n\n> **Note**\n> Automatic rebases have been disabled on this pull request as it has been open for over 30 days.',
#     'created_at': '2023-11-22T15:03:43Z',
#     'updated_at': '2024-02-14T10:18:46Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': '4e26244d3c2c9290e74e2f0476649383cb8f0c0f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'darrelmiller',
#       'id': 447694,
#       'node_id': 'MDQ6VXNlcjQ0NzY5NA==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/447694?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/darrelmiller',
#       'html_url': 'https://github.com/darrelmiller',
#       'followers_url': 'https://api.github.com/users/darrelmiller/followers',
#       'following_url': 'https://api.github.com/users/darrelmiller/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/darrelmiller/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/darrelmiller/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/darrelmiller/subscriptions',
#       'organizations_url': 'https://api.github.com/users/darrelmiller/orgs',
#       'repos_url': 'https://api.github.com/users/darrelmiller/repos',
#       'events_url': 'https://api.github.com/users/darrelmiller/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/darrelmiller/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'zengin',
#       'id': 803311,
#       'node_id': 'MDQ6VXNlcjgwMzMxMQ==',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/803311?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/zengin',
#       'html_url': 'https://github.com/zengin',
#       'followers_url': 'https://api.github.com/users/zengin/followers',
#       'following_url': 'https://api.github.com/users/zengin/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/zengin/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/zengin/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/zengin/subscriptions',
#       'organizations_url': 'https://api.github.com/users/zengin/orgs',
#       'repos_url': 'https://api.github.com/users/zengin/repos',
#       'events_url': 'https://api.github.com/users/zengin/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/zengin/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'koros',
#       'id': 1716093,
#       'node_id': 'MDQ6VXNlcjE3MTYwOTM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1716093?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/koros',
#       'html_url': 'https://github.com/koros',
#       'followers_url': 'https://api.github.com/users/koros/followers',
#       'following_url': 'https://api.github.com/users/koros/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/koros/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/koros/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/koros/subscriptions',
#       'organizations_url': 'https://api.github.com/users/koros/orgs',
#       'repos_url': 'https://api.github.com/users/koros/repos',
#       'events_url': 'https://api.github.com/users/koros/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/koros/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'andrueastman',
#       'id': 6464005,
#       'node_id': 'MDQ6VXNlcjY0NjQwMDU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6464005?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/andrueastman',
#       'html_url': 'https://github.com/andrueastman',
#       'followers_url': 'https://api.github.com/users/andrueastman/followers',
#       'following_url': 'https://api.github.com/users/andrueastman/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/andrueastman/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/andrueastman/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/andrueastman/subscriptions',
#       'organizations_url': 'https://api.github.com/users/andrueastman/orgs',
#       'repos_url': 'https://api.github.com/users/andrueastman/repos',
#       'events_url': 'https://api.github.com/users/andrueastman/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/andrueastman/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'gavinbarron',
#       'id': 7122716,
#       'node_id': 'MDQ6VXNlcjcxMjI3MTY=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/7122716?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/gavinbarron',
#       'html_url': 'https://github.com/gavinbarron',
#       'followers_url': 'https://api.github.com/users/gavinbarron/followers',
#       'following_url': 'https://api.github.com/users/gavinbarron/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/gavinbarron/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/gavinbarron/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/gavinbarron/subscriptions',
#       'organizations_url': 'https://api.github.com/users/gavinbarron/orgs',
#       'repos_url': 'https://api.github.com/users/gavinbarron/repos',
#       'events_url': 'https://api.github.com/users/gavinbarron/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/gavinbarron/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'MIchaelMainer',
#       'id': 8527305,
#       'node_id': 'MDQ6VXNlcjg1MjczMDU=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/8527305?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/MIchaelMainer',
#       'html_url': 'https://github.com/MIchaelMainer',
#       'followers_url': 'https://api.github.com/users/MIchaelMainer/followers',
#       'following_url': 'https://api.github.com/users/MIchaelMainer/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/MIchaelMainer/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/MIchaelMainer/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/MIchaelMainer/subscriptions',
#       'organizations_url': 'https://api.github.com/users/MIchaelMainer/orgs',
#       'repos_url': 'https://api.github.com/users/MIchaelMainer/repos',
#       'events_url': 'https://api.github.com/users/MIchaelMainer/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/MIchaelMainer/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'ddyett',
#       'id': 20829981,
#       'node_id': 'MDQ6VXNlcjIwODI5OTgx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/20829981?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ddyett',
#       'html_url': 'https://github.com/ddyett',
#       'followers_url': 'https://api.github.com/users/ddyett/followers',
#       'following_url': 'https://api.github.com/users/ddyett/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ddyett/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ddyett/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ddyett/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ddyett/orgs',
#       'repos_url': 'https://api.github.com/users/ddyett/repos',
#       'events_url': 'https://api.github.com/users/ddyett/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ddyett/received_events',
#       'type': 'User',
#       'site_admin': False},
#      {'login': 'nikithauc',
#       'id': 23219007,
#       'node_id': 'MDQ6VXNlcjIzMjE5MDA3',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/23219007?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/nikithauc',
#       'html_url': 'https://github.com/nikithauc',
#       'followers_url': 'https://api.github.com/users/nikithauc/followers',
#       'following_url': 'https://api.github.com/users/nikithauc/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/nikithauc/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/nikithauc/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/nikithauc/subscriptions',
#       'organizations_url': 'https://api.github.com/users/nikithauc/orgs',
#       'repos_url': 'https://api.github.com/users/nikithauc/repos',
#       'events_url': 'https://api.github.com/users/nikithauc/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/nikithauc/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [{'id': 3955655810,
#       'node_id': 'LA_kwDOGhwMsM7rxoSC',
#       'url': 'https://api.github.com/repos/microsoft/kiota-typescript/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 3955655819,
#       'node_id': 'LA_kwDOGhwMsM7rxoSL',
#       'url': 'https://api.github.com/repos/microsoft/kiota-typescript/labels/javascript',
#       'name': 'javascript',
#       'color': '168700',
#       'default': False,
#       'description': 'Pull requests that update Javascript code'},
#      {'id': 5105969788,
#       'node_id': 'LA_kwDOGhwMsM8AAAABMFbqfA',
#       'url': 'https://api.github.com/repos/microsoft/kiota-typescript/labels/conflicting',
#       'name': 'conflicting',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/microsoft/kiota-typescript/pulls/964/commits',
#     'review_comments_url': 'https://api.github.com/repos/microsoft/kiota-typescript/pulls/964/comments',
#     'review_comment_url': 'https://api.github.com/repos/microsoft/kiota-typescript/pulls/comments{/number}',
# ...
#      'id': 140382483,
#      'node_id': 'U_kgDOCF4REw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/140382483?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/sg-acloset',
#      'html_url': 'https://github.com/sg-acloset',
#      'followers_url': 'https://api.github.com/users/sg-acloset/followers',
#      'following_url': 'https://api.github.com/users/sg-acloset/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/sg-acloset/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/sg-acloset/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/sg-acloset/subscriptions',
#      'organizations_url': 'https://api.github.com/users/sg-acloset/orgs',
#      'repos_url': 'https://api.github.com/users/sg-acloset/repos',
#      'events_url': 'https://api.github.com/users/sg-acloset/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/sg-acloset/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/sg-acloset/echo-swagger',
#     'description': 'echo middleware to automatically generate RESTful API documentation with Swagger 2.0.',
#     'fork': True,
#     'url': 'https://api.github.com/repos/sg-acloset/echo-swagger',
#     'forks_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/forks',
#     'keys_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/teams',
#     'hooks_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/hooks',
#     'issue_events_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/events',
#     'assignees_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/tags',
#     'blobs_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/languages',
#     'stargazers_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/stargazers',
#     'contributors_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/contributors',
#     'subscribers_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/subscribers',
#     'subscription_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/subscription',
#     'commits_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/merges',
#     'archive_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/downloads',
#     'issues_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/sg-acloset/echo-swagger/deployments',
#     'created_at': '2024-02-14T10:18:46Z',
#     'updated_at': '2024-02-14T10:18:46Z',
#     'pushed_at': '2024-01-02T17:04:17Z',
#     'git_url': 'git://github.com/sg-acloset/echo-swagger.git',
#     'ssh_url': 'git@github.com:sg-acloset/echo-swagger.git',
#     'clone_url': 'https://github.com/sg-acloset/echo-swagger.git',
#     'svn_url': 'https://github.com/sg-acloset/echo-swagger',
#     'homepage': '',
#     'size': 96,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'has_discussions': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'allow_forking': True,
#     'is_template': False,
#     'web_commit_signoff_required': False,
#     'topics': [],
#     'visibility': 'public',
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'main',
#     'public': True}},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z',
#   'org': {'id': 29616670,
#    'login': 'swaggo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/swaggo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29616670?'}},
#  {'id': '35665347947',
#   'type': 'IssuesEvent',
#   'actor': {'id': 136498486,
#    'login': 'workflow-bot-apheon[bot]',
#    'display_login': 'workflow-bot-apheon',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/workflow-bot-apheon[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/136498486?'},
#   'repo': {'id': 623540205,
#    'name': 'apheon-terra/01_k3s_ops',
#    'url': 'https://api.github.com/repos/apheon-terra/01_k3s_ops'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/apheon-terra/01_k3s_ops/issues/6124',
#     'repository_url': 'https://api.github.com/repos/apheon-terra/01_k3s_ops',
#     'labels_url': 'https://api.github.com/repos/apheon-terra/01_k3s_ops/issues/6124/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/apheon-terra/01_k3s_ops/issues/6124/comments',
#     'events_url': 'https://api.github.com/repos/apheon-terra/01_k3s_ops/issues/6124/events',
#     'html_url': 'https://github.com/apheon-terra/01_k3s_ops/issues/6124',
#     'id': 2133997434,
#     'node_id': 'I_kwDOJSp37c5_Mjd6',
#     'number': 6124,
#     'title': 'Renovate Dashboard 🤖',
#     'user': {'login': 'workflow-bot-apheon[bot]',
#      'id': 136498486,
#      'node_id': 'BOT_kgDOCCLNNg',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/68638661?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/workflow-bot-apheon%5Bbot%5D',
#      'html_url': 'https://github.com/apps/workflow-bot-apheon',
#      'followers_url': 'https://api.github.com/users/workflow-bot-apheon%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/workflow-bot-apheon%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/workflow-bot-apheon%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/workflow-bot-apheon%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/workflow-bot-apheon%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/workflow-bot-apheon%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/workflow-bot-apheon%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/workflow-bot-apheon%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/workflow-bot-apheon%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2024-02-14T10:18:45Z',
#     'updated_at': '2024-02-14T10:18:45Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': 'This issue lists Renovate updates and detected dependencies. Read the [Dependency Dashboard](https://docs.renovatebot.com/key-concepts/dashboard/) docs to learn more.\n\n## Repository problems\n\nRenovate tried to run on this repository, but found these problems.\n\n - WARN: Found renovate config warnings\n - WARN: Excess registryUrls found for datasource lookup - using first configured only\n - WARN: No docker auth found - returning\n - WARN: Package lookup failures\n - WARN: Error updating branch: update failure\n\n## Errored\n\nThese updates encountered an error and will be retried. Click on a checkbox below to force a retry now.\n\n - [ ] <!-- retry-branch=renovate/alert-1.x -->chore(deps): update alert to notification.toolkit.fluxcd.io/v1beta3\n - [ ] <!-- retry-branch=renovate/helmrelease-2.x -->chore(deps): update helmrelease to helm.toolkit.fluxcd.io/v2beta2\n - [ ] <!-- retry-branch=renovate/kustomization-1.x -->chore(deps): update kustomization to kustomize.toolkit.fluxcd.io/v1\n - [ ] <!-- retry-branch=renovate/provider-1.x -->chore(deps): update provider to notification.toolkit.fluxcd.io/v1beta3\n - [ ] <!-- retry-branch=renovate/receiver-1.x -->chore(deps): update receiver to notification.toolkit.fluxcd.io/v1\n - [ ] <!-- retry-branch=renovate/xanmanning.k3s-3.x -->chore(deps): update xanmanning.k3s to v3.4.4\n - [ ] <!-- retry-branch=renovate/community.sops-1.x -->fix(ansible): update community.sops to 1.6.7\n - [ ] <!-- retry-branch=renovate/kubernetes.core-2.x -->fix(ansible): update kubernetes.core to 2.4.1\n - [ ] <!-- retry-branch=renovate/docker.io-jmalloc-echo-server-0.x -->fix(container): update image docker.io/jmalloc/echo-server to v0.3.6\n - [ ] <!-- retry-branch=renovate/docker.io-remirigal-plex-auto-languages-1.x -->fix(container): update image docker.io/remirigal/plex-auto-languages to v1.2.3\n - [ ] <!-- retry-branch=renovate/ghcr.io-foxcpp-maddy-0.x -->fix(container): update image ghcr.io/foxcpp/maddy to v0.7.1\n - [ ] <!-- retry-branch=renovate/ghcr.io-onedr0p-jellyfin-10.x -->fix(container): update image ghcr.io/onedr0p/jellyfin to v10.8.11\n - [ ] <!-- retry-branch=renovate/ghcr.io-onedr0p-sonarr-develop-4.x -->fix(container): update image ghcr.io/onedr0p/sonarr-develop to v4.0.1.1131\n - [ ] <!-- retry-branch=renovate/ghcr.io-sct-overseerr-1.x -->fix(container): update image ghcr.io/sct/overseerr to v1.33.2\n - [ ] <!-- retry-branch=renovate/ghcr.io-shlinkio-shlink-web-client-3.x -->fix(container): update image ghcr.io/shlinkio/shlink-web-client to v3.10.2\n - [ ] <!-- retry-branch=renovate/public.ecr.aws-docker-library-couchdb-3.x -->fix(container): update image public.ecr.aws/docker/library/couchdb to v3.3.3\n - [ ] <!-- retry-branch=renovate/public.ecr.aws-docker-library-eclipse-mosquitto-2.x -->fix(container): update image public.ecr.aws/docker/library/eclipse-mosquitto to v2.0.18\n - [ ] <!-- retry-branch=renovate/registry.k8s.io-git-sync-git-sync-3.x -->fix(container): update image registry.k8s.io/git-sync/git-sync to v3.6.9\n - [ ] <!-- retry-branch=renovate/vectorim-element-web-1.x -->fix(container): update image vectorim/element-web to v1.11.58\n - [ ] <!-- retry-branch=renovate/endbug-label-sync-2.x -->fix(github-action): update endbug/label-sync action to v2.3.3\n - [ ] <!-- retry-branch=renovate/ghcr.io-bjw-s-mdbook-0.x -->fix(github-action): update image ghcr.io/bjw-s/mdbook to v0.4.37\n - [ ] <!-- retry-branch=renovate/renovatebot-github-action-38.x -->fix(github-action): update renovatebot/github-action action to v38.1.13\n - [ ] <!-- retry-branch=renovate/actions-runner-controller-0.x -->fix(helm): update chart actions-runner-controller to 0.23.7\n - [ ] <!-- retry-branch=renovate/nextcloud-3.x -->fix(helm): update chart nextcloud to 3.5.22\n - [ ] <!-- retry-branch=renovate/reloader-1.x -->fix(helm): update chart reloader to 1.0.67\n - [ ] <!-- retry-branch=renovate/weave-gitops-4.x -->fix(helm): update chart weave-gitops to 4.0.36\n - [ ] <!-- retry-branch=renova ...
#     'reactions': {'url': 'https://api.github.com/repos/apheon-terra/01_k3s_ops/issues/6124/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/apheon-terra/01_k3s_ops/issues/6124/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z'},
#  {'id': '35665347929',
#   'type': 'PublicEvent',
#   'actor': {'id': 81850683,
#    'login': 'alve-coderx',
#    'display_login': 'alve-coderx',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alve-coderx',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/81850683?'},
#   'repo': {'id': 756907273,
#    'name': 'alve-coderx/Solona-SPL',
#    'url': 'https://api.github.com/repos/alve-coderx/Solona-SPL'},
#   'payload': {},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z'},
#  {'id': '35665347836',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 661535205,
#    'name': 'thedoggybrad/easylist-mirror',
#    'url': 'https://api.github.com/repos/thedoggybrad/easylist-mirror'},
#   'payload': {'repository_id': 661535205,
#    'push_id': 17085918913,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '2f9b7d52ba2b4d7afd2c6c9edb060b916cafc20d',
#    'before': '7e98414de1be5e283ff4c17ea0627de5b8a6ad64',
#    'commits': [{'sha': '2f9b7d52ba2b4d7afd2c6c9edb060b916cafc20d',
#      'author': {'email': '142152315+syncbot-easylistmirror@users.noreply.github.com',
#       'name': 'syncbot-easylistmirror'},
#      'message': 'Sync NordicFiltersABP-Inclusion.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/thedoggybrad/easylist-mirror/commits/2f9b7d52ba2b4d7afd2c6c9edb060b916cafc20d'}]},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z'},
#  {'id': '35665347830',
#   'type': 'CreateEvent',
#   'actor': {'id': 102787579,
#    'login': 'Kalyani-Naidu',
#    'display_login': 'Kalyani-Naidu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kalyani-Naidu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/102787579?'},
#   'repo': {'id': 757352822,
#    'name': 'Kalyani-Naidu/EmployeeAPI',
#    'url': 'https://api.github.com/repos/Kalyani-Naidu/EmployeeAPI'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z'},
#  {'id': '35665347872',
#   'type': 'WatchEvent',
#   'actor': {'id': 6384068,
#    'login': 'xfloor',
#    'display_login': 'xfloor',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/xfloor',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6384068?'},
#   'repo': {'id': 225260962,
#    'name': 'udecode/plate',
#    'url': 'https://api.github.com/repos/udecode/plate'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-02-14T10:18:47Z',
#   'org': {'id': 66228141,
#    'login': 'udecode',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/udecode',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66228141?'}}]

# %%
pd.DataFrame(response.json())
# Out:
#              id                    type  \
# 0   35665348045               PushEvent
# 1   35665348017               PushEvent
# 2   35665348090               PushEvent
# 3   35665348042               PushEvent
# 4   35665348075             CreateEvent
# 5   35665348065               PushEvent
# 6   35665348086             CreateEvent
# 7   35665348018  PullRequestReviewEvent
# 8   35665348059               PushEvent
# 9   35665348034               PushEvent
# 10  35665348004  PullRequestReviewEvent
# 11  35665348081             CreateEvent
# 12  35665348071               PushEvent
# 13  35665348046               ForkEvent
# 14  35665348008        PullRequestEvent
# 15  35665348084             CreateEvent
# 16  35665347931               PushEvent
# 17  35665347919               PushEvent
# 18  35665347992             CreateEvent
# 19  35665347920               PushEvent
# 20  35665347973        PullRequestEvent
# 21  35665347964             CreateEvent
# 22  35665347924               PushEvent
# 23  35665347930               PushEvent
# 24  35665347941               ForkEvent
# 25  35665347947             IssuesEvent
# 26  35665347929             PublicEvent
# 27  35665347836               PushEvent
# 28  35665347830             CreateEvent
# 29  35665347872              WatchEvent
#
#                                                 actor  \
# 0   {'id': 66976984, 'login': 'NilleSnille', 'disp...
# 1   {'id': 106912404, 'login': 'DimitrisDavidGerok...
# 2   {'id': 8376748, 'login': 'Arjoo', 'display_log...
# 3   {'id': 157866528, 'login': 'ttgds3asu', 'displ...
# 4   {'id': 105236673, 'login': 'scalr-autotester8'...
# 5   {'id': 137176738, 'login': 'ashish-egov', 'dis...
# 6   {'id': 148450933, 'login': 'seankennelly', 'di...
# 7   {'id': 31882754, 'login': 'Jihed525', 'display...
# 8   {'id': 157866528, 'login': 'ttgds3asu', 'displ...
# 9   {'id': 11218275, 'login': 'tmmlaarhoven', 'dis...
# 10  {'id': 7905502, 'login': 'baywet', 'display_lo...
# 11  {'id': 19403799, 'login': 'andrewtarzia', 'dis...
# 12  {'id': 155029846, 'login': 'vismerka', 'displa...
# 13  {'id': 146932071, 'login': 'Mustafa-Bakri136',...
# 14  {'id': 39814207, 'login': 'pull[bot]', 'displa...
# 15  {'id': 46999366, 'login': 'Louciole', 'display...
# 16  {'id': 41898282, 'login': 'github-actions[bot]...
# 17  {'id': 155029846, 'login': 'vismerka', 'displa...
# 18  {'id': 1580956, 'login': 'chenrui333', 'displa...
# 19  {'id': 155487937, 'login': 'vluis566', 'displa...
# 20  {'id': 29894366, 'login': 'julienrbrt', 'displ...
# 21  {'id': 10810283, 'login': 'direwolf-github', '...
# 22  {'id': 157866528, 'login': 'ttgds3asu', 'displ...
# 23  {'id': 157866528, 'login': 'ttgds3asu', 'displ...
# 24  {'id': 140382483, 'login': 'sg-acloset', 'disp...
# 25  {'id': 136498486, 'login': 'workflow-bot-apheo...
# 26  {'id': 81850683, 'login': 'alve-coderx', 'disp...
# 27  {'id': 41898282, 'login': 'github-actions[bot]...
# 28  {'id': 102787579, 'login': 'Kalyani-Naidu', 'd...
# 29  {'id': 6384068, 'login': 'xfloor', 'display_lo...
#
#                                                  repo  \
# 0   {'id': 757153299, 'name': 'NilleSnille/collect...
# 1   {'id': 755607266, 'name': 'DimitrisDavidGeroko...
# 2   {'id': 757005237, 'name': 'Arjoo/spring-boot-m...
# 3   {'id': 752900181, 'name': 'udnsenattinndgi/rep...
# 4   {'id': 492878833, 'name': 'scalr-automation/te...
# 5   {'id': 690467910, 'name': 'egovernments/DIGIT-...
# 6   {'id': 757351581, 'name': 'seankennelly/kreati...
# 7   {'id': 205883930, 'name': 'exoplatform/news', ...
# 8   {'id': 751736860, 'name': '235wgdf/repo4', 'ur...
# 9   {'id': 702186019, 'name': 'tmmlaarhoven/liches...
# 10  {'id': 438045872, 'name': 'microsoft/kiota-typ...
# 11  {'id': 540097715, 'name': 'andrewtarzia/CGExpl...
# 12  {'id': 756518553, 'name': 'vismerka/porject1',...
# 13  {'id': 757152290, 'name': 'testsolutionx/proje...
# 14  {'id': 596046086, 'name': 'buiawpkgew1/github-...
# 15  {'id': 757352828, 'name': 'Louciole/ada', 'url...
# 16  {'id': 729458283, 'name': 'The-Code-Monkey/lex...
# 17  {'id': 756530228, 'name': 'vismerka/project9',...
# 18  {'id': 742992499, 'name': 'chenrui333/homebrew...
# 19  {'id': 757158212, 'name': 'vluis566/rp-1', 'ur...
# 20  {'id': 51193526, 'name': 'cosmos/cosmos-sdk', ...
# 21  {'id': 757352825, 'name': 'direwolf-github/eph...
# 22  {'id': 751736690, 'name': '235wgdf/repo1', 'ur...
# 23  {'id': 752900221, 'name': 'udnsenattinndgi/rep...
# 24  {'id': 95058999, 'name': 'swaggo/echo-swagger'...
# 25  {'id': 623540205, 'name': 'apheon-terra/01_k3s...
# 26  {'id': 756907273, 'name': 'alve-coderx/Solona-...
# 27  {'id': 661535205, 'name': 'thedoggybrad/easyli...
# 28  {'id': 757352822, 'name': 'Kalyani-Naidu/Emplo...
# 29  {'id': 225260962, 'name': 'udecode/plate', 'ur...
#
#                                               payload  public  \
# 0   {'repository_id': 757153299, 'push_id': 170859...    True
# 1   {'repository_id': 755607266, 'push_id': 170859...    True
# 2   {'repository_id': 757005237, 'push_id': 170859...    True
# 3   {'repository_id': 752900181, 'push_id': 170859...    True
# 4   {'ref': 'abase-operation-feeling', 'ref_type':...    True
# 5   {'repository_id': 690467910, 'push_id': 170859...    True
# 6   {'ref': 'sean_branch', 'ref_type': 'branch', '...    True
# 7   {'action': 'created', 'review': {'id': 1879884...    True
# 8   {'repository_id': 751736860, 'push_id': 170859...    True
# 9   {'repository_id': 702186019, 'push_id': 170859...    True
# 10  {'action': 'created', 'review': {'id': 1879884...    True
# 11  {'ref': 'refactoring_and_docs', 'ref_type': 'b...    True
# 12  {'repository_id': 756518553, 'push_id': 170859...    True
# 13  {'forkee': {'id': 757352829, 'node_id': 'R_kgD...    True
# 14  {'action': 'opened', 'number': 99, 'pull_reque...    True
# 15  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 16  {'repository_id': 729458283, 'push_id': 170859...    True
# 17  {'repository_id': 756530228, 'push_id': 170859...    True
# 18  {'ref': 'bump-workspace-one-intelligent-hub-24...    True
# 19  {'repository_id': 757158212, 'push_id': 170859...    True
# 20  {'action': 'closed', 'number': 19425, 'pull_re...    True
# 21  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 22  {'repository_id': 751736690, 'push_id': 170859...    True
# 23  {'repository_id': 752900221, 'push_id': 170859...    True
# 24  {'forkee': {'id': 757352826, 'node_id': 'R_kgD...    True
# 25  {'action': 'opened', 'issue': {'url': 'https:/...    True
# 26                                                 {}    True
# 27  {'repository_id': 661535205, 'push_id': 170859...    True
# 28  {'ref': None, 'ref_type': 'repository', 'maste...    True
# 29                              {'action': 'started'}    True
#
#               created_at                                                org
# 0   2024-02-14T10:18:47Z                                                NaN
# 1   2024-02-14T10:18:47Z                                                NaN
# 2   2024-02-14T10:18:47Z                                                NaN
# 3   2024-02-14T10:18:47Z  {'id': 158984731, 'login': 'udnsenattinndgi', ...
# 4   2024-02-14T10:18:47Z  {'id': 103308247, 'login': 'scalr-automation',...
# 5   2024-02-14T10:18:47Z  {'id': 6940476, 'login': 'egovernments', 'grav...
# 6   2024-02-14T10:18:47Z                                                NaN
# 7   2024-02-14T10:18:47Z  {'id': 259384, 'login': 'exoplatform', 'gravat...
# 8   2024-02-14T10:18:47Z  {'id': 158556802, 'login': '235wgdf', 'gravata...
# 9   2024-02-14T10:18:47Z                                                NaN
# 10  2024-02-14T10:18:47Z  {'id': 6154722, 'login': 'microsoft', 'gravata...
# 11  2024-02-14T10:18:47Z                                                NaN
# 12  2024-02-14T10:18:47Z                                                NaN
# 13  2024-02-14T10:18:47Z  {'id': 159965194, 'login': 'testsolutionx', 'g...
# 14  2024-02-14T10:18:47Z                                                NaN
# 15  2024-02-14T10:18:47Z                                                NaN
# 16  2024-02-14T10:18:47Z                                                NaN
# 17  2024-02-14T10:18:47Z                                                NaN
# 18  2024-02-14T10:18:47Z                                                NaN
# 19  2024-02-14T10:18:47Z                                                NaN
# 20  2024-02-14T10:18:47Z  {'id': 228843, 'login': 'cosmos', 'gravatar_id...
# 21  2024-02-14T10:18:47Z                                                NaN
# 22  2024-02-14T10:18:47Z  {'id': 158556802, 'login': '235wgdf', 'gravata...
# 23  2024-02-14T10:18:47Z  {'id': 158984731, 'login': 'udnsenattinndgi', ...
# 24  2024-02-14T10:18:47Z  {'id': 29616670, 'login': 'swaggo', 'gravatar_...
# 25  2024-02-14T10:18:47Z                                                NaN
# 26  2024-02-14T10:18:47Z                                                NaN
# 27  2024-02-14T10:18:47Z                                                NaN
# 28  2024-02-14T10:18:47Z                                                NaN
# 29  2024-02-14T10:18:47Z  {'id': 66228141, 'login': 'udecode', 'gravatar...

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code

# %%
response.url

# %%
response.json()

# %%
iss = response.json()

# %%
# Challenge: find longitude of ISS 

iss["iss_position"]["longitude"]
