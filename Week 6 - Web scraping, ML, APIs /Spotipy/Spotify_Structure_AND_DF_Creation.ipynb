# %% [markdown]
# # Installing Spotipy

# %%
## !conda install -c conda-forge spotipy

# %% [markdown]
# ## Loading credentials from the config file

# %%
import config

# %%
## Starting with Spotify API

# %%
import spotipy
import pandas as pd
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))



results = sp.search(q="daddy cool",limit=5,market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1KQUrny9y5zGpktF6hAGd4'},
#      'href': 'https://api.spotify.com/v1/albums/1KQUrny9y5zGpktF6hAGd4',
#      'id': '1KQUrny9y5zGpktF6hAGd4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Take The Heat Off Me',
#      'release_date': '1976',
#      'release_date_precision': 'year',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1KQUrny9y5zGpktF6hAGd4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 208600,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEC737600002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3WMbD1OyfKuwWDWMNbPQ4g'},
#     'href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g',
#     'id': '3WMbD1OyfKuwWDWMNbPQ4g',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/03e2b60a6a5c101dc0d41866f2e079d8de4a663b?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/155cebHEGGBqYJAXKWJw6D'},
#      'href': 'https://api.spotify.com/v1/albums/155cebHEGGBqYJAXKWJw6D',
#      'id': '155cebHEGGBqYJAXKWJw6D',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d792d961638fd28f8d281947',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d792d961638fd28f8d281947',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d792d961638fd28f8d281947',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Daddy Cool',
#      'release_date': '1994-03-14',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:155cebHEGGBqYJAXKWJw6D'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 220666,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED160000010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5lWSa1rmuSL6OBPOnkAqoa'},
#     'href': 'https://api.spotify.com/v1/tracks/5lWSa1rmuSL6OBPOnkAqoa',
#     'id': '5lWSa1rmuSL6OBPOnkAqoa',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Rasputin',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/99129129d46b1937b0897e38d561110e1cd319f4?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5lWSa1rmuSL6OBPOnkAqoa'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#        'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#        'id': '12A83CWwFiyXy90ScLWPIe',
#        'name': 'LIZOT',
#        'type': 'artist',
#        'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7fXtm0TpLRIJhxobKDjxRp'},
#      'href': 'https://api.spotify.com/v1/albums/7fXtm0TpLRIJhxobKDjxRp',
#      'id': '7fXtm0TpLRIJhxobKDjxRp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273da8ce498bc7d441e6d841d25',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02da8ce498bc7d441e6d841d25',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851da8ce498bc7d441e6d841d25',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Daddy Cool',
#      'release_date': '2021-12-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7fXtm0TpLRIJhxobKDjxRp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#       'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#       'id': '12A83CWwFiyXy90ScLWPIe',
#       'name': 'LIZOT',
#       'type': 'artist',
#       'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 154858,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEE862102870'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/50rcUhHimavzT1qq6QrgMG'},
#     'href': 'https://api.spotify.com/v1/tracks/50rcUhHimavzT1qq6QrgMG',
#     'id': '50rcUhHimavzT1qq6QrgMG',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/857d68f8f69125e431cea3e5e89e653440600762?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:50rcUhHimavzT1qq6QrgMG'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#        'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#        'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#        'name': 'Baccara',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5e6VPOPLw5cSXsVMvQEioq'},
#      'href': 'https://api.spotify.com/v1/albums/5e6VPOPLw5cSXsVMvQEioq',
#      'id': '5e6VPOPLw5cSXsVMvQEioq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f9742033ffb15f5413898ef9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f9742033ffb15f5413898ef9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f9742033ffb15f5413898ef9',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'The Collection & Tracklisting',
#      'release_date': '1998',
#      'release_date_precision': 'year',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:5e6VPOPLw5cSXsVMvQEioq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#       'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#       'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#       'name': 'Baccara',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#     'disc_number': 1,
#     'duration_ms': 273866,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEC760000065'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2LScqpywMqGcnum6nNaxXX'},
#     'href': 'https://api.spotify.com/v1/tracks/2LScqpywMqGcnum6nNaxXX',
#     'id': '2LScqpywMqGcnum6nNaxXX',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Yes Sir, I Can Boogie',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/704fbc9b86f59da239d2de11d6d5baf808596856?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:2LScqpywMqGcnum6nNaxXX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7kTsa1wUFrahJJf1cJEOpZ'},
#      'href': 'https://api.spotify.com/v1/albums/7kTsa1wUFrahJJf1cJEOpZ',
#      'id': '7kTsa1wUFrahJJf1cJEOpZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27362c995dbce6d7ffa4c097475',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0262c995dbce6d7ffa4c097475',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485162c995dbce6d7ffa4c097475',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Covers',
#      'release_date': '2003-03-24',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:7kTsa1wUFrahJJf1cJEOpZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#       'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#       'id': '6RZUqkomCmb8zCRqc9eznB',
#       'name': 'Placebo',
#       'type': 'artist',
#       'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#     'disc_number': 1,
#     'duration_ms': 201706,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAAA0201215'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6blKbRwYDoXl5fFvQY2U75'},
#     'href': 'https://api.spotify.com/v1/tracks/6blKbRwYDoXl5fFvQY2U75',
#     'id': '6blKbRwYDoXl5fFvQY2U75',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4af3ad78f847b23200036e9cee4d5b06868aea6b?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6blKbRwYDoXl5fFvQY2U75'}],
#   'limit': 5,
#   'next': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=5&limit=5',
#   'offset': 0,
#   'previous': None,
#   'total': 825}}

# %%
import pprint

# %%
pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=0&limit=5',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                               'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                               'id': '54R6Y0I7jGUCveDTtI21nb',
#                                               'name': 'Boney M.',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/1KQUrny9y5zGpktF6hAGd4'},
#                                  'href': 'https://api.spotify.com/v1/albums/1KQUrny9y5zGpktF6hAGd4',
#                                  'id': '1KQUrny9y5zGpktF6hAGd4',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Take The Heat Off Me',
#                                  'release_date': '1976',
#                                  'release_date_precision': 'year',
#                                  'total_tracks': 10,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:1KQUrny9y5zGpktF6hAGd4'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                     'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                     'id': '54R6Y0I7jGUCveDTtI21nb',
#                                     'name': 'Boney M.',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                        'disc_number': 1,
#                        'duration_ms': 208600,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'DEC737600002'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/3WMbD1OyfKuwWDWMNbPQ4g'},
#                        'href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g',
#                        'id': '3WMbD1OyfKuwWDWMNbPQ4g',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Daddy Cool',
#                        'popularity': 77,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/03e2b60a6a5c101dc0d41866f2e079d8de4a663b?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'},
#                       {'album': {'album_type': 'compilation',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                               'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                               'id': '54R6Y0I7jGUCveDTtI21nb',
#                                               'name': 'Boney M.',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/155cebHEGGBqYJAXKWJw6D'},
#                                  'href': 'https://api.spotify.com/v1/albums/155cebHEGGBqYJAXKWJw6D',
#                                  'id': '155cebHEGGBqYJAXKWJw6D',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273d792d961638fd28f8d281947',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02d792d961638fd28f8d281947',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851d792d961638fd28f8d281947',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Daddy Cool',
#                                  'release_date': '1994-03-14',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 16,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:155cebHEGGBqYJAXKWJw6D'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                     'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                     'id': '54R6Y0I7jGUCveDTtI21nb',
#                                     'name': 'Boney M.',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                        'disc_number': 1,
#                        'duration_ms': 220666,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'DED160000010'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/5lWSa1rmuSL6OBPOnkAqoa'},
#                        'href': 'https://api.spotify.com/v1/tracks/5lWSa1rmuSL6OBPOnkAqoa',
#                        'id': '5lWSa1rmuSL6OBPOnkAqoa',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Rasputin',
#                        'popularity': 72,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/99129129d46b1937b0897e38d561110e1cd319f4?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                        'track_number': 3,
#                        'type': 'track',
#                        'uri': 'spotify:track:5lWSa1rmuSL6OBPOnkAqoa'},
#                       {'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#                                               'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#                                               'id': '12A83CWwFiyXy90ScLWPIe',
#                                               'name': 'LIZOT',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#                                              {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                               'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                               'id': '54R6Y0I7jGUCveDTtI21nb',
#                                               'name': 'Boney M.',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/7fXtm0TpLRIJhxobKDjxRp'},
#                                  'href': 'https://api.spotify.com/v1/albums/7fXtm0TpLRIJhxobKDjxRp',
#                                  'id': '7fXtm0TpLRIJhxobKDjxRp',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273da8ce498bc7d441e6d841d25',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02da8ce498bc7d441e6d841d25',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851da8ce498bc7d441e6d841d25',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Daddy Cool',
#                                  'release_date': '2021-12-03',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 1,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:7fXtm0TpLRIJhxobKDjxRp'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#                                     'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#                                     'id': '12A83CWwFiyXy90ScLWPIe',
#                                     'name': 'LIZOT',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#                                     'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#                                     'id': '54R6Y0I7jGUCveDTtI21nb',
#                                     'name': 'Boney M.',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#                        'disc_number': 1,
#                        'duration_ms': 154858,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'DEE862102870'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/50rcUhHimavzT1qq6QrgMG'},
#                        'href': 'https://api.spotify.com/v1/tracks/50rcUhHimavzT1qq6QrgMG',
#                        'id': '50rcUhHimavzT1qq6QrgMG',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Daddy Cool',
#                        'popularity': 59,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/857d68f8f69125e431cea3e5e89e653440600762?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                        'track_number': 1,
#                        'type': 'track',
#                        'uri': 'spotify:track:50rcUhHimavzT1qq6QrgMG'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#                                               'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#                                               'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#                                               'name': 'Baccara',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/5e6VPOPLw5cSXsVMvQEioq'},
#                                  'href': 'https://api.spotify.com/v1/albums/5e6VPOPLw5cSXsVMvQEioq',
#                                  'id': '5e6VPOPLw5cSXsVMvQEioq',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273f9742033ffb15f5413898ef9',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02f9742033ffb15f5413898ef9',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851f9742033ffb15f5413898ef9',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'The Collection & Tracklisting',
#                                  'release_date': '1998',
#                                  'release_date_precision': 'year',
#                                  'total_tracks': 19,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:5e6VPOPLw5cSXsVMvQEioq'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#                                     'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#                                     'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#                                     'name': 'Baccara',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#                        'disc_number': 1,
#                        'duration_ms': 273866,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'DEC760000065'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/2LScqpywMqGcnum6nNaxXX'},
#                        'href': 'https://api.spotify.com/v1/tracks/2LScqpywMqGcnum6nNaxXX',
#                        'id': '2LScqpywMqGcnum6nNaxXX',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Yes Sir, I Can Boogie',
#                        'popularity': 65,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/704fbc9b86f59da239d2de11d6d5baf808596856?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                        'track_number': 6,
#                        'type': 'track',
#                        'uri': 'spotify:track:2LScqpywMqGcnum6nNaxXX'},
#                       {'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#                                               'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#                                               'id': '6RZUqkomCmb8zCRqc9eznB',
#                                               'name': 'Placebo',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/7kTsa1wUFrahJJf1cJEOpZ'},
#                                  'href': 'https://api.spotify.com/v1/albums/7kTsa1wUFrahJJf1cJEOpZ',
#                                  'id': '7kTsa1wUFrahJJf1cJEOpZ',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b27362c995dbce6d7ffa4c097475',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e0262c995dbce6d7ffa4c097475',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000485162c995dbce6d7ffa4c097475',
#                                              'width': 64}],
#                                  'is_playable': True,
#                                  'name': 'Covers',
#                                  'release_date': '2003-03-24',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 10,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:7kTsa1wUFrahJJf1cJEOpZ'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#                                     'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#                                     'id': '6RZUqkomCmb8zCRqc9eznB',
#                                     'name': 'Placebo',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#                        'disc_number': 1,
#                        'duration_ms': 201706,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'GBAAA0201215'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6blKbRwYDoXl5fFvQY2U75'},
#                        'href': 'https://api.spotify.com/v1/tracks/6blKbRwYDoXl5fFvQY2U75',
#                        'id': '6blKbRwYDoXl5fFvQY2U75',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Daddy Cool',
#                        'popularity': 47,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/4af3ad78f847b23200036e9cee4d5b06868aea6b?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                        'track_number': 9,
#                        'type': 'track',
#                        'uri': 'spotify:track:6blKbRwYDoXl5fFvQY2U75'}],
#             'limit': 5,
#             'next': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=5&limit=5',
#             'offset': 0,
#             'previous': None,
#             'total': 825}}

# %%
pprint.pprint(results["tracks"]["items"][0]["id"])
# Out:
# '3WMbD1OyfKuwWDWMNbPQ4g'

# %% [markdown]
# # Understanding the json

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=0&limit=5
# The song's info is contained in:  [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1KQUrny9y5zGpktF6hAGd4'}, 'href': 'https://api.spotify.com/v1/albums/1KQUrny9y5zGpktF6hAGd4', 'id': '1KQUrny9y5zGpktF6hAGd4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691', 'width': 64}], 'is_playable': True, 'name': 'Take The Heat Off Me', 'release_date': '1976', 'release_date_precision': 'year', 'total_tracks': 10, 'type': 'album', 'uri': 'spotify:album:1KQUrny9y5zGpktF6hAGd4'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'disc_number': 1, 'duration_ms': 208600, 'explicit': False, 'external_ids': {'isrc': 'DEC737600002'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/3WMbD1OyfKuwWDWMNbPQ4g'}, 'href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g', 'id': '3WMbD1OyfKuwWDWMNbPQ4g', 'is_local': False, 'is_playable': True, 'name': 'Daddy Cool', 'popularity': 77, 'preview_url': 'https://p.scdn.co/mp3-preview/03e2b60a6a5c101dc0d41866f2e079d8de4a663b?cid=bda81a37da0a4c3397c9dd7cd2949b4d', 'track_number': 1, 'type': 'track', 'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'}, {'album': {'album_type': 'compilation', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/155cebHEGGBqYJAXKWJw6D'}, 'href': 'https://api.spotify.com/v1/albums/155cebHEGGBqYJAXKWJw6D', 'id': '155cebHEGGBqYJAXKWJw6D', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273d792d961638fd28f8d281947', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02d792d961638fd28f8d281947', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851d792d961638fd28f8d281947', 'width': 64}], 'is_playable': True, 'name': 'Daddy Cool', 'release_date': '1994-03-14', 'release_date_precision': 'day', 'total_tracks': 16, 'type': 'album', 'uri': 'spotify:album:155cebHEGGBqYJAXKWJw6D'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'}, 'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb', 'id': '54R6Y0I7jGUCveDTtI21nb', 'name': 'Boney M.', 'type': 'artist', 'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}], 'disc_number': 1, 'duration_ms': 220666, 'explicit': False, 'external_ids': {'isrc': 'DED160000010'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/5lWSa1rmuSL6OBPOnkAqoa'}, 'href': 'https://api.spotify.com/v1/tracks/5lWSa1rmuSL6OBPOnkAqoa', 'id': '5lWSa1rmuSL6OBPOnkAqoa', 'is_local': False, 'is_playable': True, 'name': 'Rasputin', 'popularity': 72, 'preview_url': 'https://p.scdn.co/mp3-preview/99129129d46b1937b0897e38d561110e1cd319f4?cid=bda81a37da0a4c3397c9dd7cd2949b4d', 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:5lWSa1rmuSL6OBPOnkAqoa'}, {'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'}, 'href': 'https://api.s ...
# The limit of the query we've made is:  5
# The next page if any:  https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=5&limit=5
# The starting webpage:  0
# Starting webpage:  None
# Total number of results:  825

# %% [markdown]
# ## Other Info

# %%
results["tracks"]["items"][0]["artists"] # Track artists
results["tracks"]["items"][0]["id"] # Track ID
results["tracks"]["items"][0]["name"] # Track name
results["tracks"]["items"][0]["popularity"] # Popularity index
results["tracks"]["items"][0]["uri"] # Basically ID
# Out:
# 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'

# %%
len(results['tracks']["items"])
# Out:
# 5

# %% [markdown]
# ## Getting the track_id

# %%
track_id=results["tracks"]["items"][0]["id"]
track_id
# Out:
# '3WMbD1OyfKuwWDWMNbPQ4g'

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item["id"]))
# Out:
# The name of song is: 'Daddy Cool' and the id is: 3WMbD1OyfKuwWDWMNbPQ4g
# The name of song is: 'Rasputin' and the id is: 5lWSa1rmuSL6OBPOnkAqoa
# The name of song is: 'Daddy Cool' and the id is: 50rcUhHimavzT1qq6QrgMG
# The name of song is: 'Yes Sir, I Can Boogie' and the id is: 2LScqpywMqGcnum6nNaxXX
# The name of song is: 'Daddy Cool' and the id is: 6blKbRwYDoXl5fFvQY2U75

# %% [markdown]
# ## Embeded track player

# %%
from IPython.display import IFrame

track_id = '3WMbD1OyfKuwWDWMNbPQ4g'
#track_id= 'spotify:track:3hgl7EQwTutSm6PESsB7gZ'
IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3WMbD1OyfKuwWDWMNbPQ4g?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song('3WMbD1OyfKuwWDWMNbPQ4g')
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/3WMbD1OyfKuwWDWMNbPQ4g?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
user_input = input("please enter your song: ")
user_json = sp.search(q=user_input, limit=5, market="GB")
user_id = user_json["tracks"]["items"][0]["id"]
play_song(user_id)
# Out:
# please enter your song:  take a look around
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/2avKuMN2QXkaG9vvHa2JLt?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Getting the Audio features of a song

# %%
id_ = results["tracks"]["items"][0]["id"]

# %%
sp.audio_features(id_ )
# Out:
# [{'danceability': 0.763,
#   'energy': 0.777,
#   'key': 5,
#   'loudness': -6.932,
#   'mode': 0,
#   'speechiness': 0.0364,
#   'acousticness': 0.281,
#   'instrumentalness': 0.79,
#   'liveness': 0.134,
#   'valence': 0.929,
#   'tempo': 124.431,
#   'type': 'audio_features',
#   'id': '3WMbD1OyfKuwWDWMNbPQ4g',
#   'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g',
#   'track_href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3WMbD1OyfKuwWDWMNbPQ4g',
#   'duration_ms': 208600,
#   'time_signature': 4}]

# %%
play_song('2TVxnKdb3tqe1nhQWwwZCO')
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/2TVxnKdb3tqe1nhQWwwZCO?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
sp.audio_features("3WMbD1OyfKuwWDWMNbPQ4g")
# Out:
# [{'danceability': 0.763,
#   'energy': 0.777,
#   'key': 5,
#   'loudness': -6.932,
#   'mode': 0,
#   'speechiness': 0.0364,
#   'acousticness': 0.281,
#   'instrumentalness': 0.79,
#   'liveness': 0.134,
#   'valence': 0.929,
#   'tempo': 124.431,
#   'type': 'audio_features',
#   'id': '3WMbD1OyfKuwWDWMNbPQ4g',
#   'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g',
#   'track_href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3WMbD1OyfKuwWDWMNbPQ4g',
#   'duration_ms': 208600,
#   'time_signature': 4}]

# %% [markdown]
# ## Building a Data frame of audio features

# %%
sp.audio_features(results["tracks"]["items"][0]["uri"])
# Out:
# [{'danceability': 0.763,
#   'energy': 0.777,
#   'key': 5,
#   'loudness': -6.932,
#   'mode': 0,
#   'speechiness': 0.0364,
#   'acousticness': 0.281,
#   'instrumentalness': 0.79,
#   'liveness': 0.134,
#   'valence': 0.929,
#   'tempo': 124.431,
#   'type': 'audio_features',
#   'id': '3WMbD1OyfKuwWDWMNbPQ4g',
#   'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g',
#   'track_href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3WMbD1OyfKuwWDWMNbPQ4g',
#   'duration_ms': 208600,
#   'time_signature': 4}]

# %%
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1KQUrny9y5zGpktF6hAGd4'},
#      'href': 'https://api.spotify.com/v1/albums/1KQUrny9y5zGpktF6hAGd4',
#      'id': '1KQUrny9y5zGpktF6hAGd4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dafd1cd6e9537ec8463ea691',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dafd1cd6e9537ec8463ea691',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dafd1cd6e9537ec8463ea691',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Take The Heat Off Me',
#      'release_date': '1976',
#      'release_date_precision': 'year',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1KQUrny9y5zGpktF6hAGd4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 208600,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEC737600002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3WMbD1OyfKuwWDWMNbPQ4g'},
#     'href': 'https://api.spotify.com/v1/tracks/3WMbD1OyfKuwWDWMNbPQ4g',
#     'id': '3WMbD1OyfKuwWDWMNbPQ4g',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/03e2b60a6a5c101dc0d41866f2e079d8de4a663b?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3WMbD1OyfKuwWDWMNbPQ4g'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/155cebHEGGBqYJAXKWJw6D'},
#      'href': 'https://api.spotify.com/v1/albums/155cebHEGGBqYJAXKWJw6D',
#      'id': '155cebHEGGBqYJAXKWJw6D',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d792d961638fd28f8d281947',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d792d961638fd28f8d281947',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d792d961638fd28f8d281947',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Daddy Cool',
#      'release_date': '1994-03-14',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:155cebHEGGBqYJAXKWJw6D'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 220666,
#     'explicit': False,
#     'external_ids': {'isrc': 'DED160000010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5lWSa1rmuSL6OBPOnkAqoa'},
#     'href': 'https://api.spotify.com/v1/tracks/5lWSa1rmuSL6OBPOnkAqoa',
#     'id': '5lWSa1rmuSL6OBPOnkAqoa',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Rasputin',
#     'popularity': 72,
#     'preview_url': 'https://p.scdn.co/mp3-preview/99129129d46b1937b0897e38d561110e1cd319f4?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5lWSa1rmuSL6OBPOnkAqoa'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#        'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#        'id': '12A83CWwFiyXy90ScLWPIe',
#        'name': 'LIZOT',
#        'type': 'artist',
#        'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#        'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#        'id': '54R6Y0I7jGUCveDTtI21nb',
#        'name': 'Boney M.',
#        'type': 'artist',
#        'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7fXtm0TpLRIJhxobKDjxRp'},
#      'href': 'https://api.spotify.com/v1/albums/7fXtm0TpLRIJhxobKDjxRp',
#      'id': '7fXtm0TpLRIJhxobKDjxRp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273da8ce498bc7d441e6d841d25',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02da8ce498bc7d441e6d841d25',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851da8ce498bc7d441e6d841d25',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Daddy Cool',
#      'release_date': '2021-12-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7fXtm0TpLRIJhxobKDjxRp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12A83CWwFiyXy90ScLWPIe'},
#       'href': 'https://api.spotify.com/v1/artists/12A83CWwFiyXy90ScLWPIe',
#       'id': '12A83CWwFiyXy90ScLWPIe',
#       'name': 'LIZOT',
#       'type': 'artist',
#       'uri': 'spotify:artist:12A83CWwFiyXy90ScLWPIe'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/54R6Y0I7jGUCveDTtI21nb'},
#       'href': 'https://api.spotify.com/v1/artists/54R6Y0I7jGUCveDTtI21nb',
#       'id': '54R6Y0I7jGUCveDTtI21nb',
#       'name': 'Boney M.',
#       'type': 'artist',
#       'uri': 'spotify:artist:54R6Y0I7jGUCveDTtI21nb'}],
#     'disc_number': 1,
#     'duration_ms': 154858,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEE862102870'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/50rcUhHimavzT1qq6QrgMG'},
#     'href': 'https://api.spotify.com/v1/tracks/50rcUhHimavzT1qq6QrgMG',
#     'id': '50rcUhHimavzT1qq6QrgMG',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/857d68f8f69125e431cea3e5e89e653440600762?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:50rcUhHimavzT1qq6QrgMG'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#        'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#        'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#        'name': 'Baccara',
#        'type': 'artist',
#        'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5e6VPOPLw5cSXsVMvQEioq'},
#      'href': 'https://api.spotify.com/v1/albums/5e6VPOPLw5cSXsVMvQEioq',
#      'id': '5e6VPOPLw5cSXsVMvQEioq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f9742033ffb15f5413898ef9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f9742033ffb15f5413898ef9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f9742033ffb15f5413898ef9',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'The Collection & Tracklisting',
#      'release_date': '1998',
#      'release_date_precision': 'year',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:5e6VPOPLw5cSXsVMvQEioq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dn4KQgTE4P3jrwa3iIVzQ'},
#       'href': 'https://api.spotify.com/v1/artists/4dn4KQgTE4P3jrwa3iIVzQ',
#       'id': '4dn4KQgTE4P3jrwa3iIVzQ',
#       'name': 'Baccara',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dn4KQgTE4P3jrwa3iIVzQ'}],
#     'disc_number': 1,
#     'duration_ms': 273866,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEC760000065'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2LScqpywMqGcnum6nNaxXX'},
#     'href': 'https://api.spotify.com/v1/tracks/2LScqpywMqGcnum6nNaxXX',
#     'id': '2LScqpywMqGcnum6nNaxXX',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Yes Sir, I Can Boogie',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/704fbc9b86f59da239d2de11d6d5baf808596856?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:2LScqpywMqGcnum6nNaxXX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#        'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#        'id': '6RZUqkomCmb8zCRqc9eznB',
#        'name': 'Placebo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7kTsa1wUFrahJJf1cJEOpZ'},
#      'href': 'https://api.spotify.com/v1/albums/7kTsa1wUFrahJJf1cJEOpZ',
#      'id': '7kTsa1wUFrahJJf1cJEOpZ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27362c995dbce6d7ffa4c097475',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0262c995dbce6d7ffa4c097475',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485162c995dbce6d7ffa4c097475',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Covers',
#      'release_date': '2003-03-24',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:7kTsa1wUFrahJJf1cJEOpZ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6RZUqkomCmb8zCRqc9eznB'},
#       'href': 'https://api.spotify.com/v1/artists/6RZUqkomCmb8zCRqc9eznB',
#       'id': '6RZUqkomCmb8zCRqc9eznB',
#       'name': 'Placebo',
#       'type': 'artist',
#       'uri': 'spotify:artist:6RZUqkomCmb8zCRqc9eznB'}],
#     'disc_number': 1,
#     'duration_ms': 201706,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAAA0201215'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6blKbRwYDoXl5fFvQY2U75'},
#     'href': 'https://api.spotify.com/v1/tracks/6blKbRwYDoXl5fFvQY2U75',
#     'id': '6blKbRwYDoXl5fFvQY2U75',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Daddy Cool',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4af3ad78f847b23200036e9cee4d5b06868aea6b?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6blKbRwYDoXl5fFvQY2U75'}],
#   'limit': 5,
#   'next': 'https://api.spotify.com/v1/search?query=daddy+cool&type=track&market=GB&offset=5&limit=5',
#   'offset': 0,
#   'previous': None,
#   'total': 825}}

# %%
list_of_songs=[]
for i in results["tracks"]["items"]:
    list_of_songs.append(i["id"])

song_features = sp.audio_features(list_of_songs)

df=pd.DataFrame(song_features)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.763   0.777    -6.932       0.0364      0.281000
# 1         0.690   0.752   -11.470       0.0455      0.463000
# 2         0.809   0.872    -4.729       0.0792      0.005810
# 3         0.454   0.769    -7.653       0.0814      0.127000
# 4         0.586   0.820    -6.414       0.0323      0.000001
#
#    instrumentalness  liveness  valence    tempo                      id  \
# 0          0.790000    0.1340    0.929  124.431  3WMbD1OyfKuwWDWMNbPQ4g
# 1          0.001020    0.5950    0.970  126.005  5lWSa1rmuSL6OBPOnkAqoa
# 2          0.545000    0.0637    0.969  123.996  50rcUhHimavzT1qq6QrgMG
# 3          0.000003    0.1750    0.491  122.531  2LScqpywMqGcnum6nNaxXX
# 4          0.794000    0.1060    0.917  125.037  6blKbRwYDoXl5fFvQY2U75
#
#    duration_ms
# 0       208600
# 1       220667
# 2       154859
# 3       273867
# 4       201707

# %% [markdown]
# ## Searching a playlist

# %%
jazz_pl = sp.search(q="jazz classics", limit = 3, type = "playlist")

# %%
results = sp.search(q="down jay sean")
play_song(results["tracks"]["items"][0]["id"])
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/6cmm1LMvZdB5zsCwX5BjqE?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
playlist = sp.user_playlist_tracks("spotify", "4ebKOuGNfJ5g8RdtbEBHxe",market="GB")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4ebKOuGNfJ5g8RdtbEBHxe/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2021-11-07T08:03:16Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Pcw4hXyhUXI5lAxdjDvww'},
#        'href': 'https://api.spotify.com/v1/artists/2Pcw4hXyhUXI5lAxdjDvww',
#        'id': '2Pcw4hXyhUXI5lAxdjDvww',
#        'name': 'Post Rock Community',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Pcw4hXyhUXI5lAxdjDvww'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4rfmp4tcSWXavXohMvBexj'},
#      'href': 'https://api.spotify.com/v1/albums/4rfmp4tcSWXavXohMvBexj',
#      'id': '4rfmp4tcSWXavXohMvBexj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733f59fc09b3c13ea6df333772',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023f59fc09b3c13ea6df333772',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513f59fc09b3c13ea6df333772',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Collab',
#      'release_date': '2021-09-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4rfmp4tcSWXavXohMvBexj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Pcw4hXyhUXI5lAxdjDvww'},
#       'href': 'https://api.spotify.com/v1/artists/2Pcw4hXyhUXI5lAxdjDvww',
#       'id': '2Pcw4hXyhUXI5lAxdjDvww',
#       'name': 'Post Rock Community',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Pcw4hXyhUXI5lAxdjDvww'}],
#     'disc_number': 1,
#     'duration_ms': 409975,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GX5MX2135681'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/61lyAGlyT5DOYWVtJ3OdLz'},
#     'href': 'https://api.spotify.com/v1/tracks/61lyAGlyT5DOYWVtJ3OdLz',
#     'id': '61lyAGlyT5DOYWVtJ3OdLz',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Collab',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e5aa8f0369c1210317b0f1b516b1b4be62d794b6?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:61lyAGlyT5DOYWVtJ3OdLz'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-05-12T08:36:10Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Pcw4hXyhUXI5lAxdjDvww'},
#        'href': 'https://api.spotify.com/v1/artists/2Pcw4hXyhUXI5lAxdjDvww',
#        'id': '2Pcw4hXyhUXI5lAxdjDvww',
#        'name': 'Post Rock Community',
#        'type': 'artist',
#        'uri': 'spotify:artist:2Pcw4hXyhUXI5lAxdjDvww'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/26UfGi7fmVCjTIWW0EOIiR'},
#      'href': 'https://api.spotify.com/v1/albums/26UfGi7fmVCjTIWW0EOIiR',
#      'id': '26UfGi7fmVCjTIWW0EOIiR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27399c46ab657c6882951eaf55d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0299c46ab657c6882951eaf55d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485199c46ab657c6882951eaf55d',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Collab 2',
#      'release_date': '2023-05-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:26UfGi7fmVCjTIWW0EOIiR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Pcw4hXyhUXI5lAxdjDvww'},
#       'href': 'https://api.spotify.com/v1/artists/2Pcw4hXyhUXI5lAxdjDvww',
#       'id': '2Pcw4hXyhUXI5lAxdjDvww',
#       'name': 'Post Rock Community',
#       'type': 'artist',
#       'uri': 'spotify:artist:2Pcw4hXyhUXI5lAxdjDvww'}],
#     'disc_number': 1,
#     'duration_ms': 480583,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GX8LE2343480'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6BUvum6dn8mlXvDb97ORzR'},
#     'href': 'https://api.spotify.com/v1/tracks/6BUvum6dn8mlXvDb97ORzR',
#     'id': '6BUvum6dn8mlXvDb97ORzR',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Collab 2',
#     'popularity': 27,
#     'preview_url': 'https://p.scdn.co/mp3-preview/989cc5b006cea11e169d6fb672ba425c83a4153e?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6BUvum6dn8mlXvDb97ORzR'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-05T22:22:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TMo9LIzfhFsHRxt5e3sJc'},
#        'href': 'https://api.spotify.com/v1/artists/1TMo9LIzfhFsHRxt5e3sJc',
#        'id': '1TMo9LIzfhFsHRxt5e3sJc',
#        'name': 'Daturah',
#        'type': 'artist',
#        'uri': 'spotify:artist:1TMo9LIzfhFsHRxt5e3sJc'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/589y5zz4pMuwk64smVef6c'},
#      'href': 'https://api.spotify.com/v1/albums/589y5zz4pMuwk64smVef6c',
#      'id': '589y5zz4pMuwk64smVef6c',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27374032f707c6ac21b6c27421e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0274032f707c6ac21b6c27421e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485174032f707c6ac21b6c27421e',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Reverie',
#      'release_date': '2008-04-15',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:589y5zz4pMuwk64smVef6c'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TMo9LIzfhFsHRxt5e3sJc'},
#       'href': 'https://api.spotify.com/v1/artists/1TMo9LIzfhFsHRxt5e3sJc',
#       'id': '1TMo9LIzfhFsHRxt5e3sJc',
#       'name': 'Daturah',
#       'type': 'artist',
#       'uri': 'spotify:artist:1TMo9LIzfhFsHRxt5e3sJc'}],
#     'disc_number': 1,
#     'duration_ms': 571506,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEGM90700002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1c8RQ6bmKXeywT9FSK4QwQ'},
#     'href': 'https://api.spotify.com/v1/tracks/1c8RQ6bmKXeywT9FSK4QwQ',
#     'id': '1c8RQ6bmKXeywT9FSK4QwQ',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3iR74TFFFJioMz710Otmhx'},
#      'href': 'https://api.spotify.com/v1/tracks/3iR74TFFFJioMz710Otmhx',
#      'id': '3iR74TFFFJioMz710Otmhx',
#      'type': 'track',
#      'uri': 'spotify:track:3iR74TFFFJioMz710Otmhx'},
#     'name': 'Hybrisma',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/78148ff1436af4160f2b8ed558bfdcd6bcfb9d5c?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1c8RQ6bmKXeywT9FSK4QwQ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-05T22:27:37Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KyWqSOpfFRnPTWsq1oUAw'},
#        'href': 'https://api.spotify.com/v1/artists/5KyWqSOpfFRnPTWsq1oUAw',
#        'id': '5KyWqSOpfFRnPTWsq1oUAw',
#        'name': 'The Evpatoria Report',
#        'type': 'artist',
#        'uri': 'spotify:artist:5KyWqSOpfFRnPTWsq1oUAw'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/66uCQxyHqHIObxRVdsV6Vf'},
#      'href': 'https://api.spotify.com/v1/albums/66uCQxyHqHIObxRVdsV6Vf',
#      'id': '66uCQxyHqHIObxRVdsV6Vf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273901ad905fab27bba23f34809',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02901ad905fab27bba23f34809',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851901ad905fab27bba23f34809',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Golevka',
#      'release_date': '2005',
#      'release_date_precision': 'year',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:66uCQxyHqHIObxRVdsV6Vf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KyWqSOpfFRnPTWsq1oUAw'},
#       'href': 'https://api.spotify.com/v1/artists/5KyWqSOpfFRnPTWsq1oUAw',
#       'id': '5KyWqSOpfFRnPTWsq1oUAw',
#       'name': 'The Evpatoria Report',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KyWqSOpfFRnPTWsq1oUAw'}],
#     'disc_number': 1,
#     'duration_ms': 660200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CH6580901402'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/52Fw0bPlDegUpoETTxtIgf'},
#     'href': 'https://api.spotify.com/v1/tracks/52Fw0bPlDegUpoETTxtIgf',
#     'id': '52Fw0bPlDegUpoETTxtIgf',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Taijin Kyofusho',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5dbcfb1fcdc0ae588133ff842d3d361472e023b0?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:52Fw0bPlDegUpoETTxtIgf'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-05T22:31:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2GVzsXcXyU95u2EahzwqN7'},
#        'href': 'https://api.spotify.com/v1/artists/2GVzsXcXyU95u2EahzwqN7',
#        'id': '2GVzsXcXyU95u2EahzwqN7',
#        'name': 'If These Trees Could Talk',
#        'type': 'artist',
#        'uri': 'spotify:artist:2GVzsXcXyU95u2EahzwqN7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2bDAXWsXzO0cPixzPXCEiJ'},
#      'href': 'https://api.spotify.com/v1/albums/2bDAXWsXzO0cPixzPXCEiJ',
#      'id': '2bDAXWsXzO0cPixzPXCEiJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a5a49ab3fd0875948e5ec41e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a5a49ab3fd0875948e5ec41e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a5a49ab3fd0875948e5ec41e',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Above the Earth, Below the Sky',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:2bDAXWsXzO0cPixzPXCEiJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2GVzsXcXyU95u2EahzwqN7'},
#       'href': 'https://api.spotify.com/v1/artists/2GVzsXcXyU95u2EahzwqN7',
#       'id': '2GVzsXcXyU95u2EahzwqN7',
#       'name': 'If These Trees Could Talk',
#       'type': 'artist',
#       'uri': 'spotify:artist:2GVzsXcXyU95u2EahzwqN7'}],
#     'disc_number': 1,
#     'duration_ms': 440853,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'uscgh0995078'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/36UD2Vi7SP9YreuZYeDGyi'},
#     'href': 'https://api.spotify.com/v1/tracks/36UD2Vi7SP9YreuZYeDGyi',
#     'id': '36UD2Vi7SP9YreuZYeDGyi',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Below the Sky',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5b3033ea606d623a95c91ddb91ab8b6160a987ce?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:36UD2Vi7SP9YreuZYeDGyi'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-05T22:36:16Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2GVzsXcXyU95u2EahzwqN7'},
#        'href': 'https://api.spotify.com/v1/artists/2GVzsXcXyU95u2EahzwqN7',
#        'id': '2GVzsXcXyU95u2EahzwqN7',
#        'name': 'If These Trees Could Talk',
#        'type': 'artist',
#        'uri': 'spotify:artist:2GVzsXcXyU95u2EahzwqN7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0i1vP6JtYq4kE3oygILHzk'},
#      'href': 'https://api.spotify.com/v1/albums/0i1vP6JtYq4kE3oygILHzk',
#      'id': '0i1vP6JtYq4kE3oygILHzk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f0edc0c2044e103e27e8e0b8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f0edc0c2044e103e27e8e0b8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f0edc0c2044e103e27e8e0b8',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Red Forest',
#      'release_date': '2012-03-20',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:0i1vP6JtYq4kE3oygILHzk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2GVzsXcXyU95u2EahzwqN7'},
#       'href': 'https://api.spotify.com/v1/artists/2GVzsXcXyU95u2EahzwqN7',
#       'id': '2GVzsXcXyU95u2EahzwqN7',
#       'name': 'If These Trees Could Talk',
#       'type': 'artist',
#       'uri': 'spotify:artist:2GVzsXcXyU95u2EahzwqN7'}],
#     'disc_number': 1,
#     'duration_ms': 505653,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'uscgj1202187'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7dML6rAjXeRTHg6X8UZW83'},
#     'href': 'https://api.spotify.com/v1/tracks/7dML6rAjXeRTHg6X8UZW83',
#     'id': '7dML6rAjXeRTHg6X8UZW83',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Red Forest',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/722346b33d42f83580721cd9fa610fbc2efd2094?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7dML6rAjXeRTHg6X8UZW83'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-05T22:38:42Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0MG4LXIw7n4x0wjDc6WYXk'},
#        'href': 'https://api.spotify.com/v1/artists/0MG4LXIw7n4x0wjDc6WYXk',
#        'id': '0MG4LXIw7n4x0wjDc6WYXk',
#        'name': 'This Will Destroy You',
#        'type': 'artist',
#        'uri': 'spotify:artist:0MG4LXIw7n4x0wjDc6WYXk'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4In2V4QylBdWT8HJ0dLDw5'},
#      'href': 'https://api.spotify.com/v1/albums/4In2V4QylBdWT8HJ0dLDw5',
#      'id': '4In2V4QylBdWT8HJ0dLDw5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27339522c242d7f10c0b80eb9b9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0239522c242d7f10c0b80eb9b9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485139522c242d7f10c0b80eb9b9',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Young Mountain',
#      'release_date': '2006-06-06',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:4In2V4QylBdWT8HJ0dLDw5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0MG4LXIw7n4x0wjDc6WYXk'},
#       'href': 'https://api.spotify.com/v1/artists/0MG4LXIw7n4x0wjDc6WYXk',
#       'id': '0MG4LXIw7n4x0wjDc6WYXk',
#       'name': 'This Will Destroy You',
#       'type': 'artist',
#       'uri': 'spotify:artist:0MG4LXIw7n4x0wjDc6WYXk'}],
#     'disc_number': 1,
#     'duration_ms': 293173,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'US76L0710012'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4llDF3RuBQYj2nkjTCJY4w'},
#     'href': 'https://api.spotify.com/v1/tracks/4llDF3RuBQYj2nkjTCJY4w',
#     'id': '4llDF3RuBQYj2nkjTCJY4w',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Quiet',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f9d953a91ae45433157d0df05e955bc52f2f3392?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4llDF3RuBQYj2nkjTCJY4w'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-05T22:46:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7935eVYpj7jQM3mRJ3kGeX'},
#        'href': 'https://api.spotify.com/v1/artists/7935eVYpj7jQM3mRJ3kGeX',
#        'id': '7935eVYpj7jQM3mRJ3kGeX',
#        'name': 'Exxasens',
#        'type': 'artist',
#        'uri': 'spotify:artist:7935eVYpj7jQM3mRJ3kGeX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6tbMoRTY3brzgQfwSzkTGH'},
#      'href': 'https://api.spotify.com/v1/albums/6tbMoRTY3brzgQfwSzkTGH',
#      'id': '6tbMoRTY3brzgQfwSzkTGH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733c1df9e5c56d63e61a16f140',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023c1df9e5c56d63e61a16f140',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513c1df9e5c56d63e61a16f140',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Back to Earth',
#      'release_date': '2015-09-07',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:6tbMoRTY3brzgQfwSzkTGH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7935eVYpj7jQM3mRJ3kGeX'},
#       'href': 'https://api.spotify.com/v1/artists/7935eVYpj7jQM3mRJ3kGeX',
#       'id': '7935eVYpj7jQM3mRJ3kGeX',
#       'name': 'Exxasens',
#       'type': 'artist',
#       'uri': 'spotify:artist:7935eVYpj7jQM3mRJ3kGeX'}],
#     'disc_number': 1,
#     'duration_ms': 187066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ESA011990699'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3zQqvV121is4wfC3mKSyYA'},
#     'href': 'https://api.spotify.com/v1/tracks/3zQqvV121is4wfC3mKSyYA',
#     'id': '3zQqvV121is4wfC3mKSyYA',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0gTjRKnv2AyIQPCRoxCrPX'},
#      'href': 'https://api.spotify.com/v1/tracks/0gTjRKnv2AyIQPCRoxCrPX',
#      'id': '0gTjRKnv2AyIQPCRoxCrPX',
#      'type': 'track',
#      'uri': 'spotify:track:0gTjRKnv2AyIQPCRoxCrPX'},
#     'name': 'Your Dreams Are My Dreams',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1d6b5f11ccbbd894b2993c06222de9ec2d62ee01?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:3zQqvV121is4wfC3mKSyYA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-05T22:55:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21DtKSgtPS1mEUQsSl6y6Y'},
#        'href': 'https://api.spotify.com/v1/artists/21DtKSgtPS1mEUQsSl6y6Y',
#        'id': '21DtKSgtPS1mEUQsSl6y6Y',
#        'name': 'Leech',
#        'type': 'artist',
#        'uri': 'spotify:artist:21DtKSgtPS1mEUQsSl6y6Y'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1qLOtV8AJZO4d6qHHt29ol'},
#      'href': 'https://api.spotify.com/v1/albums/1qLOtV8AJZO4d6qHHt29ol',
#      'id': '1qLOtV8AJZO4d6qHHt29ol',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27390e3be8c18c4bc63b17d6d31',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0290e3be8c18c4bc63b17d6d31',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485190e3be8c18c4bc63b17d6d31',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'The Stolen View',
#      'release_date': '2007-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:1qLOtV8AJZO4d6qHHt29ol'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21DtKSgtPS1mEUQsSl6y6Y'},
#       'href': 'https://api.spotify.com/v1/artists/21DtKSgtPS1mEUQsSl6y6Y',
#       'id': '21DtKSgtPS1mEUQsSl6y6Y',
#       'name': 'Leech',
#       'type': 'artist',
#       'uri': 'spotify:artist:21DtKSgtPS1mEUQsSl6y6Y'}],
#     'disc_number': 1,
#     'duration_ms': 510440,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CH7510900523'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/01k0fYnD9sFE89A2zPD38v'},
#     'href': 'https://api.spotify.com/v1/tracks/01k0fYnD9sFE89A2zPD38v',
#     'id': '01k0fYnD9sFE89A2zPD38v',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The Man With The Hammer',
#     'popularity': 31,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0dca00ed7a2209f228b3df2fbf43215f6bbad841?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:01k0fYnD9sFE89A2zPD38v'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-05T22:56:52Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rRk0aScbAjuf5lAnnTe6n'},
#        'href': 'https://api.spotify.com/v1/artists/1rRk0aScbAjuf5lAnnTe6n',
#        'id': '1rRk0aScbAjuf5lAnnTe6n',
#        'name': 'Jakob',
#        'type': 'artist',
#        'uri': 'spotify:artist:1rRk0aScbAjuf5lAnnTe6n'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7jMbWLMw2mJOrIgxFxbPop'},
#      'href': 'https://api.spotify.com/v1/albums/7jMbWLMw2mJOrIgxFxbPop',
#      'id': '7jMbWLMw2mJOrIgxFxbPop',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739045c39471b1471a2b0b2870',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029045c39471b1471a2b0b2870',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519045c39471b1471a2b0b2870',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Solace',
#      'release_date': '2006-11-09',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:7jMbWLMw2mJOrIgxFxbPop'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rRk0aScbAjuf5lAnnTe6n'},
#       'href': 'https://api.spotify.com/v1/artists/1rRk0aScbAjuf5lAnnTe6n',
#       'id': '1rRk0aScbAjuf5lAnnTe6n',
#       'name': 'Jakob',
#       'type': 'artist',
#       'uri': 'spotify:artist:1rRk0aScbAjuf5lAnnTe6n'}],
#     'disc_number': 1,
#     'duration_ms': 392960,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'NZMI10600001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0GLOE0S3W89vMCOYanPgf5'},
#     'href': 'https://api.spotify.com/v1/tracks/0GLOE0S3W89vMCOYanPgf5',
#     'id': '0GLOE0S3W89vMCOYanPgf5',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0BKHHihvyZdG6beQ5cwPWL'},
#      'href': 'https://api.spotify.com/v1/tracks/0BKHHihvyZdG6beQ5cwPWL',
#      'id': '0BKHHihvyZdG6beQ5cwPWL',
#      'type': 'track',
#      'uri': 'spotify:track:0BKHHihvyZdG6beQ5cwPWL'},
#     'name': 'Malachite',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fc04896b6c74a9fbc44c6818d32e79965212f0ae?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0GLOE0S3W89vMCOYanPgf5'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-05T23:52:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/739AuFSVMsDpObOcslwJRI'},
#        'href': 'https://api.spotify.com/v1/artists/739AuFSVMsDpObOcslwJRI',
#        'id': '739AuFSVMsDpObOcslwJRI',
#        'name': 'April Rain',
#        'type': 'artist',
#        'uri': 'spotify:artist:739AuFSVMsDpObOcslwJRI'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/13KNtCQLLYLLzQmHv8vFYp'},
#      'href': 'https://api.spotify.com/v1/albums/13KNtCQLLYLLzQmHv8vFYp',
#      'id': '13KNtCQLLYLLzQmHv8vFYp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736233db52dfa89902accb91e3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026233db52dfa89902accb91e3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516233db52dfa89902accb91e3',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Waiting for Sunrise',
#      'release_date': '2014-08-30',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:13KNtCQLLYLLzQmHv8vFYp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/739AuFSVMsDpObOcslwJRI'},
#       'href': 'https://api.spotify.com/v1/artists/739AuFSVMsDpObOcslwJRI',
#       'id': '739AuFSVMsDpObOcslwJRI',
#       'name': 'April Rain',
#       'type': 'artist',
#       'uri': 'spotify:artist:739AuFSVMsDpObOcslwJRI'}],
#     'disc_number': 1,
#     'duration_ms': 415082,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'AEA0Q2192988'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4GErLZioCGVHHcy6Elh7dU'},
#     'href': 'https://api.spotify.com/v1/tracks/4GErLZioCGVHHcy6Elh7dU',
#     'id': '4GErLZioCGVHHcy6Elh7dU',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2I2DR9udeiHsiaMUhgKPoo'},
#      'href': 'https://api.spotify.com/v1/tracks/2I2DR9udeiHsiaMUhgKPoo',
#      'id': '2I2DR9udeiHsiaMUhgKPoo',
#      'type': 'track',
#      'uri': 'spotify:track:2I2DR9udeiHsiaMUhgKPoo'},
#     'name': 'Come Back Quicker Please',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f6a579a90c5654c31bbe20df634fbc8cd5b26908?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4GErLZioCGVHHcy6Elh7dU'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-06T08:23:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0mwbAhNgoHdpzdahGIsAUs'},
#        'href': 'https://api.spotify.com/v1/artists/0mwbAhNgoHdpzdahGIsAUs',
#        'id': '0mwbAhNgoHdpzdahGIsAUs',
#        'name': 'The Seven Mile Journey',
#        'type': 'artist',
#        'uri': 'spotify:artist:0mwbAhNgoHdpzdahGIsAUs'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/769ShcHbbjhaUX9rdAArAr'},
#      'href': 'https://api.spotify.com/v1/albums/769ShcHbbjhaUX9rdAArAr',
#      'id': '769ShcHbbjhaUX9rdAArAr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f359fa78e388200ead76f081',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f359fa78e388200ead76f081',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f359fa78e388200ead76f081',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'The Journey Studies',
#      'release_date': '2005-06-17',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:769ShcHbbjhaUX9rdAArAr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0mwbAhNgoHdpzdahGIsAUs'},
#       'href': 'https://api.spotify.com/v1/artists/0mwbAhNgoHdpzdahGIsAUs',
#       'id': '0mwbAhNgoHdpzdahGIsAUs',
#       'name': 'The Seven Mile Journey',
#       'type': 'artist',
#       'uri': 'spotify:artist:0mwbAhNgoHdpzdahGIsAUs'}],
#     'disc_number': 1,
#     'duration_ms': 451480,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA560886563'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2CdK2F1L8VWzxBbqwSsJI5'},
#     'href': 'https://api.spotify.com/v1/tracks/2CdK2F1L8VWzxBbqwSsJI5',
#     'id': '2CdK2F1L8VWzxBbqwSsJI5',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'The Murderer/Victim Monologues',
#     'popularity': 24,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8d6a1641a0d09ee9ca31b0c40ac3e1ecade4a403?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2CdK2F1L8VWzxBbqwSsJI5'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-06T09:09:15Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1U0FaHAc4fcwQcYEJFgkm9'},
#        'href': 'https://api.spotify.com/v1/artists/1U0FaHAc4fcwQcYEJFgkm9',
#        'id': '1U0FaHAc4fcwQcYEJFgkm9',
#        'name': 'Balmorhea',
#        'type': 'artist',
#        'uri': 'spotify:artist:1U0FaHAc4fcwQcYEJFgkm9'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3RGZGuwR3f0n6Y4WtE7dlR'},
#      'href': 'https://api.spotify.com/v1/albums/3RGZGuwR3f0n6Y4WtE7dlR',
#      'id': '3RGZGuwR3f0n6Y4WtE7dlR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273df91f7635e716e39145b8e6d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02df91f7635e716e39145b8e6d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851df91f7635e716e39145b8e6d',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'All Is Wild, All Is Silent',
#      'release_date': '2009-10-03',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:3RGZGuwR3f0n6Y4WtE7dlR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1U0FaHAc4fcwQcYEJFgkm9'},
#       'href': 'https://api.spotify.com/v1/artists/1U0FaHAc4fcwQcYEJFgkm9',
#       'id': '1U0FaHAc4fcwQcYEJFgkm9',
#       'name': 'Balmorhea',
#       'type': 'artist',
#       'uri': 'spotify:artist:1U0FaHAc4fcwQcYEJFgkm9'}],
#     'disc_number': 1,
#     'duration_ms': 349200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'US78L0910014'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7xiw42KTmCcqfZNCZqUcnF'},
#     'href': 'https://api.spotify.com/v1/tracks/7xiw42KTmCcqfZNCZqUcnF',
#     'id': '7xiw42KTmCcqfZNCZqUcnF',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4VCKj1eGRZ0snkb5WLgLsX'},
#      'href': 'https://api.spotify.com/v1/tracks/4VCKj1eGRZ0snkb5WLgLsX',
#      'id': '4VCKj1eGRZ0snkb5WLgLsX',
#      'type': 'track',
#      'uri': 'spotify:track:4VCKj1eGRZ0snkb5WLgLsX'},
#     'name': 'Remembrance',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cd21911f38f85188cebf92c8dfbf53c805b102dc?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7xiw42KTmCcqfZNCZqUcnF'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-06T08:35:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5y6sgY3BsTu5q1R2GylGBQ'},
#        'href': 'https://api.spotify.com/v1/artists/5y6sgY3BsTu5q1R2GylGBQ',
#        'id': '5y6sgY3BsTu5q1R2GylGBQ',
#        'name': 'Spoiwo',
#        'type': 'artist',
#        'uri': 'spotify:artist:5y6sgY3BsTu5q1R2GylGBQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2CZVCpgbj9OxEci6fPgq4u'},
#      'href': 'https://api.spotify.com/v1/albums/2CZVCpgbj9OxEci6fPgq4u',
#      'id': '2CZVCpgbj9OxEci6fPgq4u',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273425cc3fb549c368705f443fc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02425cc3fb549c368705f443fc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851425cc3fb549c368705f443fc',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Salute Solitude',
#      'release_date': '2015-03-13',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:2CZVCpgbj9OxEci6fPgq4u'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5y6sgY3BsTu5q1R2GylGBQ'},
#       'href': 'https://api.spotify.com/v1/artists/5y6sgY3BsTu5q1R2GylGBQ',
#       'id': '5y6sgY3BsTu5q1R2GylGBQ',
#       'name': 'Spoiwo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5y6sgY3BsTu5q1R2GylGBQ'}],
#     'disc_number': 1,
#     'duration_ms': 256731,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'usdy41795803'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6kE8jI28r6FpCQNmFN3fyB'},
#     'href': 'https://api.spotify.com/v1/tracks/6kE8jI28r6FpCQNmFN3fyB',
#     'id': '6kE8jI28r6FpCQNmFN3fyB',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Skin',
#     'popularity': 23,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ab65aa0d96f0a95174a975066d7196c74ff18a86?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6kE8jI28r6FpCQNmFN3fyB'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-06T08:27:49Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GVByFFfFJYCzK4d8ZyL6s'},
#        'href': 'https://api.spotify.com/v1/artists/7GVByFFfFJYCzK4d8ZyL6s',
#        'id': '7GVByFFfFJYCzK4d8ZyL6s',
#        'name': 'We Lost The Sea',
#        'type': 'artist',
#        'uri': 'spotify:artist:7GVByFFfFJYCzK4d8ZyL6s'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5VbiQX9WB7ZDNvFOy3pY7J'},
#      'href': 'https://api.spotify.com/v1/albums/5VbiQX9WB7ZDNvFOy3pY7J',
#      'id': '5VbiQX9WB7ZDNvFOy3pY7J',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c37d2fca5c268e7655bd8053',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c37d2fca5c268e7655bd8053',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c37d2fca5c268e7655bd8053',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Triumph & Disaster',
#      'release_date': '2019-10-04',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:5VbiQX9WB7ZDNvFOy3pY7J'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7GVByFFfFJYCzK4d8ZyL6s'},
#       'href': 'https://api.spotify.com/v1/artists/7GVByFFfFJYCzK4d8ZyL6s',
#       'id': '7GVByFFfFJYCzK4d8ZyL6s',
#       'name': 'We Lost The Sea',
#       'type': 'artist',
#       'uri': 'spotify:artist:7GVByFFfFJYCzK4d8ZyL6s'}],
#     'disc_number': 1,
#     'duration_ms': 903680,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUAJ11900013'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4cEmRW2agalEtEy2bL9kcq'},
#     'href': 'https://api.spotify.com/v1/tracks/4cEmRW2agalEtEy2bL9kcq',
#     'id': '4cEmRW2agalEtEy2bL9kcq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Towers',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6b987273e8b83d6b6874427388a5da7d2fcadade?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4cEmRW2agalEtEy2bL9kcq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-06T08:40:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CDM8i1eI2OkPmruOwwQV6'},
#        'href': 'https://api.spotify.com/v1/artists/6CDM8i1eI2OkPmruOwwQV6',
#        'id': '6CDM8i1eI2OkPmruOwwQV6',
#        'name': 'Distant Dream',
#        'type': 'artist',
#        'uri': 'spotify:artist:6CDM8i1eI2OkPmruOwwQV6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1CmXeIdzguf1Hq4FNQDJj0'},
#      'href': 'https://api.spotify.com/v1/albums/1CmXeIdzguf1Hq4FNQDJj0',
#      'id': '1CmXeIdzguf1Hq4FNQDJj0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27336c9867914e9a535806e36de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0236c9867914e9a535806e36de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485136c9867914e9a535806e36de',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'It All Starts from Pieces',
#      'release_date': '2017-05-27',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:1CmXeIdzguf1Hq4FNQDJj0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CDM8i1eI2OkPmruOwwQV6'},
#       'href': 'https://api.spotify.com/v1/artists/6CDM8i1eI2OkPmruOwwQV6',
#       'id': '6CDM8i1eI2OkPmruOwwQV6',
#       'name': 'Distant Dream',
#       'type': 'artist',
#       'uri': 'spotify:artist:6CDM8i1eI2OkPmruOwwQV6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/76G7JHgzIJp4B1xZG6GHRA'},
#       'href': 'https://api.spotify.com/v1/artists/76G7JHgzIJp4B1xZG6GHRA',
#       'id': '76G7JHgzIJp4B1xZG6GHRA',
#       'name': 'Dhalif Ali',
#       'type': 'artist',
#       'uri': 'spotify:artist:76G7JHgzIJp4B1xZG6GHRA'}],
#     'disc_number': 1,
#     'duration_ms': 327997,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADC1721539'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1ukjeAD5u0riT9muPRzvrj'},
#     'href': 'https://api.spotify.com/v1/tracks/1ukjeAD5u0riT9muPRzvrj',
#     'id': '1ukjeAD5u0riT9muPRzvrj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Sleeping Waves (feat. Dhalif Ali)',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/47393fff05a94501a0d701cc2f1e3080a2af2b6c?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1ukjeAD5u0riT9muPRzvrj'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-06T08:52:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SiCxhceGZgzusCLHd4Zz6'},
#        'href': 'https://api.spotify.com/v1/artists/3SiCxhceGZgzusCLHd4Zz6',
#        'id': '3SiCxhceGZgzusCLHd4Zz6',
#        'name': 'Long Distance Calling',
#        'type': 'artist',
#        'uri': 'spotify:artist:3SiCxhceGZgzusCLHd4Zz6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/65OQXbKwC9pJbVFVQDXF60'},
#      'href': 'https://api.spotify.com/v1/albums/65OQXbKwC9pJbVFVQDXF60',
#      'id': '65OQXbKwC9pJbVFVQDXF60',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a27f89d20a122ecd3d8bf8f9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a27f89d20a122ecd3d8bf8f9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a27f89d20a122ecd3d8bf8f9',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Avoid the Light',
#      'release_date': '2010-07-16',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:65OQXbKwC9pJbVFVQDXF60'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SiCxhceGZgzusCLHd4Zz6'},
#       'href': 'https://api.spotify.com/v1/artists/3SiCxhceGZgzusCLHd4Zz6',
#       'id': '3SiCxhceGZgzusCLHd4Zz6',
#       'name': 'Long Distance Calling',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SiCxhceGZgzusCLHd4Zz6'}],
#     'disc_number': 1,
#     'duration_ms': 475120,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDHC0901203'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7pV8dWHPZML60VZXvfPoIK'},
#     'href': 'https://api.spotify.com/v1/tracks/7pV8dWHPZML60VZXvfPoIK',
#     'id': '7pV8dWHPZML60VZXvfPoIK',
#     'is_local': False,
#     'is_playable': True,
#     'name': '359°',
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4ad123f6a43208479f34f85a8d870fef40c2f23d?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7pV8dWHPZML60VZXvfPoIK'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-11-06T09:52:04Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/60HxgwwUIAr3hxVgRedY19'},
#        'href': 'https://api.spotify.com/v1/artists/60HxgwwUIAr3hxVgRedY19',
#        'id': '60HxgwwUIAr3hxVgRedY19',
#        'name': 'Blueneck',
#        'type': 'artist',
#        'uri': 'spotify:artist:60HxgwwUIAr3hxVgRedY19'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4lk5gUGka6s2IXyXpiGEBj'},
#      'href': 'https://api.spotify.com/v1/albums/4lk5gUGka6s2IXyXpiGEBj',
#      'id': '4lk5gUGka6s2IXyXpiGEBj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27337934b27923f8cfaf7db8b44',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0237934b27923f8cfaf7db8b44',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485137934b27923f8cfaf7db8b44',
# ...
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2O7pDjQ0ajMqmQ26XUZh1N'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-03-30T14:04:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/01tD6pz0YTMXpRkFj4wuQ3'},
#        'href': 'https://api.spotify.com/v1/artists/01tD6pz0YTMXpRkFj4wuQ3',
#        'id': '01tD6pz0YTMXpRkFj4wuQ3',
#        'name': 'Deer Park Ranger',
#        'type': 'artist',
#        'uri': 'spotify:artist:01tD6pz0YTMXpRkFj4wuQ3'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5GB8fVcRpOGvBfer3kro0H'},
#      'href': 'https://api.spotify.com/v1/albums/5GB8fVcRpOGvBfer3kro0H',
#      'id': '5GB8fVcRpOGvBfer3kro0H',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27369a3b3dd06b53a8c15f3e5aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0269a3b3dd06b53a8c15f3e5aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485169a3b3dd06b53a8c15f3e5aa',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Adaptation',
#      'release_date': '2020-03-19',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:5GB8fVcRpOGvBfer3kro0H'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/01tD6pz0YTMXpRkFj4wuQ3'},
#       'href': 'https://api.spotify.com/v1/artists/01tD6pz0YTMXpRkFj4wuQ3',
#       'id': '01tD6pz0YTMXpRkFj4wuQ3',
#       'name': 'Deer Park Ranger',
#       'type': 'artist',
#       'uri': 'spotify:artist:01tD6pz0YTMXpRkFj4wuQ3'}],
#     'disc_number': 1,
#     'duration_ms': 482448,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR10S2084761'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0vhD3lkqYtnnGxsMgg6qy4'},
#     'href': 'https://api.spotify.com/v1/tracks/0vhD3lkqYtnnGxsMgg6qy4',
#     'id': '0vhD3lkqYtnnGxsMgg6qy4',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Shapeshifter',
#     'popularity': 13,
#     'preview_url': 'https://p.scdn.co/mp3-preview/39476d85cb17d32d28a2c8ec4fe7926e679822ef?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:0vhD3lkqYtnnGxsMgg6qy4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-05-04T17:24:44Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2z0KnKHXj7tHvp49Ws1JiW'},
#        'href': 'https://api.spotify.com/v1/artists/2z0KnKHXj7tHvp49Ws1JiW',
#        'id': '2z0KnKHXj7tHvp49Ws1JiW',
#        'name': 'Artyom',
#        'type': 'artist',
#        'uri': 'spotify:artist:2z0KnKHXj7tHvp49Ws1JiW'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7EEjnc6qA9jc0GpDrWJbqv'},
#      'href': 'https://api.spotify.com/v1/albums/7EEjnc6qA9jc0GpDrWJbqv',
#      'id': '7EEjnc6qA9jc0GpDrWJbqv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bfd0aa5497ef09cf0bf7e2e4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bfd0aa5497ef09cf0bf7e2e4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bfd0aa5497ef09cf0bf7e2e4',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Paris',
#      'release_date': '2020-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:7EEjnc6qA9jc0GpDrWJbqv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2z0KnKHXj7tHvp49Ws1JiW'},
#       'href': 'https://api.spotify.com/v1/artists/2z0KnKHXj7tHvp49Ws1JiW',
#       'id': '2z0KnKHXj7tHvp49Ws1JiW',
#       'name': 'Artyom',
#       'type': 'artist',
#       'uri': 'spotify:artist:2z0KnKHXj7tHvp49Ws1JiW'}],
#     'disc_number': 1,
#     'duration_ms': 511755,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CALVP2088254'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5480ixMtZrxXUK35jUlR8K'},
#     'href': 'https://api.spotify.com/v1/tracks/5480ixMtZrxXUK35jUlR8K',
#     'id': '5480ixMtZrxXUK35jUlR8K',
#     'is_local': False,
#     'is_playable': False,
#     'name': 'Paris',
#     'popularity': 0,
#     'preview_url': None,
#     'restrictions': {'reason': 'market'},
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5480ixMtZrxXUK35jUlR8K'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-05-08T17:49:36Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eV1lwtIFk1zlao9llmRTn'},
#        'href': 'https://api.spotify.com/v1/artists/5eV1lwtIFk1zlao9llmRTn',
#        'id': '5eV1lwtIFk1zlao9llmRTn',
#        'name': 'Gazelles',
#        'type': 'artist',
#        'uri': 'spotify:artist:5eV1lwtIFk1zlao9llmRTn'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/543bpgL9PYMcgjHd8ysAn0'},
#      'href': 'https://api.spotify.com/v1/albums/543bpgL9PYMcgjHd8ysAn0',
#      'id': '543bpgL9PYMcgjHd8ysAn0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fdeb537401d0400ebf54d77a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fdeb537401d0400ebf54d77a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fdeb537401d0400ebf54d77a',
#        'width': 64}],
#      'is_playable': True,
#      'name': "There's No One New Around You",
#      'release_date': '2017-10-20',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:543bpgL9PYMcgjHd8ysAn0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eV1lwtIFk1zlao9llmRTn'},
#       'href': 'https://api.spotify.com/v1/artists/5eV1lwtIFk1zlao9llmRTn',
#       'id': '5eV1lwtIFk1zlao9llmRTn',
#       'name': 'Gazelles',
#       'type': 'artist',
#       'uri': 'spotify:artist:5eV1lwtIFk1zlao9llmRTn'}],
#     'disc_number': 1,
#     'duration_ms': 432634,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADH1715504'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/49AtitzqZS8BvLNJyW4X07'},
#     'href': 'https://api.spotify.com/v1/tracks/49AtitzqZS8BvLNJyW4X07',
#     'id': '49AtitzqZS8BvLNJyW4X07',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Great White Black',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/593ad92bd79da112083fbde8c2b5cbf6313a5fc7?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:49AtitzqZS8BvLNJyW4X07'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-05-20T20:11:11Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7yJoUbl6dOkkkUbVkbsonA'},
#        'href': 'https://api.spotify.com/v1/artists/7yJoUbl6dOkkkUbVkbsonA',
#        'id': '7yJoUbl6dOkkkUbVkbsonA',
#        'name': 'In Two We Break',
#        'type': 'artist',
#        'uri': 'spotify:artist:7yJoUbl6dOkkkUbVkbsonA'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5jz00ik0UqH7tV2dSCxvKR'},
#      'href': 'https://api.spotify.com/v1/albums/5jz00ik0UqH7tV2dSCxvKR',
#      'id': '5jz00ik0UqH7tV2dSCxvKR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732aaff319f0d41d73dd834647',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022aaff319f0d41d73dd834647',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512aaff319f0d41d73dd834647',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Out of the Light',
#      'release_date': '2020-04-20',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:5jz00ik0UqH7tV2dSCxvKR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7yJoUbl6dOkkkUbVkbsonA'},
#       'href': 'https://api.spotify.com/v1/artists/7yJoUbl6dOkkkUbVkbsonA',
#       'id': '7yJoUbl6dOkkkUbVkbsonA',
#       'name': 'In Two We Break',
#       'type': 'artist',
#       'uri': 'spotify:artist:7yJoUbl6dOkkkUbVkbsonA'}],
#     'disc_number': 1,
#     'duration_ms': 334322,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCAET2082926'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/59IufJecoIwUJjnLjy0czz'},
#     'href': 'https://api.spotify.com/v1/tracks/59IufJecoIwUJjnLjy0czz',
#     'id': '59IufJecoIwUJjnLjy0czz',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Law of Club and Fang',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/58acf5996d5bb7a5cde7054d724500be50a9f1c4?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:59IufJecoIwUJjnLjy0czz'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-05-22T10:56:37Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1V85uZNnreRvRvV3kVK4Ku'},
#        'href': 'https://api.spotify.com/v1/artists/1V85uZNnreRvRvV3kVK4Ku',
#        'id': '1V85uZNnreRvRvV3kVK4Ku',
#        'name': 'Egoera',
#        'type': 'artist',
#        'uri': 'spotify:artist:1V85uZNnreRvRvV3kVK4Ku'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0lcWQHzk1taKoTqJTzE4pf'},
#      'href': 'https://api.spotify.com/v1/albums/0lcWQHzk1taKoTqJTzE4pf',
#      'id': '0lcWQHzk1taKoTqJTzE4pf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cd623f80d3a0ddf08a6e1dac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cd623f80d3a0ddf08a6e1dac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cd623f80d3a0ddf08a6e1dac',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Fortuna',
#      'release_date': '2020-04-30',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:0lcWQHzk1taKoTqJTzE4pf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1V85uZNnreRvRvV3kVK4Ku'},
#       'href': 'https://api.spotify.com/v1/artists/1V85uZNnreRvRvV3kVK4Ku',
#       'id': '1V85uZNnreRvRvV3kVK4Ku',
#       'name': 'Egoera',
#       'type': 'artist',
#       'uri': 'spotify:artist:1V85uZNnreRvRvV3kVK4Ku'}],
#     'disc_number': 1,
#     'duration_ms': 315457,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'usdy42027169'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2PRSNJbOWptRyOtM8y0FUX'},
#     'href': 'https://api.spotify.com/v1/tracks/2PRSNJbOWptRyOtM8y0FUX',
#     'id': '2PRSNJbOWptRyOtM8y0FUX',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Hiru',
#     'popularity': 13,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3999744730df794e456141b17ccd9696368a8b3d?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2PRSNJbOWptRyOtM8y0FUX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-05-22T10:56:44Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#     'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#     'id': '20oxoq89bzf5r8uf5x54v3k8a',
#     'type': 'user',
#     'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1V85uZNnreRvRvV3kVK4Ku'},
#        'href': 'https://api.spotify.com/v1/artists/1V85uZNnreRvRvV3kVK4Ku',
#        'id': '1V85uZNnreRvRvV3kVK4Ku',
#        'name': 'Egoera',
#        'type': 'artist',
#        'uri': 'spotify:artist:1V85uZNnreRvRvV3kVK4Ku'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0lcWQHzk1taKoTqJTzE4pf'},
#      'href': 'https://api.spotify.com/v1/albums/0lcWQHzk1taKoTqJTzE4pf',
#      'id': '0lcWQHzk1taKoTqJTzE4pf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cd623f80d3a0ddf08a6e1dac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cd623f80d3a0ddf08a6e1dac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cd623f80d3a0ddf08a6e1dac',
#        'width': 64}],
#      'is_playable': True,
#      'name': 'Fortuna',
#      'release_date': '2020-04-30',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:0lcWQHzk1taKoTqJTzE4pf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1V85uZNnreRvRvV3kVK4Ku'},
#       'href': 'https://api.spotify.com/v1/artists/1V85uZNnreRvRvV3kVK4Ku',
#       'id': '1V85uZNnreRvRvV3kVK4Ku',
#       'name': 'Egoera',
#       'type': 'artist',
#       'uri': 'spotify:artist:1V85uZNnreRvRvV3kVK4Ku'}],
#     'disc_number': 1,
#     'duration_ms': 379942,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'usdy42070493'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7gmYuNTOzbTFVUMrzOIg6B'},
#     'href': 'https://api.spotify.com/v1/tracks/7gmYuNTOzbTFVUMrzOIg6B',
#     'id': '7gmYuNTOzbTFVUMrzOIg6B',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Fortuna',
#     'popularity': 14,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e59a7ec6d64a849edfc39b531255f9eb08bc68c7?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7gmYuNTOzbTFVUMrzOIg6B'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/4ebKOuGNfJ5g8RdtbEBHxe/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 248}

# %%
type(playlist)
# Out:
# dict

# %%
playlist.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
len(playlist["items"])
# Out:
# 100

# %% [markdown]
# ## Extracting a song from playlist

# %%
pprint.pprint(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4ebKOuGNfJ5g8RdtbEBHxe/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2021-11-07T08:03:16Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Pcw4hXyhUXI5lAxdjDvww'},
#                                              'href': 'https://api.spotify.com/v1/artists/2Pcw4hXyhUXI5lAxdjDvww',
#                                              'id': '2Pcw4hXyhUXI5lAxdjDvww',
#                                              'name': 'Post Rock Community',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2Pcw4hXyhUXI5lAxdjDvww'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/4rfmp4tcSWXavXohMvBexj'},
#                                 'href': 'https://api.spotify.com/v1/albums/4rfmp4tcSWXavXohMvBexj',
#                                 'id': '4rfmp4tcSWXavXohMvBexj',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2733f59fc09b3c13ea6df333772',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e023f59fc09b3c13ea6df333772',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048513f59fc09b3c13ea6df333772',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Collab',
#                                 'release_date': '2021-09-16',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 1,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:4rfmp4tcSWXavXohMvBexj'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Pcw4hXyhUXI5lAxdjDvww'},
#                                    'href': 'https://api.spotify.com/v1/artists/2Pcw4hXyhUXI5lAxdjDvww',
#                                    'id': '2Pcw4hXyhUXI5lAxdjDvww',
#                                    'name': 'Post Rock Community',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2Pcw4hXyhUXI5lAxdjDvww'}],
#                       'disc_number': 1,
#                       'duration_ms': 409975,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GX5MX2135681'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/61lyAGlyT5DOYWVtJ3OdLz'},
#                       'href': 'https://api.spotify.com/v1/tracks/61lyAGlyT5DOYWVtJ3OdLz',
#                       'id': '61lyAGlyT5DOYWVtJ3OdLz',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Collab',
#                       'popularity': 32,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/e5aa8f0369c1210317b0f1b516b1b4be62d794b6?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:61lyAGlyT5DOYWVtJ3OdLz'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2023-05-12T08:36:10Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Pcw4hXyhUXI5lAxdjDvww'},
#                                              'href': 'https://api.spotify.com/v1/artists/2Pcw4hXyhUXI5lAxdjDvww',
#                                              'id': '2Pcw4hXyhUXI5lAxdjDvww',
#                                              'name': 'Post Rock Community',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2Pcw4hXyhUXI5lAxdjDvww'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/26UfGi7fmVCjTIWW0EOIiR'},
#                                 'href': 'https://api.spotify.com/v1/albums/26UfGi7fmVCjTIWW0EOIiR',
#                                 'id': '26UfGi7fmVCjTIWW0EOIiR',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27399c46ab657c6882951eaf55d',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0299c46ab657c6882951eaf55d',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485199c46ab657c6882951eaf55d',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Collab 2',
#                                 'release_date': '2023-05-03',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 1,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:26UfGi7fmVCjTIWW0EOIiR'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2Pcw4hXyhUXI5lAxdjDvww'},
#                                    'href': 'https://api.spotify.com/v1/artists/2Pcw4hXyhUXI5lAxdjDvww',
#                                    'id': '2Pcw4hXyhUXI5lAxdjDvww',
#                                    'name': 'Post Rock Community',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2Pcw4hXyhUXI5lAxdjDvww'}],
#                       'disc_number': 1,
#                       'duration_ms': 480583,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'GX8LE2343480'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6BUvum6dn8mlXvDb97ORzR'},
#                       'href': 'https://api.spotify.com/v1/tracks/6BUvum6dn8mlXvDb97ORzR',
#                       'id': '6BUvum6dn8mlXvDb97ORzR',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Collab 2',
#                       'popularity': 27,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/989cc5b006cea11e169d6fb672ba425c83a4153e?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:6BUvum6dn8mlXvDb97ORzR'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-11-05T22:22:03Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TMo9LIzfhFsHRxt5e3sJc'},
#                                              'href': 'https://api.spotify.com/v1/artists/1TMo9LIzfhFsHRxt5e3sJc',
#                                              'id': '1TMo9LIzfhFsHRxt5e3sJc',
#                                              'name': 'Daturah',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1TMo9LIzfhFsHRxt5e3sJc'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/589y5zz4pMuwk64smVef6c'},
#                                 'href': 'https://api.spotify.com/v1/albums/589y5zz4pMuwk64smVef6c',
#                                 'id': '589y5zz4pMuwk64smVef6c',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27374032f707c6ac21b6c27421e',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0274032f707c6ac21b6c27421e',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485174032f707c6ac21b6c27421e',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Reverie',
#                                 'release_date': '2008-04-15',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 5,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:589y5zz4pMuwk64smVef6c'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1TMo9LIzfhFsHRxt5e3sJc'},
#                                    'href': 'https://api.spotify.com/v1/artists/1TMo9LIzfhFsHRxt5e3sJc',
#                                    'id': '1TMo9LIzfhFsHRxt5e3sJc',
#                                    'name': 'Daturah',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1TMo9LIzfhFsHRxt5e3sJc'}],
#                       'disc_number': 1,
#                       'duration_ms': 571506,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'DEGM90700002'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1c8RQ6bmKXeywT9FSK4QwQ'},
#                       'href': 'https://api.spotify.com/v1/tracks/1c8RQ6bmKXeywT9FSK4QwQ',
#                       'id': '1c8RQ6bmKXeywT9FSK4QwQ',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3iR74TFFFJioMz710Otmhx'},
#                                       'href': 'https://api.spotify.com/v1/tracks/3iR74TFFFJioMz710Otmhx',
#                                       'id': '3iR74TFFFJioMz710Otmhx',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:3iR74TFFFJioMz710Otmhx'},
#                       'name': 'Hybrisma',
#                       'popularity': 33,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/78148ff1436af4160f2b8ed558bfdcd6bcfb9d5c?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:1c8RQ6bmKXeywT9FSK4QwQ'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-11-05T22:27:37Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KyWqSOpfFRnPTWsq1oUAw'},
#                                              'href': 'https://api.spotify.com/v1/artists/5KyWqSOpfFRnPTWsq1oUAw',
#                                              'id': '5KyWqSOpfFRnPTWsq1oUAw',
#                                              'name': 'The Evpatoria Report',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5KyWqSOpfFRnPTWsq1oUAw'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/66uCQxyHqHIObxRVdsV6Vf'},
#                                 'href': 'https://api.spotify.com/v1/albums/66uCQxyHqHIObxRVdsV6Vf',
#                                 'id': '66uCQxyHqHIObxRVdsV6Vf',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273901ad905fab27bba23f34809',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02901ad905fab27bba23f34809',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851901ad905fab27bba23f34809',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Golevka',
#                                 'release_date': '2005',
#                                 'release_date_precision': 'year',
#                                 'total_tracks': 8,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:66uCQxyHqHIObxRVdsV6Vf'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KyWqSOpfFRnPTWsq1oUAw'},
#                                    'href': 'https://api.spotify.com/v1/artists/5KyWqSOpfFRnPTWsq1oUAw',
#                                    'id': '5KyWqSOpfFRnPTWsq1oUAw',
#                                    'name': 'The Evpatoria Report',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5KyWqSOpfFRnPTWsq1oUAw'}],
#                       'disc_number': 1,
#                       'duration_ms': 660200,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'CH6580901402'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/52Fw0bPlDegUpoETTxtIgf'},
#                       'href': 'https://api.spotify.com/v1/tracks/52Fw0bPlDegUpoETTxtIgf',
#                       'id': '52Fw0bPlDegUpoETTxtIgf',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Taijin Kyofusho',
#                       'popularity': 38,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/5dbcfb1fcdc0ae588133ff842d3d361472e023b0?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:52Fw0bPlDegUpoETTxtIgf'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-11-05T22:31:57Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2GVzsXcXyU95u2EahzwqN7'},
#                                              'href': 'https://api.spotify.com/v1/artists/2GVzsXcXyU95u2EahzwqN7',
#                                              'id': '2GVzsXcXyU95u2EahzwqN7',
#                                              'name': 'If These Trees Could '
#                                                      'Talk',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2GVzsXcXyU95u2EahzwqN7'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/2bDAXWsXzO0cPixzPXCEiJ'},
#                                 'href': 'https://api.spotify.com/v1/albums/2bDAXWsXzO0cPixzPXCEiJ',
#                                 'id': '2bDAXWsXzO0cPixzPXCEiJ',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273a5a49ab3fd0875948e5ec41e',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02a5a49ab3fd0875948e5ec41e',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851a5a49ab3fd0875948e5ec41e',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Above the Earth, Below the Sky',
#                                 'release_date': '2009-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 10,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:2bDAXWsXzO0cPixzPXCEiJ'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2GVzsXcXyU95u2EahzwqN7'},
#                                    'href': 'https://api.spotify.com/v1/artists/2GVzsXcXyU95u2EahzwqN7',
#                                    'id': '2GVzsXcXyU95u2EahzwqN7',
#                                    'name': 'If These Trees Could Talk',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2GVzsXcXyU95u2EahzwqN7'}],
#                       'disc_number': 1,
#                       'duration_ms': 440853,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'uscgh0995078'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/36UD2Vi7SP9YreuZYeDGyi'},
#                       'href': 'https://api.spotify.com/v1/tracks/36UD2Vi7SP9YreuZYeDGyi',
#                       'id': '36UD2Vi7SP9YreuZYeDGyi',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Below the Sky',
#                       'popularity': 33,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/5b3033ea606d623a95c91ddb91ab8b6160a987ce?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:36UD2Vi7SP9YreuZYeDGyi'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-11-05T22:36:16Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2GVzsXcXyU95u2EahzwqN7'},
#                                              'href': 'https://api.spotify.com/v1/artists/2GVzsXcXyU95u2EahzwqN7',
#                                              'id': '2GVzsXcXyU95u2EahzwqN7',
#                                              'name': 'If These Trees Could '
#                                                      'Talk',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2GVzsXcXyU95u2EahzwqN7'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0i1vP6JtYq4kE3oygILHzk'},
#                                 'href': 'https://api.spotify.com/v1/albums/0i1vP6JtYq4kE3oygILHzk',
#                                 'id': '0i1vP6JtYq4kE3oygILHzk',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273f0edc0c2044e103e27e8e0b8',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02f0edc0c2044e103e27e8e0b8',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851f0edc0c2044e103e27e8e0b8',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Red Forest',
#                                 'release_date': '2012-03-20',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 9,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0i1vP6JtYq4kE3oygILHzk'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2GVzsXcXyU95u2EahzwqN7'},
#                                    'href': 'https://api.spotify.com/v1/artists/2GVzsXcXyU95u2EahzwqN7',
#                                    'id': '2GVzsXcXyU95u2EahzwqN7',
#                                    'name': 'If These Trees Could Talk',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2GVzsXcXyU95u2EahzwqN7'}],
#                       'disc_number': 1,
#                       'duration_ms': 505653,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'uscgj1202187'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/7dML6rAjXeRTHg6X8UZW83'},
#                       'href': 'https://api.spotify.com/v1/tracks/7dML6rAjXeRTHg6X8UZW83',
#                       'id': '7dML6rAjXeRTHg6X8UZW83',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Red Forest',
#                       'popularity': 34,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/722346b33d42f83580721cd9fa610fbc2efd2094?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 6,
#                       'type': 'track',
#                       'uri': 'spotify:track:7dML6rAjXeRTHg6X8UZW83'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-11-05T22:38:42Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0MG4LXIw7n4x0wjDc6WYXk'},
#                                              'href': 'https://api.spotify.com/v1/artists/0MG4LXIw7n4x0wjDc6WYXk',
#                                              'id': '0MG4LXIw7n4x0wjDc6WYXk',
#                                              'name': 'This Will Destroy You',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:0MG4LXIw7n4x0wjDc6WYXk'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/4In2V4QylBdWT8HJ0dLDw5'},
#                                 'href': 'https://api.spotify.com/v1/albums/4In2V4QylBdWT8HJ0dLDw5',
#                                 'id': '4In2V4QylBdWT8HJ0dLDw5',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27339522c242d7f10c0b80eb9b9',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0239522c242d7f10c0b80eb9b9',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485139522c242d7f10c0b80eb9b9',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Young Mountain',
#                                 'release_date': '2006-06-06',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 6,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:4In2V4QylBdWT8HJ0dLDw5'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0MG4LXIw7n4x0wjDc6WYXk'},
#                                    'href': 'https://api.spotify.com/v1/artists/0MG4LXIw7n4x0wjDc6WYXk',
#                                    'id': '0MG4LXIw7n4x0wjDc6WYXk',
#                                    'name': 'This Will Destroy You',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0MG4LXIw7n4x0wjDc6WYXk'}],
#                       'disc_number': 1,
#                       'duration_ms': 293173,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'US76L0710012'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/4llDF3RuBQYj2nkjTCJY4w'},
#                       'href': 'https://api.spotify.com/v1/tracks/4llDF3RuBQYj2nkjTCJY4w',
#                       'id': '4llDF3RuBQYj2nkjTCJY4w',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Quiet',
#                       'popularity': 46,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/f9d953a91ae45433157d0df05e955bc52f2f3392?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:4llDF3RuBQYj2nkjTCJY4w'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-11-05T22:46:54Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7935eVYpj7jQM3mRJ3kGeX'},
#                                              'href': 'https://api.spotify.com/v1/artists/7935eVYpj7jQM3mRJ3kGeX',
#                                              'id': '7935eVYpj7jQM3mRJ3kGeX',
#                                              'name': 'Exxasens',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7935eVYpj7jQM3mRJ3kGeX'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6tbMoRTY3brzgQfwSzkTGH'},
#                                 'href': 'https://api.spotify.com/v1/albums/6tbMoRTY3brzgQfwSzkTGH',
#                                 'id': '6tbMoRTY3brzgQfwSzkTGH',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2733c1df9e5c56d63e61a16f140',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e023c1df9e5c56d63e61a16f140',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048513c1df9e5c56d63e61a16f140',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Back to Earth',
#                                 'release_date': '2015-09-07',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 8,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6tbMoRTY3brzgQfwSzkTGH'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7935eVYpj7jQM3mRJ3kGeX'},
#                                    'href': 'https://api.spotify.com/v1/artists/7935eVYpj7jQM3mRJ3kGeX',
#                                    'id': '7935eVYpj7jQM3mRJ3kGeX',
#                                    'name': 'Exxasens',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7935eVYpj7jQM3mRJ3kGeX'}],
#                       'disc_number': 1,
#                       'duration_ms': 187066,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'ESA011990699'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3zQqvV121is4wfC3mKSyYA'},
#                       'href': 'https://api.spotify.com/v1/tracks/3zQqvV121is4wfC3mKSyYA',
#                       'id': '3zQqvV121is4wfC3mKSyYA',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0gTjRKnv2AyIQPCRoxCrPX'},
#                                       'href': 'https://api.spotify.com/v1/tracks/0gTjRKnv2AyIQPCRoxCrPX',
#                                       'id': '0gTjRKnv2AyIQPCRoxCrPX',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:0gTjRKnv2AyIQPCRoxCrPX'},
#                       'name': 'Your Dreams Are My Dreams',
#                       'popularity': 35,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/1d6b5f11ccbbd894b2993c06222de9ec2d62ee01?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:3zQqvV121is4wfC3mKSyYA'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-11-05T22:55:05Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21DtKSgtPS1mEUQsSl6y6Y'},
#                                              'href': 'https://api.spotify.com/v1/artists/21DtKSgtPS1mEUQsSl6y6Y',
#                                              'id': '21DtKSgtPS1mEUQsSl6y6Y',
#                                              'name': 'Leech',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:21DtKSgtPS1mEUQsSl6y6Y'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1qLOtV8AJZO4d6qHHt29ol'},
#                                 'href': 'https://api.spotify.com/v1/albums/1qLOtV8AJZO4d6qHHt29ol',
#                                 'id': '1qLOtV8AJZO4d6qHHt29ol',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27390e3be8c18c4bc63b17d6d31',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0290e3be8c18c4bc63b17d6d31',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485190e3be8c18c4bc63b17d6d31',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'The Stolen View',
#                                 'release_date': '2007-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 6,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1qLOtV8AJZO4d6qHHt29ol'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/21DtKSgtPS1mEUQsSl6y6Y'},
#                                    'href': 'https://api.spotify.com/v1/artists/21DtKSgtPS1mEUQsSl6y6Y',
#                                    'id': '21DtKSgtPS1mEUQsSl6y6Y',
#                                    'name': 'Leech',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:21DtKSgtPS1mEUQsSl6y6Y'}],
#                       'disc_number': 1,
#                       'duration_ms': 510440,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'CH7510900523'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/01k0fYnD9sFE89A2zPD38v'},
#                       'href': 'https://api.spotify.com/v1/tracks/01k0fYnD9sFE89A2zPD38v',
#                       'id': '01k0fYnD9sFE89A2zPD38v',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'The Man With The Hammer',
#                       'popularity': 31,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/0dca00ed7a2209f228b3df2fbf43215f6bbad841?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:01k0fYnD9sFE89A2zPD38v'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-11-05T22:56:52Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rRk0aScbAjuf5lAnnTe6n'},
#                                              'href': 'https://api.spotify.com/v1/artists/1rRk0aScbAjuf5lAnnTe6n',
#                                              'id': '1rRk0aScbAjuf5lAnnTe6n',
#                                              'name': 'Jakob',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1rRk0aScbAjuf5lAnnTe6n'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/7jMbWLMw2mJOrIgxFxbPop'},
#                                 'href': 'https://api.spotify.com/v1/albums/7jMbWLMw2mJOrIgxFxbPop',
#                                 'id': '7jMbWLMw2mJOrIgxFxbPop',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2739045c39471b1471a2b0b2870',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e029045c39471b1471a2b0b2870',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048519045c39471b1471a2b0b2870',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Solace',
#                                 'release_date': '2006-11-09',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 8,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:7jMbWLMw2mJOrIgxFxbPop'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rRk0aScbAjuf5lAnnTe6n'},
#                                    'href': 'https://api.spotify.com/v1/artists/1rRk0aScbAjuf5lAnnTe6n',
#                                    'id': '1rRk0aScbAjuf5lAnnTe6n',
#                                    'name': 'Jakob',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1rRk0aScbAjuf5lAnnTe6n'}],
#                       'disc_number': 1,
#                       'duration_ms': 392960,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'NZMI10600001'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0GLOE0S3W89vMCOYanPgf5'},
#                       'href': 'https://api.spotify.com/v1/tracks/0GLOE0S3W89vMCOYanPgf5',
#                       'id': '0GLOE0S3W89vMCOYanPgf5',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0BKHHihvyZdG6beQ5cwPWL'},
#                                       'href': 'https://api.spotify.com/v1/tracks/0BKHHihvyZdG6beQ5cwPWL',
#                                       'id': '0BKHHihvyZdG6beQ5cwPWL',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:0BKHHihvyZdG6beQ5cwPWL'},
#                       'name': 'Malachite',
#                       'popularity': 35,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/fc04896b6c74a9fbc44c6818d32e79965212f0ae?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:0GLOE0S3W89vMCOYanPgf5'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-11-05T23:52:09Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/739AuFSVMsDpObOcslwJRI'},
#                                              'href': 'https://api.spotify.com/v1/artists/739AuFSVMsDpObOcslwJRI',
#                                              'id': '739AuFSVMsDpObOcslwJRI',
#                                              'name': 'April Rain',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:739AuFSVMsDpObOcslwJRI'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/13KNtCQLLYLLzQmHv8vFYp'},
#                                 'href': 'https://api.spotify.com/v1/albums/13KNtCQLLYLLzQmHv8vFYp',
#                                 'id': '13KNtCQLLYLLzQmHv8vFYp',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2736233db52dfa89902accb91e3',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e026233db52dfa89902accb91e3',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048516233db52dfa89902accb91e3',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Waiting for Sunrise',
#                                 'release_date': '2014-08-30',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 10,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:13KNtCQLLYLLzQmHv8vFYp'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/739AuFSVMsDpObOcslwJRI'},
#                                    'href': 'https://api.spotify.com/v1/artists/739AuFSVMsDpObOcslwJRI',
#                                    'id': '739AuFSVMsDpObOcslwJRI',
#                                    'name': 'April Rain',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:739AuFSVMsDpObOcslwJRI'}],
#                       'disc_number': 1,
#                       'duration_ms': 415082,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'AEA0Q2192988'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/4GErLZioCGVHHcy6Elh7dU'},
#                       'href': 'https://api.spotify.com/v1/tracks/4GErLZioCGVHHcy6Elh7dU',
#                       'id': '4GErLZioCGVHHcy6Elh7dU',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2I2DR9udeiHsiaMUhgKPoo'},
#                                       'href': 'https://api.spotify.com/v1/tracks/2I2DR9udeiHsiaMUhgKPoo',
#                                       'id': '2I2DR9udeiHsiaMUhgKPoo',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:2I2DR9udeiHsiaMUhgKPoo'},
#                       'name': 'Come Back Quicker Please',
#                       'popularity': 30,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/f6a579a90c5654c31bbe20df634fbc8cd5b26908?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:4GErLZioCGVHHcy6Elh7dU'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2019-11-06T08:23:32Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0mwbAhNgoHdpzdahGIsAUs'},
#                                              'href': 'https://api.spotify.com/v1/artists/0mwbAhNgoHdpzdahGIsAUs',
#                                              'id': '0mwbAhNgoHdpzdahGIsAUs',
#                                              'name': 'The Seven Mile Journey',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:0mwbAhNgoHdpzdahGIsAUs'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/769ShcHbbjhaUX9rdAArAr'},
#                                 'href': 'https://api.spotify.com/v1/albums/769ShcHbbjhaUX9rdAArAr',
#                                 'id': '769ShcHbbjhaUX9rdAArAr',
#                                 'images': [{'height': 640,
# ...
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eV1lwtIFk1zlao9llmRTn'},
#                                              'href': 'https://api.spotify.com/v1/artists/5eV1lwtIFk1zlao9llmRTn',
#                                              'id': '5eV1lwtIFk1zlao9llmRTn',
#                                              'name': 'Gazelles',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5eV1lwtIFk1zlao9llmRTn'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/543bpgL9PYMcgjHd8ysAn0'},
#                                 'href': 'https://api.spotify.com/v1/albums/543bpgL9PYMcgjHd8ysAn0',
#                                 'id': '543bpgL9PYMcgjHd8ysAn0',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273fdeb537401d0400ebf54d77a',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02fdeb537401d0400ebf54d77a',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851fdeb537401d0400ebf54d77a',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': "There's No One New Around You",
#                                 'release_date': '2017-10-20',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 7,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:543bpgL9PYMcgjHd8ysAn0'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5eV1lwtIFk1zlao9llmRTn'},
#                                    'href': 'https://api.spotify.com/v1/artists/5eV1lwtIFk1zlao9llmRTn',
#                                    'id': '5eV1lwtIFk1zlao9llmRTn',
#                                    'name': 'Gazelles',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5eV1lwtIFk1zlao9llmRTn'}],
#                       'disc_number': 1,
#                       'duration_ms': 432634,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'TCADH1715504'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/49AtitzqZS8BvLNJyW4X07'},
#                       'href': 'https://api.spotify.com/v1/tracks/49AtitzqZS8BvLNJyW4X07',
#                       'id': '49AtitzqZS8BvLNJyW4X07',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Great White Black',
#                       'popularity': 12,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/593ad92bd79da112083fbde8c2b5cbf6313a5fc7?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:49AtitzqZS8BvLNJyW4X07'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2020-05-20T20:11:11Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'single',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7yJoUbl6dOkkkUbVkbsonA'},
#                                              'href': 'https://api.spotify.com/v1/artists/7yJoUbl6dOkkkUbVkbsonA',
#                                              'id': '7yJoUbl6dOkkkUbVkbsonA',
#                                              'name': 'In Two We Break',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:7yJoUbl6dOkkkUbVkbsonA'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5jz00ik0UqH7tV2dSCxvKR'},
#                                 'href': 'https://api.spotify.com/v1/albums/5jz00ik0UqH7tV2dSCxvKR',
#                                 'id': '5jz00ik0UqH7tV2dSCxvKR',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2732aaff319f0d41d73dd834647',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e022aaff319f0d41d73dd834647',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048512aaff319f0d41d73dd834647',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Out of the Light',
#                                 'release_date': '2020-04-20',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 5,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5jz00ik0UqH7tV2dSCxvKR'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7yJoUbl6dOkkkUbVkbsonA'},
#                                    'href': 'https://api.spotify.com/v1/artists/7yJoUbl6dOkkkUbVkbsonA',
#                                    'id': '7yJoUbl6dOkkkUbVkbsonA',
#                                    'name': 'In Two We Break',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:7yJoUbl6dOkkkUbVkbsonA'}],
#                       'disc_number': 1,
#                       'duration_ms': 334322,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'TCAET2082926'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/59IufJecoIwUJjnLjy0czz'},
#                       'href': 'https://api.spotify.com/v1/tracks/59IufJecoIwUJjnLjy0czz',
#                       'id': '59IufJecoIwUJjnLjy0czz',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Law of Club and Fang',
#                       'popularity': 12,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/58acf5996d5bb7a5cde7054d724500be50a9f1c4?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:59IufJecoIwUJjnLjy0czz'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2020-05-22T10:56:37Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1V85uZNnreRvRvV3kVK4Ku'},
#                                              'href': 'https://api.spotify.com/v1/artists/1V85uZNnreRvRvV3kVK4Ku',
#                                              'id': '1V85uZNnreRvRvV3kVK4Ku',
#                                              'name': 'Egoera',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1V85uZNnreRvRvV3kVK4Ku'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0lcWQHzk1taKoTqJTzE4pf'},
#                                 'href': 'https://api.spotify.com/v1/albums/0lcWQHzk1taKoTqJTzE4pf',
#                                 'id': '0lcWQHzk1taKoTqJTzE4pf',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273cd623f80d3a0ddf08a6e1dac',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02cd623f80d3a0ddf08a6e1dac',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851cd623f80d3a0ddf08a6e1dac',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Fortuna',
#                                 'release_date': '2020-04-30',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 7,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0lcWQHzk1taKoTqJTzE4pf'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1V85uZNnreRvRvV3kVK4Ku'},
#                                    'href': 'https://api.spotify.com/v1/artists/1V85uZNnreRvRvV3kVK4Ku',
#                                    'id': '1V85uZNnreRvRvV3kVK4Ku',
#                                    'name': 'Egoera',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1V85uZNnreRvRvV3kVK4Ku'}],
#                       'disc_number': 1,
#                       'duration_ms': 315457,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'usdy42027169'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/2PRSNJbOWptRyOtM8y0FUX'},
#                       'href': 'https://api.spotify.com/v1/tracks/2PRSNJbOWptRyOtM8y0FUX',
#                       'id': '2PRSNJbOWptRyOtM8y0FUX',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Hiru',
#                       'popularity': 13,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/3999744730df794e456141b17ccd9696368a8b3d?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:2PRSNJbOWptRyOtM8y0FUX'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2020-05-22T10:56:44Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/20oxoq89bzf5r8uf5x54v3k8a'},
#                          'href': 'https://api.spotify.com/v1/users/20oxoq89bzf5r8uf5x54v3k8a',
#                          'id': '20oxoq89bzf5r8uf5x54v3k8a',
#                          'type': 'user',
#                          'uri': 'spotify:user:20oxoq89bzf5r8uf5x54v3k8a'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1V85uZNnreRvRvV3kVK4Ku'},
#                                              'href': 'https://api.spotify.com/v1/artists/1V85uZNnreRvRvV3kVK4Ku',
#                                              'id': '1V85uZNnreRvRvV3kVK4Ku',
#                                              'name': 'Egoera',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1V85uZNnreRvRvV3kVK4Ku'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0lcWQHzk1taKoTqJTzE4pf'},
#                                 'href': 'https://api.spotify.com/v1/albums/0lcWQHzk1taKoTqJTzE4pf',
#                                 'id': '0lcWQHzk1taKoTqJTzE4pf',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273cd623f80d3a0ddf08a6e1dac',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02cd623f80d3a0ddf08a6e1dac',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851cd623f80d3a0ddf08a6e1dac',
#                                             'width': 64}],
#                                 'is_playable': True,
#                                 'name': 'Fortuna',
#                                 'release_date': '2020-04-30',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 7,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0lcWQHzk1taKoTqJTzE4pf'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1V85uZNnreRvRvV3kVK4Ku'},
#                                    'href': 'https://api.spotify.com/v1/artists/1V85uZNnreRvRvV3kVK4Ku',
#                                    'id': '1V85uZNnreRvRvV3kVK4Ku',
#                                    'name': 'Egoera',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1V85uZNnreRvRvV3kVK4Ku'}],
#                       'disc_number': 1,
#                       'duration_ms': 379942,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'usdy42070493'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/7gmYuNTOzbTFVUMrzOIg6B'},
#                       'href': 'https://api.spotify.com/v1/tracks/7gmYuNTOzbTFVUMrzOIg6B',
#                       'id': '7gmYuNTOzbTFVUMrzOIg6B',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Fortuna',
#                       'popularity': 14,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/e59a7ec6d64a849edfc39b531255f9eb08bc68c7?cid=bda81a37da0a4c3397c9dd7cd2949b4d',
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:7gmYuNTOzbTFVUMrzOIg6B'},
#             'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/4ebKOuGNfJ5g8RdtbEBHxe/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 248}

# %%
playlist["items"][0]["track"]["id"]
# Out:
# '61lyAGlyT5DOYWVtJ3OdLz'

# %%
play_song(playlist["items"][0]["track"]["id"])
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/61lyAGlyT5DOYWVtJ3OdLz?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) #  Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  248
# 100

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
sp.audio_features(bob_dylan_id_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sp.audio_features(bob_dylan_id_list)
#
# NameError: name 'bob_dylan_id_list' is not defined

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
spanish_tracks = get_playlist_tracks("Spotify","37i9dQZF1EQpj7X7UK8OOF")

spanish_ids = []
for i in spanish_tracks:
    spanish_ids.append(i['track']['id'])
 
af = sp.audio_features(spanish_ids)

# %%
len(spanish_tracks)
# Out:
# 50

# %%
spanish_ids = []
for i in spanish_tracks:
    spanish_ids.append(i['track']['id'])

# %%
len(spanish_ids)
# Out:
# 50

# %%
spanish_ids
# Out:
# ['2LawezPeJhN4AWuSB0GtAU',
#  '60a0Rd6pjrkxjPbaKzXjfq',
#  '70LcF31zb1H0PyJoS1Sx1r',
#  '2DlHlPMa4M17kufBvI2lEN',
#  '0hCB0YR03f6AmQaHbwWDe8',
#  '1xsYj84j7hUDDnTTerGWlH',
#  '63T7DJ1AFDD6Bn8VzG6JE8',
#  '37ZJ0p5Jm13JPevGcx4SkF',
#  '0nLiqZ6A27jJri2VCalIUs',
#  '0snQkGI5qnAmohLE7jTsTn',
#  '78lgmZwycJ3nzsdgmPPGNx',
#  '6TfBA04WJ3X1d1wXhaCFVT',
#  '11LmqTE2naFULdEP94AUBa',
#  '2SiXAy7TuUkycRVbbWDEpo',
#  '63OFKbMaZSDZ4wtesuuq6f',
#  '7sqp1w76zjW3K04htuRA8H',
#  '3qT4bUD1MaWpGrTwcvguhb',
#  '4JfuiOWlWCkjP6OKurHjSn',
#  '59WN2psjkt1tyaxjspN8fp',
#  '2zYzyRzz6pRmhPzyfMEC8s',
#  '64BbK9SFKH2jk86U3dGj2P',
#  '6gZVQvQZOFpzIy3HblJ20F',
#  '6KTv0Z8BmVqM7DPxbGzpVC',
#  '73TxYZd0lBCVRrHawrAglA',
#  '0C80GCp0mMuBzLf3EAXqxv',
#  '755bvJDSA3LNcNuFgBT9LK',
#  '7e89621JPkKaeDSTQ3avtg',
#  '5Rizj5FLb2AyNKu9esjYY6',
#  '6gQUbFwwdYXlKdmqRoWKJe',
#  '64yrDBpcdwEdNY9loyEGbX',
#  '57bgtoPSgt236HzfBOd8kj',
#  '1FTSo4v6BOZH9QxKc3MbVM',
#  '0v1XpBHnsbkCn7iJ9Ucr1l',
#  '2m1hi0nfMR9vdGC8UcrnwU',
#  '5XcZRgJv3zMhTqCyESjQrF',
#  '31RTFPrB7wmYBhlkM2ILXG',
#  '5G1sTBGbZT5o4PNRc75RKI',
#  '5EWPGh7jbTNO2wakv8LjUI',
#  '23IJ5wLRhEZ9DOuia5mPiZ',
#  '3ZOEytgrvLwQaqXreDs2Jx',
#  '60a5c4dDARPsksClcom0OD',
#  '6gCVA6ja6g0foIsWv0RuSZ',
#  '7HKez549fwJQDzx3zLjHKC',
#  '1wsRitfRRtWyEapl0q22o8',
#  '46QazXxQS0B31CnbRCy8CV',
#  '1f2V8U1BiWaC9aJWmpOARe',
#  '6eN1f9KNmiWEhpE2RhQqB5',
#  '70Z9t1qhytWtG4cCmmi7mU',
#  '4EchqUKQ3qAQuRNKmeIpnf',
#  '43DeSV93pJPT4lCZaWZ6b1']

# %%
af = sp.audio_features(spanish_ids)

# %%
af
# Out:
# [{'danceability': 0.741,
#   'energy': 0.697,
#   'key': 0,
#   'loudness': -7.028,
#   'mode': 1,
#   'speechiness': 0.0277,
#   'acousticness': 0.0664,
#   'instrumentalness': 2.28e-05,
#   'liveness': 0.133,
#   'valence': 0.774,
#   'tempo': 116.109,
#   'type': 'audio_features',
#   'id': '2LawezPeJhN4AWuSB0GtAU',
#   'uri': 'spotify:track:2LawezPeJhN4AWuSB0GtAU',
#   'track_href': 'https://api.spotify.com/v1/tracks/2LawezPeJhN4AWuSB0GtAU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2LawezPeJhN4AWuSB0GtAU',
#   'duration_ms': 160133,
#   'time_signature': 4},
#  {'danceability': 0.556,
#   'energy': 0.864,
#   'key': 3,
#   'loudness': -5.87,
#   'mode': 0,
#   'speechiness': 0.0584,
#   'acousticness': 0.00958,
#   'instrumentalness': 0,
#   'liveness': 0.209,
#   'valence': 0.4,
#   'tempo': 105.143,
#   'type': 'audio_features',
#   'id': '60a0Rd6pjrkxjPbaKzXjfq',
#   'uri': 'spotify:track:60a0Rd6pjrkxjPbaKzXjfq',
#   'track_href': 'https://api.spotify.com/v1/tracks/60a0Rd6pjrkxjPbaKzXjfq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60a0Rd6pjrkxjPbaKzXjfq',
#   'duration_ms': 216880,
#   'time_signature': 4},
#  {'danceability': 0.515,
#   'energy': 0.43,
#   'key': 7,
#   'loudness': -9.935,
#   'mode': 1,
#   'speechiness': 0.0372,
#   'acousticness': 0.0097,
#   'instrumentalness': 0.000133,
#   'liveness': 0.129,
#   'valence': 0.104,
#   'tempo': 91.844,
#   'type': 'audio_features',
#   'id': '70LcF31zb1H0PyJoS1Sx1r',
#   'uri': 'spotify:track:70LcF31zb1H0PyJoS1Sx1r',
#   'track_href': 'https://api.spotify.com/v1/tracks/70LcF31zb1H0PyJoS1Sx1r',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/70LcF31zb1H0PyJoS1Sx1r',
#   'duration_ms': 238640,
#   'time_signature': 4},
#  {'danceability': 0.417,
#   'energy': 0.934,
#   'key': 7,
#   'loudness': -3.908,
#   'mode': 0,
#   'speechiness': 0.119,
#   'acousticness': 0.000278,
#   'instrumentalness': 0.0015,
#   'liveness': 0.132,
#   'valence': 0.287,
#   'tempo': 127.066,
#   'type': 'audio_features',
#   'id': '2DlHlPMa4M17kufBvI2lEN',
#   'uri': 'spotify:track:2DlHlPMa4M17kufBvI2lEN',
#   'track_href': 'https://api.spotify.com/v1/tracks/2DlHlPMa4M17kufBvI2lEN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2DlHlPMa4M17kufBvI2lEN',
#   'duration_ms': 210240,
#   'time_signature': 4},
#  {'danceability': 0.412,
#   'energy': 0.902,
#   'key': 9,
#   'loudness': -11.6,
#   'mode': 1,
#   'speechiness': 0.405,
#   'acousticness': 0.0484,
#   'instrumentalness': 0.131,
#   'liveness': 0.405,
#   'valence': 0.422,
#   'tempo': 89.74,
#   'type': 'audio_features',
#   'id': '0hCB0YR03f6AmQaHbwWDe8',
#   'uri': 'spotify:track:0hCB0YR03f6AmQaHbwWDe8',
#   'track_href': 'https://api.spotify.com/v1/tracks/0hCB0YR03f6AmQaHbwWDe8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0hCB0YR03f6AmQaHbwWDe8',
#   'duration_ms': 333893,
#   'time_signature': 4},
#  {'danceability': 0.392,
#   'energy': 0.476,
#   'key': 1,
#   'loudness': -7.583,
#   'mode': 1,
#   'speechiness': 0.0249,
#   'acousticness': 0.397,
#   'instrumentalness': 0.000163,
#   'liveness': 0.309,
#   'valence': 0.234,
#   'tempo': 78.031,
#   'type': 'audio_features',
#   'id': '1xsYj84j7hUDDnTTerGWlH',
#   'uri': 'spotify:track:1xsYj84j7hUDDnTTerGWlH',
#   'track_href': 'https://api.spotify.com/v1/tracks/1xsYj84j7hUDDnTTerGWlH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1xsYj84j7hUDDnTTerGWlH',
#   'duration_ms': 267597,
#   'time_signature': 4},
#  {'danceability': 0.464,
#   'energy': 0.795,
#   'key': 1,
#   'loudness': -9.267,
#   'mode': 1,
#   'speechiness': 0.0926,
#   'acousticness': 0.0493,
#   'instrumentalness': 0.00244,
#   'liveness': 0.399,
#   'valence': 0.612,
#   'tempo': 158.691,
#   'type': 'audio_features',
#   'id': '63T7DJ1AFDD6Bn8VzG6JE8',
#   'uri': 'spotify:track:63T7DJ1AFDD6Bn8VzG6JE8',
#   'track_href': 'https://api.spotify.com/v1/tracks/63T7DJ1AFDD6Bn8VzG6JE8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/63T7DJ1AFDD6Bn8VzG6JE8',
#   'duration_ms': 202267,
#   'time_signature': 4},
#  {'danceability': 0.532,
#   'energy': 0.887,
#   'key': 0,
#   'loudness': -3.757,
#   'mode': 1,
#   'speechiness': 0.0335,
#   'acousticness': 0.0778,
#   'instrumentalness': 0.000214,
#   'liveness': 0.294,
#   'valence': 0.795,
#   'tempo': 122.511,
#   'type': 'audio_features',
#   'id': '37ZJ0p5Jm13JPevGcx4SkF',
#   'uri': 'spotify:track:37ZJ0p5Jm13JPevGcx4SkF',
#   'track_href': 'https://api.spotify.com/v1/tracks/37ZJ0p5Jm13JPevGcx4SkF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37ZJ0p5Jm13JPevGcx4SkF',
#   'duration_ms': 249293,
#   'time_signature': 4},
#  {'danceability': 0.553,
#   'energy': 0.362,
#   'key': 4,
#   'loudness': -11.218,
#   'mode': 0,
#   'speechiness': 0.0263,
#   'acousticness': 0.0458,
#   'instrumentalness': 6.01e-06,
#   'liveness': 0.075,
#   'valence': 0.158,
#   'tempo': 142.352,
#   'type': 'audio_features',
#   'id': '0nLiqZ6A27jJri2VCalIUs',
#   'uri': 'spotify:track:0nLiqZ6A27jJri2VCalIUs',
#   'track_href': 'https://api.spotify.com/v1/tracks/0nLiqZ6A27jJri2VCalIUs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0nLiqZ6A27jJri2VCalIUs',
#   'duration_ms': 388267,
#   'time_signature': 3},
#  {'danceability': 0.413,
#   'energy': 0.873,
#   'key': 8,
#   'loudness': -4.151,
#   'mode': 1,
#   'speechiness': 0.0536,
#   'acousticness': 0.000264,
#   'instrumentalness': 0.00249,
#   'liveness': 0.204,
#   'valence': 0.48,
#   'tempo': 116.68,
#   'type': 'audio_features',
#   'id': '0snQkGI5qnAmohLE7jTsTn',
#   'uri': 'spotify:track:0snQkGI5qnAmohLE7jTsTn',
#   'track_href': 'https://api.spotify.com/v1/tracks/0snQkGI5qnAmohLE7jTsTn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0snQkGI5qnAmohLE7jTsTn',
#   'duration_ms': 218933,
#   'time_signature': 3},
#  {'danceability': 0.564,
#   'energy': 0.932,
#   'key': 11,
#   'loudness': -10.068,
#   'mode': 1,
#   'speechiness': 0.0554,
#   'acousticness': 0.013,
#   'instrumentalness': 0.169,
#   'liveness': 0.349,
#   'valence': 0.619,
#   'tempo': 112.937,
#   'type': 'audio_features',
#   'id': '78lgmZwycJ3nzsdgmPPGNx',
#   'uri': 'spotify:track:78lgmZwycJ3nzsdgmPPGNx',
#   'track_href': 'https://api.spotify.com/v1/tracks/78lgmZwycJ3nzsdgmPPGNx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78lgmZwycJ3nzsdgmPPGNx',
#   'duration_ms': 146250,
#   'time_signature': 4},
#  {'danceability': 0.55,
#   'energy': 0.917,
#   'key': 0,
#   'loudness': -3.159,
#   'mode': 1,
#   'speechiness': 0.0638,
#   'acousticness': 0.00428,
#   'instrumentalness': 0,
#   'liveness': 0.197,
#   'valence': 0.601,
#   'tempo': 126.115,
#   'type': 'audio_features',
#   'id': '6TfBA04WJ3X1d1wXhaCFVT',
#   'uri': 'spotify:track:6TfBA04WJ3X1d1wXhaCFVT',
#   'track_href': 'https://api.spotify.com/v1/tracks/6TfBA04WJ3X1d1wXhaCFVT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6TfBA04WJ3X1d1wXhaCFVT',
#   'duration_ms': 177827,
#   'time_signature': 4},
#  {'danceability': 0.256,
#   'energy': 0.641,
#   'key': 1,
#   'loudness': -10.283,
#   'mode': 1,
#   'speechiness': 0.0552,
#   'acousticness': 0.199,
#   'instrumentalness': 0.0329,
#   'liveness': 0.0853,
#   'valence': 0.382,
#   'tempo': 203.006,
#   'type': 'audio_features',
#   'id': '11LmqTE2naFULdEP94AUBa',
#   'uri': 'spotify:track:11LmqTE2naFULdEP94AUBa',
#   'track_href': 'https://api.spotify.com/v1/tracks/11LmqTE2naFULdEP94AUBa',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11LmqTE2naFULdEP94AUBa',
#   'duration_ms': 281160,
#   'time_signature': 4},
#  {'danceability': 0.532,
#   'energy': 0.767,
#   'key': 7,
#   'loudness': -5.509,
#   'mode': 1,
#   'speechiness': 0.0574,
#   'acousticness': 0.00287,
#   'instrumentalness': 0.000513,
#   'liveness': 0.39,
#   'valence': 0.755,
#   'tempo': 127.361,
#   'type': 'audio_features',
#   'id': '2SiXAy7TuUkycRVbbWDEpo',
#   'uri': 'spotify:track:2SiXAy7TuUkycRVbbWDEpo',
#   'track_href': 'https://api.spotify.com/v1/tracks/2SiXAy7TuUkycRVbbWDEpo',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2SiXAy7TuUkycRVbbWDEpo',
#   'duration_ms': 210173,
#   'time_signature': 4},
#  {'danceability': 0.438,
#   'energy': 0.71,
#   'key': 2,
#   'loudness': -12.412,
#   'mode': 1,
#   'speechiness': 0.0919,
#   'acousticness': 0.262,
#   'instrumentalness': 0.537,
#   'liveness': 0.221,
#   'valence': 0.53,
#   'tempo': 145.928,
#   'type': 'audio_features',
#   'id': '63OFKbMaZSDZ4wtesuuq6f',
#   'uri': 'spotify:track:63OFKbMaZSDZ4wtesuuq6f',
#   'track_href': 'https://api.spotify.com/v1/tracks/63OFKbMaZSDZ4wtesuuq6f',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/63OFKbMaZSDZ4wtesuuq6f',
#   'duration_ms': 210373,
#   'time_signature': 4},
#  {'danceability': 0.433,
#   'energy': 0.842,
#   'key': 11,
#   'loudness': -3.513,
#   'mode': 0,
#   'speechiness': 0.0544,
#   'acousticness': 0.134,
#   'instrumentalness': 0,
#   'liveness': 0.16,
#   'valence': 0.341,
#   'tempo': 116.558,
#   'type': 'audio_features',
#   'id': '7sqp1w76zjW3K04htuRA8H',
#   'uri': 'spotify:track:7sqp1w76zjW3K04htuRA8H',
#   'track_href': 'https://api.spotify.com/v1/tracks/7sqp1w76zjW3K04htuRA8H',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7sqp1w76zjW3K04htuRA8H',
#   'duration_ms': 278973,
#   'time_signature': 4},
#  {'danceability': 0.437,
#   'energy': 0.864,
#   'key': 4,
#   'loudness': -7.842,
#   'mode': 0,
#   'speechiness': 0.0904,
#   'acousticness': 0.396,
#   'instrumentalness': 0.0314,
#   'liveness': 0.242,
#   'valence': 0.749,
#   'tempo': 81.394,
#   'type': 'audio_features',
#   'id': '3qT4bUD1MaWpGrTwcvguhb',
#   'uri': 'spotify:track:3qT4bUD1MaWpGrTwcvguhb',
#   'track_href': 'https://api.spotify.com/v1/tracks/3qT4bUD1MaWpGrTwcvguhb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3qT4bUD1MaWpGrTwcvguhb',
#   'duration_ms': 295387,
#   'time_signature': 4},
#  {'danceability': 0.653,
#   'energy': 0.73,
#   'key': 5,
#   'loudness': -10.613,
#   'mode': 1,
#   'speechiness': 0.0429,
#   'acousticness': 0.0115,
#   'instrumentalness': 1.02e-05,
#   'liveness': 0.0776,
#   'valence': 0.894,
#   'tempo': 108.709,
#   'type': 'audio_features',
#   'id': '4JfuiOWlWCkjP6OKurHjSn',
#   'uri': 'spotify:track:4JfuiOWlWCkjP6OKurHjSn',
#   'track_href': 'https://api.spotify.com/v1/tracks/4JfuiOWlWCkjP6OKurHjSn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4JfuiOWlWCkjP6OKurHjSn',
#   'duration_ms': 220311,
#   'time_signature': 4},
#  {'danceability': 0.466,
#   'energy': 0.833,
#   'key': 7,
#   'loudness': -4.215,
#   'mode': 1,
#   'speechiness': 0.304,
#   'acousticness': 0.0266,
#   'instrumentalness': 0,
#   'liveness': 0.0327,
#   'valence': 0.661,
#   'tempo': 88.785,
#   'type': 'audio_features',
#   'id': '59WN2psjkt1tyaxjspN8fp',
#   'uri': 'spotify:track:59WN2psjkt1tyaxjspN8fp',
#   'track_href': 'https://api.spotify.com/v1/tracks/59WN2psjkt1tyaxjspN8fp',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/59WN2psjkt1tyaxjspN8fp',
#   'duration_ms': 313573,
#   'time_signature': 4},
#  {'danceability': 0.574,
#   'energy': 0.913,
#   'key': 6,
#   'loudness': -4.793,
#   'mode': 0,
#   'speechiness': 0.133,
#   'acousticness': 0.061,
#   'instrumentalness': 0.00158,
#   'liveness': 0.156,
#   'valence': 0.423,
#   'tempo': 115.728,
#   'type': 'audio_features',
#   'id': '2zYzyRzz6pRmhPzyfMEC8s',
#   'uri': 'spotify:track:2zYzyRzz6pRmhPzyfMEC8s',
#   'track_href': 'https://api.spotify.com/v1/tracks/2zYzyRzz6pRmhPzyfMEC8s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2zYzyRzz6pRmhPzyfMEC8s',
#   'duration_ms': 208400,
#   'time_signature': 4},
#  {'danceability': 0.458,
#   'energy': 0.795,
#   'key': 0,
#   'loudness': -3.265,
#   'mode': 1,
#   'speechiness': 0.0574,
#   'acousticness': 0.00316,
#   'instrumentalness': 0.000202,
#   'liveness': 0.0756,
#   'valence': 0.513,
#   'tempo': 123.229,
#   'type': 'audio_features',
#   'id': '64BbK9SFKH2jk86U3dGj2P',
#   'uri': 'spotify:track:64BbK9SFKH2jk86U3dGj2P',
#   'track_href': 'https://api.spotify.com/v1/tracks/64BbK9SFKH2jk86U3dGj2P',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/64BbK9SFKH2jk86U3dGj2P',
#   'duration_ms': 255373,
#   'time_signature': 4},
#  {'danceability': 0.355,
#   'energy': 0.791,
#   'key': 8,
#   'loudness': -7.565,
#   'mode': 1,
#   'speechiness': 0.0453,
#   'acousticness': 0.00045,
#   'instrumentalness': 0,
#   'liveness': 0.0969,
#   'valence': 0.758,
#   'tempo': 106.392,
#   'type': 'audio_features',
#   'id': '6gZVQvQZOFpzIy3HblJ20F',
#   'uri': 'spotify:track:6gZVQvQZOFpzIy3HblJ20F',
#   'track_href': 'https://api.spotify.com/v1/tracks/6gZVQvQZOFpzIy3HblJ20F',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6gZVQvQZOFpzIy3HblJ20F',
#   'duration_ms': 285200,
#   'time_signature': 4},
#  {'danceability': 0.654,
#   'energy': 0.929,
#   'key': 1,
#   'loudness': -5.906,
#   'mode': 1,
#   'speechiness': 0.0998,
#   'acousticness': 0.0468,
#   'instrumentalness': 0,
#   'liveness': 0.0539,
#   'valence': 0.902,
#   'tempo': 144.774,
#   'type': 'audio_features',
#   'id': '6KTv0Z8BmVqM7DPxbGzpVC',
#   'uri': 'spotify:track:6KTv0Z8BmVqM7DPxbGzpVC',
#   'track_href': 'https://api.spotify.com/v1/tracks/6KTv0Z8BmVqM7DPxbGzpVC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6KTv0Z8BmVqM7DPxbGzpVC',
#   'duration_ms': 168840,
#   'time_signature': 4},
#  {'danceability': 0.379,
#   'energy': 0.76,
#   'key': 9,
#   'loudness': -10.961,
#   'mode': 1,
#   'speechiness': 0.0378,
#   'acousticness': 0.00298,
#   'instrumentalness': 0.0296,
#   'liveness': 0.104,
#   'valence': 0.491,
#   'tempo': 99.436,
#   'type': 'audio_features',
#   'id': '73TxYZd0lBCVRrHawrAglA',
#   'uri': 'spotify:track:73TxYZd0lBCVRrHawrAglA',
#   'track_href': 'https://api.spotify.com/v1/tracks/73TxYZd0lBCVRrHawrAglA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/73TxYZd0lBCVRrHawrAglA',
#   'duration_ms': 274088,
#   'time_signature': 4},
#  {'danceability': 0.457,
#   'energy': 0.904,
#   'key': 2,
#   'loudness': -5.303,
#   'mode': 1,
#   'speechiness': 0.0747,
#   'acousticness': 0.000239,
#   'instrumentalness': 0.0879,
#   'liveness': 0.396,
#   'valence': 0.48,
#   'tempo': 141.038,
#   'type': 'audio_features',
#   'id': '0C80GCp0mMuBzLf3EAXqxv',
#   'uri': 'spotify:track:0C80GCp0mMuBzLf3EAXqxv',
#   'track_href': 'https://api.spotify.com/v1/tracks/0C80GCp0mMuBzLf3EAXqxv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0C80GCp0mMuBzLf3EAXqxv',
#   'duration_ms': 317427,
#   'time_signature': 4},
#  {'danceability': 0.334,
#   'energy': 0.828,
#   'key': 9,
#   'loudness': -9.168,
#   'mode': 1,
#   'speechiness': 0.0985,
#   'acousticness': 0.00312,
#   'instrumentalness': 0.0043,
#   'liveness': 0.0949,
#   'valence': 0.515,
#   'tempo': 157.891,
#   'type': 'audio_features',
#   'id': '755bvJDSA3LNcNuFgBT9LK',
#   'uri': 'spotify:track:755bvJDSA3LNcNuFgBT9LK',
#   'track_href': 'https://api.spotify.com/v1/tracks/755bvJDSA3LNcNuFgBT9LK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/755bvJDSA3LNcNuFgBT9LK',
#   'duration_ms': 354213,
#   'time_signature': 4},
#  {'danceability': 0.596,
#   'energy': 0.605,
#   'key': 7,
#   'loudness': -12.145,
#   'mode': 1,
#   'speechiness': 0.0255,
#   'acousticness': 0.181,
#   'instrumentalness': 0.000331,
#   'liveness': 0.0863,
#   'valence': 0.886,
#   'tempo': 97.798,
#   'type': 'audio_features',
#   'id': '7e89621JPkKaeDSTQ3avtg',
#   'uri': 'spotify:track:7e89621JPkKaeDSTQ3avtg',
#   'track_href': 'https://api.spotify.com/v1/tracks/7e89621JPkKaeDSTQ3avtg',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7e89621JPkKaeDSTQ3avtg',
#   'duration_ms': 283800,
#   'time_signature': 4},
#  {'danceability': 0.42,
#   'energy': 0.746,
#   'key': 8,
#   'loudness': -10.628,
#   'mode': 1,
#   'speechiness': 0.0467,
#   'acousticness': 0.0141,
#   'instrumentalness': 0,
#   'liveness': 0.0661,
#   'valence': 0.229,
#   'tempo': 111.886,
#   'type': 'audio_features',
#   'id': '5Rizj5FLb2AyNKu9esjYY6',
#   'uri': 'spotify:track:5Rizj5FLb2AyNKu9esjYY6',
#   'track_href': 'https://api.spotify.com/v1/tracks/5Rizj5FLb2AyNKu9esjYY6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Rizj5FLb2AyNKu9esjYY6',
#   'duration_ms': 170000,
#   'time_signature': 4},
#  {'danceability': 0.54,
#   'energy': 0.982,
#   'key': 4,
#   'loudness': -2.962,
#   'mode': 0,
#   'speechiness': 0.0458,
#   'acousticness': 0.435,
#   'instrumentalness': 3.37e-05,
#   'liveness': 0.0457,
#   'valence': 0.91,
#   'tempo': 126.294,
#   'type': 'audio_features',
#   'id': '6gQUbFwwdYXlKdmqRoWKJe',
#   'uri': 'spotify:track:6gQUbFwwdYXlKdmqRoWKJe',
#   'track_href': 'https://api.spotify.com/v1/tracks/6gQUbFwwdYXlKdmqRoWKJe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6gQUbFwwdYXlKdmqRoWKJe',
#   'duration_ms': 265773,
#   'time_signature': 4},
#  {'danceability': 0.268,
#   'energy': 0.742,
#   'key': 5,
#   'loudness': -4.939,
#   'mode': 1,
#   'speechiness': 0.0355,
#   'acousticness': 0.0518,
#   'instrumentalness': 0,
#   'liveness': 0.626,
#   'valence': 0.416,
#   'tempo': 159.779,
#   'type': 'audio_features',
#   'id': '64yrDBpcdwEdNY9loyEGbX',
#   'uri': 'spotify:track:64yrDBpcdwEdNY9loyEGbX',
#   'track_href': 'https://api.spotify.com/v1/tracks/64yrDBpcdwEdNY9loyEGbX',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/64yrDBpcdwEdNY9loyEGbX',
#   'duration_ms': 321093,
#   'time_signature': 4},
#  {'danceability': 0.502,
#   'energy': 0.89,
#   'key': 4,
#   'loudness': -5.175,
#   'mode': 1,
#   'speechiness': 0.0364,
#   'acousticness': 0.000147,
#   'instrumentalness': 0.0117,
#   'liveness': 0.217,
#   'valence': 0.259,
#   'tempo': 133.52,
#   'type': 'audio_features',
#   'id': '57bgtoPSgt236HzfBOd8kj',
#   'uri': 'spotify:track:57bgtoPSgt236HzfBOd8kj',
#   'track_href': 'https://api.spotify.com/v1/tracks/57bgtoPSgt236HzfBOd8kj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57bgtoPSgt236HzfBOd8kj',
#   'duration_ms': 292880,
#   'time_signature': 4},
#  {'danceability': 0.674,
#   'energy': 0.789,
#   'key': 8,
#   'loudness': -6.903,
#   'mode': 1,
#   'speechiness': 0.0676,
#   'acousticness': 0.00178,
#   'instrumentalness': 0.00708,
#   'liveness': 0.0753,
#   'valence': 0.918,
#   'tempo': 129.802,
#   'type': 'audio_features',
#   'id': '1FTSo4v6BOZH9QxKc3MbVM',
#   'uri': 'spotify:track:1FTSo4v6BOZH9QxKc3MbVM',
#   'track_href': 'https://api.spotify.com/v1/tracks/1FTSo4v6BOZH9QxKc3MbVM',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1FTSo4v6BOZH9QxKc3MbVM',
#   'duration_ms': 121160,
#   'time_signature': 4},
#  {'danceability': 0.551,
#   'energy': 0.913,
#   'key': 0,
#   'loudness': -4.063,
#   'mode': 0,
#   'speechiness': 0.0466,
#   'acousticness': 0.0263,
#   'instrumentalness': 1.35e-05,
#   'liveness': 0.347,
#   'valence': 0.544,
#   'tempo': 119.992,
#   'type': 'audio_features',
#   'id': '0v1XpBHnsbkCn7iJ9Ucr1l',
#   'uri': 'spotify:track:0v1XpBHnsbkCn7iJ9Ucr1l',
#   'track_href': 'https://api.spotify.com/v1/tracks/0v1XpBHnsbkCn7iJ9Ucr1l',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0v1XpBHnsbkCn7iJ9Ucr1l',
#   'duration_ms': 224493,
#   'time_signature': 4},
#  {'danceability': 0.434,
#   'energy': 0.897,
#   'key': 0,
#   'loudness': -4.918,
#   'mode': 1,
#   'speechiness': 0.0488,
#   'acousticness': 0.0103,
#   'instrumentalness': 0,
#   'liveness': 0.612,
#   'valence': 0.684,
#   'tempo': 148.726,
#   'type': 'audio_features',
#   'id': '2m1hi0nfMR9vdGC8UcrnwU',
#   'uri': 'spotify:track:2m1hi0nfMR9vdGC8UcrnwU',
#   'track_href': 'https://api.spotify.com/v1/tracks/2m1hi0nfMR9vdGC8UcrnwU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2m1hi0nfMR9vdGC8UcrnwU',
#   'duration_ms': 167067,
#   'time_signature': 4},
#  {'danceability': 0.28,
#   'energy': 0.908,
#   'key': 2,
#   'loudness': -5.509,
#   'mode': 0,
#   'speechiness': 0.109,
#   'acousticness': 0.0327,
#   'instrumentalness': 8.85e-06,
#   'liveness': 0.18,
#   'valence': 0.26,
#   'tempo': 118.698,
#   'type': 'audio_features',
#   'id': '5XcZRgJv3zMhTqCyESjQrF',
#   'uri': 'spotify:track:5XcZRgJv3zMhTqCyESjQrF',
#   'track_href': 'https://api.spotify.com/v1/tracks/5XcZRgJv3zMhTqCyESjQrF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XcZRgJv3zMhTqCyESjQrF',
#   'duration_ms': 270080,
#   'time_signature': 4},
#  {'danceability': 0.451,
#   'energy': 0.889,
#   'key': 1,
#   'loudness': -2.693,
#   'mode': 1,
#   'speechiness': 0.261,
#   'acousticness': 0.00167,
#   'instrumentalness': 0.00215,
#   'liveness': 0.258,
#   'valence': 0.586,
#   'tempo': 131.073,
#   'type': 'audio_features',
#   'id': '31RTFPrB7wmYBhlkM2ILXG',
#   'uri': 'spotify:track:31RTFPrB7wmYBhlkM2ILXG',
#   'track_href': 'https://api.spotify.com/v1/tracks/31RTFPrB7wmYBhlkM2ILXG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/31RTFPrB7wmYBhlkM2ILXG',
#   'duration_ms': 153800,
#   'time_signature': 4},
#  {'danceability': 0.356,
#   'energy': 0.872,
#   'key': 2,
#   'loudness': -7.837,
#   'mode': 1,
#   'speechiness': 0.068,
#   'acousticness': 0.00417,
#   'instrumentalness': 0.00975,
#   'liveness': 0.0997,
#   'valence': 0.607,
#   'tempo': 166.3,
#   'type': 'audio_features',
#   'id': '5G1sTBGbZT5o4PNRc75RKI',
#   'uri': 'spotify:track:5G1sTBGbZT5o4PNRc75RKI',
#   'track_href': 'https://api.spotify.com/v1/tracks/5G1sTBGbZT5o4PNRc75RKI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5G1sTBGbZT5o4PNRc75RKI',
#   'duration_ms': 193653,
#   'time_signature': 4},
#  {'danceability': 0.249,
#   'energy': 0.834,
#   'key': 0,
#   'loudness': -8.21,
#   'mode': 1,
#   'speechiness': 0.0577,
#   'acousticness': 0.0738,
#   'instrumentalness': 9.48e-05,
#   'liveness': 0.0924,
#   'valence': 0.338,
#   'tempo': 118.223,
#   'type': 'audio_features',
#   'id': '5EWPGh7jbTNO2wakv8LjUI',
#   'uri': 'spotify:track:5EWPGh7jbTNO2wakv8LjUI',
#   'track_href': 'https://api.spotify.com/v1/tracks/5EWPGh7jbTNO2wakv8LjUI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5EWPGh7jbTNO2wakv8LjUI',
#   'duration_ms': 547107,
#   'time_signature': 4},
#  {'danceability': 0.651,
#   'energy': 0.648,
#   'key': 9,
#   'loudness': -11.409,
#   'mode': 1,
#   'speechiness': 0.0501,
#   'acousticness': 0.262,
#   'instrumentalness': 0.0042,
#   'liveness': 0.0655,
#   'valence': 0.49,
#   'tempo': 156.372,
#   'type': 'audio_features',
#   'id': '23IJ5wLRhEZ9DOuia5mPiZ',
#   'uri': 'spotify:track:23IJ5wLRhEZ9DOuia5mPiZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/23IJ5wLRhEZ9DOuia5mPiZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23IJ5wLRhEZ9DOuia5mPiZ',
#   'duration_ms': 381627,
#   'time_signature': 4},
#  {'danceability': 0.618,
#   'energy': 0.938,
#   'key': 9,
#   'loudness': -3.442,
#   'mode': 1,
#   'speechiness': 0.0456,
#   'acousticness': 0.0179,
#   'instrumentalness': 0,
#   'liveness': 0.167,
#   'valence': 0.875,
#   'tempo': 91.455,
#   'type': 'audio_features',
#   'id': '3ZOEytgrvLwQaqXreDs2Jx',
#   'uri': 'spotify:track:3ZOEytgrvLwQaqXreDs2Jx',
#   'track_href': 'https://api.spotify.com/v1/tracks/3ZOEytgrvLwQaqXreDs2Jx',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3ZOEytgrvLwQaqXreDs2Jx',
#   'duration_ms': 269000,
#   'time_signature': 4},
#  {'danceability': 0.305,
#   'energy': 0.803,
#   'key': 0,
#   'loudness': -4.668,
#   'mode': 1,
#   'speechiness': 0.0412,
#   'acousticness': 0.0495,
#   'instrumentalness': 0.000315,
#   'liveness': 0.329,
#   'valence': 0.282,
#   'tempo': 139.381,
#   'type': 'audio_features',
#   'id': '60a5c4dDARPsksClcom0OD',
#   'uri': 'spotify:track:60a5c4dDARPsksClcom0OD',
#   'track_href': 'https://api.spotify.com/v1/tracks/60a5c4dDARPsksClcom0OD',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60a5c4dDARPsksClcom0OD',
#   'duration_ms': 355915,
#   'time_signature': 4},
#  {'danceability': 0.376,
#   'energy': 0.787,
#   'key': 5,
#   'loudness': -4.731,
#   'mode': 0,
#   'speechiness': 0.0394,
#   'acousticness': 0.00378,
#   'instrumentalness': 0,
#   'liveness': 0.548,
#   'valence': 0.371,
#   'tempo': 87.102,
#   'type': 'audio_features',
#   'id': '6gCVA6ja6g0foIsWv0RuSZ',
#   'uri': 'spotify:track:6gCVA6ja6g0foIsWv0RuSZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6gCVA6ja6g0foIsWv0RuSZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6gCVA6ja6g0foIsWv0RuSZ',
#   'duration_ms': 176200,
#   'time_signature': 4},
#  {'danceability': 0.631,
#   'energy': 0.932,
#   'key': 5,
#   'loudness': -4.142,
#   'mode': 1,
#   'speechiness': 0.0354,
#   'acousticness': 0.0436,
#   'instrumentalness': 0.137,
#   'liveness': 0.0918,
#   'valence': 0.971,
#   'tempo': 122.429,
#   'type': 'audio_features',
#   'id': '7HKez549fwJQDzx3zLjHKC',
#   'uri': 'spotify:track:7HKez549fwJQDzx3zLjHKC',
#   'track_href': 'https://api.spotify.com/v1/tracks/7HKez549fwJQDzx3zLjHKC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7HKez549fwJQDzx3zLjHKC',
#   'duration_ms': 213067,
#   'time_signature': 4},
#  {'danceability': 0.599,
#   'energy': 0.957,
#   'key': 11,
#   'loudness': -5.764,
#   'mode': 1,
#   'speechiness': 0.188,
#   'acousticness': 0.0129,
#   'instrumentalness': 7.06e-05,
#   'liveness': 0.155,
#   'valence': 0.489,
#   'tempo': 103.68,
#   'type': 'audio_features',
#   'id': '1wsRitfRRtWyEapl0q22o8',
#   'uri': 'spotify:track:1wsRitfRRtWyEapl0q22o8',
#   'track_href': 'https://api.spotify.com/v1/tracks/1wsRitfRRtWyEapl0q22o8',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wsRitfRRtWyEapl0q22o8',
#   'duration_ms': 206200,
#   'time_signature': 4},
#  {'danceability': 0.587,
#   'energy': 0.891,
#   'key': 11,
#   'loudness': -3.381,
#   'mode': 1,
#   'speechiness': 0.0361,
#   'acousticness': 0.000261,
#   'instrumentalness': 0.00454,
#   'liveness': 0.314,
#   'valence': 0.705,
#   'tempo': 124.005,
#   'type': 'audio_features',
#   'id': '46QazXxQS0B31CnbRCy8CV',
#   'uri': 'spotify:track:46QazXxQS0B31CnbRCy8CV',
#   'track_href': 'https://api.spotify.com/v1/tracks/46QazXxQS0B31CnbRCy8CV',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/46QazXxQS0B31CnbRCy8CV',
#   'duration_ms': 255573,
#   'time_signature': 4},
#  {'danceability': 0.451,
#   'energy': 0.97,
#   'key': 0,
#   'loudness': -4.938,
#   'mode': 1,
#   'speechiness': 0.107,
#   'acousticness': 0.0264,
#   'instrumentalness': 0.00355,
#   'liveness': 0.102,
#   'valence': 0.198,
#   'tempo': 122.444,
#   'type': 'audio_features',
#   'id': '1f2V8U1BiWaC9aJWmpOARe',
#   'uri': 'spotify:track:1f2V8U1BiWaC9aJWmpOARe',
#   'track_href': 'https://api.spotify.com/v1/tracks/1f2V8U1BiWaC9aJWmpOARe',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1f2V8U1BiWaC9aJWmpOARe',
#   'duration_ms': 216933,
#   'time_signature': 4},
#  {'danceability': 0.268,
#   'energy': 0.98,
#   'key': 11,
#   'loudness': -5.958,
#   'mode': 1,
#   'speechiness': 0.103,
#   'acousticness': 0.0192,
#   'instrumentalness': 0.00709,
#   'liveness': 0.182,
#   'valence': 0.395,
#   'tempo': 100.315,
#   'type': 'audio_features',
#   'id': '6eN1f9KNmiWEhpE2RhQqB5',
#   'uri': 'spotify:track:6eN1f9KNmiWEhpE2RhQqB5',
#   'track_href': 'https://api.spotify.com/v1/tracks/6eN1f9KNmiWEhpE2RhQqB5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6eN1f9KNmiWEhpE2RhQqB5',
#   'duration_ms': 405600,
#   'time_signature': 4},
#  {'danceability': 0.504,
#   'energy': 0.911,
#   'key': 2,
#   'loudness': -2.97,
#   'mode': 1,
#   'speechiness': 0.0738,
#   'acousticness': 0.00512,
#   'instrumentalness': 0.0123,
#   'liveness': 0.355,
#   'valence': 0.671,
#   'tempo': 106.244,
#   'type': 'audio_features',
#   'id': '70Z9t1qhytWtG4cCmmi7mU',
#   'uri': 'spotify:track:70Z9t1qhytWtG4cCmmi7mU',
#   'track_href': 'https://api.spotify.com/v1/tracks/70Z9t1qhytWtG4cCmmi7mU',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/70Z9t1qhytWtG4cCmmi7mU',
#   'duration_ms': 179760,
#   'time_signature': 4},
#  {'danceability': 0.523,
#   'energy': 0.943,
#   'key': 1,
#   'loudness': -4.203,
#   'mode': 1,
#   'speechiness': 0.0337,
#   'acousticness': 0.00704,
#   'instrumentalness': 3.81e-05,
#   'liveness': 0.0579,
#   'valence': 0.766,
#   'tempo': 99.607,
#   'type': 'audio_features',
#   'id': '4EchqUKQ3qAQuRNKmeIpnf',
#   'uri': 'spotify:track:4EchqUKQ3qAQuRNKmeIpnf',
#   'track_href': 'https://api.spotify.com/v1/tracks/4EchqUKQ3qAQuRNKmeIpnf',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4EchqUKQ3qAQuRNKmeIpnf',
#   'duration_ms': 180160,
#   'time_signature': 4},
#  {'danceability': 0.445,
#   'energy': 0.706,
#   'key': 8,
#   'loudness': -9.803,
#   'mode': 1,
#   'speechiness': 0.0461,
#   'acousticness': 0.234,
#   'instrumentalness': 0.000252,
#   'liveness': 0.205,
#   'valence': 0.768,
#   'tempo': 80.823,
#   'type': 'audio_features',
#   'id': '43DeSV93pJPT4lCZaWZ6b1',
#   'uri': 'spotify:track:43DeSV93pJPT4lCZaWZ6b1',
#   'track_href': 'https://api.spotify.com/v1/tracks/43DeSV93pJPT4lCZaWZ6b1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43DeSV93pJPT4lCZaWZ6b1',
#   'duration_ms': 266720,
#   'time_signature': 4}]

# %%
spanish_df = pd.DataFrame(af)
spanish_df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.741   0.697    0    -7.028     1       0.0277      0.066400
# 1         0.556   0.864    3    -5.870     0       0.0584      0.009580
# 2         0.515   0.430    7    -9.935     1       0.0372      0.009700
# 3         0.417   0.934    7    -3.908     0       0.1190      0.000278
# 4         0.412   0.902    9   -11.600     1       0.4050      0.048400
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000023     0.133    0.774  116.109  audio_features
# 1          0.000000     0.209    0.400  105.143  audio_features
# 2          0.000133     0.129    0.104   91.844  audio_features
# 3          0.001500     0.132    0.287  127.066  audio_features
# 4          0.131000     0.405    0.422   89.740  audio_features
#
#                        id                                   uri  \
# 0  2LawezPeJhN4AWuSB0GtAU  spotify:track:2LawezPeJhN4AWuSB0GtAU
# 1  60a0Rd6pjrkxjPbaKzXjfq  spotify:track:60a0Rd6pjrkxjPbaKzXjfq
# 2  70LcF31zb1H0PyJoS1Sx1r  spotify:track:70LcF31zb1H0PyJoS1Sx1r
# 3  2DlHlPMa4M17kufBvI2lEN  spotify:track:2DlHlPMa4M17kufBvI2lEN
# 4  0hCB0YR03f6AmQaHbwWDe8  spotify:track:0hCB0YR03f6AmQaHbwWDe8
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2LawezPeJhN4...
# 1  https://api.spotify.com/v1/tracks/60a0Rd6pjrkx...
# 2  https://api.spotify.com/v1/tracks/70LcF31zb1H0...
# 3  https://api.spotify.com/v1/tracks/2DlHlPMa4M17...
# 4  https://api.spotify.com/v1/tracks/0hCB0YR03f6A...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Law...       160133
# 1  https://api.spotify.com/v1/audio-analysis/60a0...       216880
# 2  https://api.spotify.com/v1/audio-analysis/70Lc...       238640
# 3  https://api.spotify.com/v1/audio-analysis/2DlH...       210240
# 4  https://api.spotify.com/v1/audio-analysis/0hCB...       333893
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %% [markdown]
# ### Chopping a big playlist into chunks

# %%
big_playlist_tracks = get_playlist_tracks("Spotify","2s1KwThY09NjEkmzeTsZWe")

# %%
bp_ids = []
for i in big_playlist_tracks:
    bp_ids.append(i['track']['id'])

# %%
chunk_size = 100
bp_ids_chopped = [bp_ids[i:i+chunk_size] for i in range(0,len(bp_ids), 100)]

# %%
bp_ids_chopped
# Out:
# [['6PCUP3dWmTjcTtXY02oFdT',
#   '7qiZfU4dY1lWllzX7mPBI3',
#   '4DzwSjtHtj52si3ndZ65tB',
#   '6QacHGYy6dD6JVUYRof9Xg',
#   '6xpDh0dXrkVp0Po1qrHUd8',
#   '2ydUT1pFhuLDnouelIv4WH',
#   '3nqm3DdVskqbHhmb8S8hMd',
#   '75SixhsPWyRRmtqHeffiXr',
#   '4948g5UqwZFLGI8UTOXqdi',
#   '0hAMkY2kwdXPPDfQ1e3BmJ',
#   '3DQVgcqaP3iSMbaKsd57l5',
#   '65mxB9IWpmVo4qUjdGSxRB',
#   '4UuHWIkAWnN176A2rx7YFB',
#   '1bhjMY5O0ZjB41OHcdRH0a',
#   '6TclVCUxDQm9s3Bey6Ao8H',
#   '5R4UtkoueIomI2z3Ei8B38',
#   '1slxnxoF2skHpFgvf3IlAW',
#   '4pImG3RdbaGfanzQOTFgyr',
#   '1HNE2PX70ztbEl6MLxrpNL',
#   '0T8P86fvSK8kCUJFYPZbIH',
#   '6TfBA04WJ3X1d1wXhaCFVT',
#   '46jHE9rVH5HqZ7VKZHPinC',
#   '4698LDOlADHX2WmTRR2N4C',
#   '4P8dRfSz0LBgyWfjod6v3J',
#   '7MXVkk9YMctZqd1Srtv4MB',
#   '3gXIeJog1dz723dGs0t894',
#   '5yJIWQ6qiXL0JYxJ0q9z44',
#   '5INJheVHitRzVVCFyh2hik',
#   '04tGB3iBg3EFjmHt7XmOoO',
#   '2NHSYwGkAvPHzCinY0KwXo',
#   '5ubHAQtKuFfiG4FXfLP804',
#   '0azC730Exh71aQlOt9Zj3y',
#   '1zi7xx7UVEFkmKfv06H8x0',
#   '0PX0Ku0gmYIUcIDRO23x8B',
#   '4B0JvthVoAAuygILe3n4Bs',
#   '09CtPGIpYB4BrO8qb1RGsF',
#   '0afhq8XCExXpqazXczTSve',
#   '2Vhd5uZB4brKHmM0MNxkZo',
#   '6G2bTEoeTar8Pty3cH414f',
#   '4KacUpvbA3Mfo05gttTjhN',
#   '4Ub8UsjWuewQrPhuepfVpd',
#   '590ZheHFaC3JsZBwL8otpk',
#   '7rMTLPej6tXQ6TQdLVSzTD',
#   '0j2T0R9dR9qdJYsB7ciXhf',
#   '2gZUPNdnz5Y45eiGxpHGSc',
#   '01UniWABhnIka7GgvzOC02',
#   '4ZPdLEztrlZqbJkgHNw54L',
#   '2pRyjmTGkz5i8xemOtJ7pG',
#   '3u1Er1rkjn1oSz1xdZH3ZD',
#   '1qp0ptMXNg9hqLH8sk7cc2',
#   '3ZzGVQUqnuAZotvLl5tRqH',
#   '0PDUDa38GO8lMxLCRc4lL1',
#   '0vg4WnUWvze6pBOJDTq99k',
#   '2pJZ1v8HezrAoZ0Fhzby92',
#   '6ie2Bw3xLj2JcGowOlcMhb',
#   '1vrjcPplEuenckUzGGp2UR',
#   '2g2a5kDeZexbUTD8abcvm6',
#   '5PZK7nZBsKjSkXDszKrJ1W',
#   '4spfRBAAdrMKR35lZWrgYF',
#   '5WxDUKPTu3SDBma67yf3H5',
#   '7xoBDnT7G2kdKeO3nFglRJ',
#   '5KapdDhHZ0HRH6EKFMaSnm',
#   '5GXAXm5YOmYT0kL5jHvYBt',
#   '15vzANxN8G9wWfwAJLLMCg',
#   '7qvxFz3JodM0A7xEM7k3YD',
#   '6PAoCw99yAkmpeXmY8IIUE',
#   '55n9yjI6qqXh5F2mYvUc2y',
#   '5uCax9HTNlzGybIStD3vDh',
#   '7BKLCZ1jbUBVqRi2FVlTVw',
#   '5k3jdIh7BpJaV1DntDQoSD',
#   '1v7L65Lzy0j0vdpRjJewt1',
#   '6or1bKJiZ06IlK0vFvY75k',
#   '15JINEqzVMv3SvJTAXAKED',
#   '7Ie9W94M7OjPoZVV216Xus',
#   '4SE4yewyGpOYfxfx59Yjc5',
#   '7bHT9osSq1rwT2yaImzqCi',
#   '4lCv7b86sLynZbXhfScfm2',
#   '6tS3XVuOyu10897O3ae7bi',
#   '55qBw1900pZKfXJ6Q9A2Lc',
#   '27tNWlhdAryQY04Gb2ZhUI',
#   '19fVfEI3sw6me7I3rTmlaJ',
#   '1q9bLSeIlGf2xBvbOkp2Wr',
#   '561jH07mF1jHuk7KlaeF0s',
#   '3yfqSUWxFvZELEM4PmlwIR',
#   '6CN3e26iQSj1N5lomh0mfO',
#   '7BMO7O7ImjV8HNTH74Tshv',
#   '6da04YB906XonC6IQNC44u',
#   '1KGi9sZVMeszgZOWivFpxs',
#   '6qspW4YKycviDFjHBOaqUY',
#   '6q3zC9dDD4lUNk8nfUztXy',
#   '4rHZZAmHpZrA3iH5zx8frV',
#   '7Lf7oSEVdzZqTA0kEDSlS5',
#   '6vt0I1cw1YmAIKDJvHVIM5',
#   '0O45fw2L5vsWpdsOdXwNAR',
#   '2V65y3PX4DkRhy1djlxd9p',
#   '4lhqb6JvbHId48OUJGwymk',
#   '77OuOZhDxJSQLYnNIpX2AG',
#   '0BBZuOGGBj9u4X3rAfmae8',
#   '5A6OHHy73AR5tLxgTc98zz',
#   '2g7uRZ68eLtv74XrxgdT2q'],
#  ['5NEKjqTQPKiqOiOG8YxLdS',
#   '0Ns3nvzgfC6Yh3j5apV66n',
#   '1akgiRM3mN2nxu2AX6ACCW',
#   '5ChkMS8OtdzJeqyybCc9R5',
#   '1OOtq8tRnDM8kG2gqUPjAj',
#   '3S2R0EVwBSAVMd5UMgKTL0',
#   '3c7Ctlw9MKlIQPxRH3fOTt',
#   '4o3cq2szX7THGyZDsWtp59',
#   '21pySLskKIKrhDziCX5ojQ',
#   '6KM6693N1wVvz6tDviEF4F',
#   '0ALV8l7nqbjwSZ2w9hS2CI',
#   '60nZcImufyMA1MKQY3dcCH',
#   '0I3q5fE6wg7LIfHGngUTnV',
#   '70FCugJxa7XW04Np6iYJdI',
#   '48EQasc6XD0pOQtkIOWqOC',
#   '2M9ro2krNb7nr7HSprkEgo',
#   '0cnqc37nLcCiEuBeXLMHqt',
#   '7urCpstCEncypWMreEwJCh',
#   '6wOOoWXr5sVA1oiw3CDicV',
#   '3XkWWCZ8THAe3MD4PVafjw',
#   '4w0uNbUBdDW1ATA93W3fDP',
#   '6b8Be6ljOzmkOmFslEb23P',
#   '0nJW01T7XtvILxQgC5J7Wh',
#   '3w3y8KPTfNeOKPiqUTakBh',
#   '386RUes7n1uM1yfzgeUuwp',
#   '7klGz8x5PqtLShAQ2PjR9X',
#   '3qW9OceXtlGavVOtNv7zhj',
#   '1zayuwd1YLZsYDArkruHdL',
#   '1DIXPcTDzTj8ZMHt3PDt8p',
#   '3DXncPQOG4VBw3QHh3S817',
#   '2cOUlop2ZakjOKe4WinesN',
#   '5Ohxk2dO5COHF1krpoPigN',
#   '1YQJ00mRFj5MGgP7h4vO1p',
#   '6L89mwZXSOwYl76YXfX13s',
#   '3a1lNhkSLSkpJE4MSHpDu9',
#   '6eT7xZZlB2mwyzJ2sUKG6w',
#   '1vnnXMrBeEWiRg3YCMCjQq',
#   '22wKQbMH8n7wZfso2VcLJL',
#   '4CeeEOM32jQcH3eN9Q2dGj',
#   '7JJmb5XwzOO8jgpou264Ml',
#   '1bCmvezFg5MRcENzCGG1Cy',
#   '4AFwnrH5atiJoAd5xS5QtR',
#   '5qaEfEh1AtSdrdrByCP7qR',
#   '6C0xucNj75wRdlejwWIEW1',
#   '69h2mpzNUmdEg5egeNa1ki',
#   '4HlFJV71xXKIGcU3kRyttv',
#   '4i387P9kogblRBfjFi3NaX',
#   '6RX5iL93VZ5fKmyvNXvF1r',
#   '27NV2KxoQ8WuLMqlTDI61F',
#   '77OuOZhDxJSQLYnNIpX2AG',
#   '2TYC9SaRhYypUQzB1ZVTG2',
#   '0JrlB9UVSGhD0mIuYx7x5U',
#   '0vbtURX4qv1l7besfwmnD8',
#   '6yraFyhgbavO2amB2lhpfi',
#   '7yq4Qj7cqayVTp3FF9CWbm',
#   '66hayvUbTotekKU3H4ta1f',
#   '17leTzpwQBLeqJRYzhJKbi',
#   '6YosK76VT06EAqgyRODjff',
#   '1OAh8uOEOvTDqkKFsKksCi',
#   '1bCmvezFg5MRcENzCGG1Cy',
#   '5A1FmxbYVRZKy4nc16MAue',
#   '76hfruVvmfQbw0eYn1nmeC',
#   '0jt6NEuzEY0OouXkwZHq5n',
#   '48UPSzbZjgc449aqz8bxox',
#   '3Y3gChJoEUTqrtuqJCIPQk',
#   '1fJFuvU2ldmeAm5nFIHcPP',
#   '5sCu5ASRG4nDhfthTFeGSN',
#   '22VdIZQfgXJea34mQxlt81',
#   '32OlwWuMpZ6b0aN2RZOeMS',
#   '62yJjFtgkhUrXktIoSjgP2',
#   '7BQVSVEQaHU92qkKDxUpA1',
#   '2DgmVBl7fNmZhuplDqo6hu',
#   '495O1Affo7AurEPQcvcr18',
#   '1oagRT7LfpVlNJN6FSZDGp',
#   '71o4RblgefcGHIf1MbvJzZ',
#   '3Q7jFW6nxqhwbUctqqthSa',
#   '0O986IRZ2rL3qGH5QiD4ZO',
#   '0a7BloCiNzLDD9qSQHh5m7',
#   '0xmjwnQ3FNE6HuWCt2nHdZ',
#   '2TfSHkHiFO4gRztVIkggkE',
#   '26VG1uCazw9xtVnq8A1vtd',
#   '1G1r2ectZOGeOkZmKtAP3m',
#   '6ndmKwWqMozN2tcZqzCX4K',
#   '0XXyGdcVEHZ6CnmAlNsqKl',
#   '4XHQyvbrBsQaaBUW1VvmsL',
#   '2cY7WSxFIsZQaoDNJe7Fz3',
#   '47ojH5LeQhl1ZltSAHBEFF',
#   '7rXOUa2yrj80b49sYqV6Qy',
#   '6PAoCw99yAkmpeXmY8IIUE',
#   '373kL6gycElmvrcrnL9tOa',
#   '4NTWZqvfQTlOMitlVn6tew',
#   '5HDPtsnyb3maFmPL8LLUTG',
#   '0BRHnOFm6sjxN1i9LJrUDu',
#   '0AkxBAeytxcvk6q2fMmFdh',
#   '3WkibOpDF7cQ5xntM1epyf',
#   '0KKkJNfGyhkQ5aFogxQAPU',
#   '0wG4gampO24nC7VKm5pxjg',
#   '6otiaV2fagE3s8IvP6WkwG',
#   '07WEDHF2YwVgYuBugi2ECO',
#   '5PUawWFG1oIS2NwEcyHaCr'],
#  ['1fyysXwSGNtMeqMBLwW3SI',
#   '3oDFtOhcN08qeDPAK6MEQG',
#   '3Zwu2K0Qa5sT6teCCHPShP',
#   '3n3Ppam7vgaVa1iaRUc9Lp',
#   '0nrRP2bk19rLc0orkWPQk2',
#   '60a0Rd6pjrkxjPbaKzXjfq',
#   '3OR8GVakIXV3KXnOyu0EaB',
#   '6smjStYPmlzbeodf5v2NGp',
#   '0M9ydKzuF3oZTfYYPfaGX1',
#   '3QHPHLAkYV5cQBUYs6rowx',
#   '3NJG6vMH1ZsectZkocMEm0',
#   '6PTwoCCzthLLmeRvNqEa5Q',
#   '3pvOdS9kIz3LL0UoRVsabS',
#   '2Bzs5ZV2pvT2m6tUKvRIGo',
#   '36lMOkznYfvRWPcptBXQav',
#   '5cc9Zbfp9u10sfJeKZ3h16',
#   '6kLZ1DzSxBkNVvdQm6CX0N',
#   '4cAgkb0ifwn0FSHGXnr4F6',
#   '48RrDBpOSSl1aLVCalGl5C',
#   '4iz9lGMjU1lXS51oPmUmTe',
#   '7dnWwCsOThlLtGtmDjlVMx',
#   '3tH03v5SIWaglfE3rzXzeB',
#   '49zD0wr2S3d0lZPib0K4e1',
#   '4bz7uB4edifWKJXSDxwHcs',
#   '0ANExk8Iu85oqCgk82rG64',
#   '5AyL2kgLtTWEu3qO3B9SqK',
#   '3G0yz3DZn3lfraledmBCT0',
#   '6bUNEbXT7HovLW6BgPCBsb',
#   '6iEcSU3TGinx759dss627V',
#   '6I3Evf3nNhxFA5lSM37Y0v',
#   '47XmM8zyPHGqqwRIzmYJil',
#   '23oxJmDc1V9uLUSmN2LIvx',
#   '20X9OeC606XNwEtDBOym5u',
#   '0e7ipj03S05BNilyu5bRzt',
#   '7CcoUAtUcYhUfBsmtn0ajO',
#   '1cS0TgbR263ey9jn0MwD2s',
#   '2Ie7pnF3ZKNTde30TQWlWx',
#   '3xpTHrC1b6dmiLEeM5jO0z',
#   '3bNv3VuUOKgrf5hu3YcuRo',
#   '6O5TrlFWTYvznd9fMC0VvU',
#   '4OSBTYWVwsQhGLF9NHvIbR',
#   '1CRtJS94Hq3PbBZT9LuF90',
#   '3di5hcvxxciiqwMH1jarhY',
#   '5mFMb5OHI3cN0UjITVztCj',
#   '1Yk0cQdMLx5RzzFTYwmuld',
#   '39shmbIHICJ2Wxnk1fPSdz',
#   '50kpGaPAhYJ3sGmk6vplg0',
#   '7xapw9Oy21WpfEcib2ErSA',
#   '3UGIZ8qcrMTwzLbx6Kttqt',
#   '6epn3r7S14KUqlReYr77hA',
#   '0GjEhVFGZW8afUYGChu3Rr',
#   '2TxCwUlqaOH3TIyJqGgR91',
#   '1M2nd8jNUkkwrc1dgBPTJz',
#   '1YW369EbVyjpeLE3YbsjKQ',
#   '6vcdzohhBSbNdsZBh5IRpQ',
#   '2a3U3GTCvrcma7wetBtOpi',
#   '3yZNKN3r1USoCVij9VDSh6',
#   '77NNZQSqzLNqh2A9JhLRkg',
#   '72TFWvU3wUYdUuxejTTIzt',
#   '5pDUMdIiW0rNLzFryqpC9j',
#   '5FTCKvxzqy72ceS4Ujux4N',
#   '0C4ejWmOTMv8vuYj85mf8m',
#   '0AH6WMe3OlAlUb5miXt2FQ',
#   '6qn9YLKt13AGvpq9jfO8py',
#   '1tfZtA15BfJHQTUy3dqTKC',
#   '0SNGe4xksgp7CGnY5kMXOJ',
#   '1TfqLAPs4K3s2rJMoCokcS',
#   '6SjbzGo7arjfM5cXpXhc5B',
#   '3CSpzkoL1XgDBZ1q9aDCUV',
#   '2tUBqZG2AbRi7Q0BIrVrEj',
#   '4PTG3Z6ehGkBFwjybzWkR8',
#   '5qFPs70nZD1fQZOi7u7cIZ',
#   '2WfaOiMkCvy7F5fcp2zZ8L',
#   '4w3tQBXhn5345eUXDGBWZG',
#   '0qi4b1l0eT3jpzeNHeFXDT',
#   '6OnfBiiSc9RGKiBKKtZXgQ',
#   '47BBI51FKFwOMlIiX6m8ya',
#   '3MjUtNVVq3C8Fn0MP3zhXa',
#   '0weAUscowxeqDtpCgtbpgp',
#   '6naxalmIoLFWR0siv8dnQQ',
#   '3Cx4yrFaX8CeHwBMReOWXI',
#   '75IN3CtuZwTHTnZvYM4qnJ',
#   '5vlEg2fT4cFWAqU5QptIpQ',
#   '0GjEhVFGZW8afUYGChu3Rr',
#   '6FB3v4YcR57y4tXFcdxI1E',
#   '3f7gYMirBEKuc57218BjOY',
#   '60jzFy6Nn4M0iD1d94oteF',
#   '0VwNdo84DaVYLIkbVO86ND',
#   '3ZFTkvIE7kyPt6Nu3PEa7V',
#   '244AvzGQ4Ksa5637JQu5Gy',
#   '4kLLWz7srcuLKA7Et40PQR',
#   '14iN3o8ptQ8cFVZTEmyQRV',
#   '02jcEwywffn3Tsb48fXmlW',
#   '2CEgGE6aESpnmtfiZwYlbV',
#   '3DamFFqW32WihKkTVlwTYQ',
#   '1QV6tiMFM6fSOKOGLMHYYg',
#   '3xrn9i8zhNZsTtcoWgQEAd',
#   '5i66xrvSh1MjjyDd6zcwgj',
#   '26wpcLqBHEfOL00i1rdbun',
#   '62LHRv9uwSNlBmByQF5jdE'],
#  ['0SiywuOBRcynK0uKGWdCnn',
#   '2y4lAQpi5VTNLu2ldeTdUH',
#   '5eqiMMbaeUZ32Q7sS00H35',
#   '5Nm9ERjJZ5oyfXZTECKmRt',
#   '3x2YIvkLcxvZQsA5x6xyIR',
#   '4VrWlk8IQxevMvERoX08iC',
#   '0ifSeVGUr7py5GggttDhXw',
#   '3dYD57lRAUcMHufyqn9GcI',
#   '2tpWsVSb9UEmDRxAl1zhX1',
#   '3tgZ9vmhuAY9wEoNUJskzV',
#   '2vwlzO0Qp8kfEtzTsCXfyE',
#   '2fTsFCKRFQ5M0igJgabnLA',
#   '4DRFIoachXrW8YV7Yje0yz',
#   '5lF0pHbsJ0QqyIrLweHJPW',
#   '2pUpNOgJBIBCcjyQZQ00qU',
#   '0qcr5FMsEO85NAQjrlDRKo',
#   '30XU4suKzCeoCK9YFzdufg',
#   '57F80059mWaWFvWG3tBTbO',
#   '3U4isOIWM3VvDubwSI3y7a',
#   '4nVBt6MZDDP6tRVdQTgxJg',
#   '4cluDES4hQEUhmXj6TXkSo',
#   '6nek1Nin9q48AVZcWs9e9D',
#   '23khhseCLQqVMCIT1WMAns',
#   '1qDrWA6lyx8cLECdZE7TV7',
#   '69kOkLUCkxIZYexIgSG8rq',
#   '0n4bITAu0Y0nigrz3MFJMb',
#   '03UrZgTINDqvnUMbbIMhql',
#   '2EZ2KXLqs9zdRVVMMz1IsH',
#   '1ve0SgTZkv3wdggJLqtBYU',
#   '2CJlJKDRC3QXz070NHwaQQ',
#   '3s4U7OHV7gnj42VV72eSZ6',
#   '3wPPWcVuinAU7dXcJXtCID',
#   '78TTtXnFQPzwqlbtbwqN0y',
#   '40xhyfAPDoMtv494MfPevP',
#   '6OEolOOk9Gh9bqkdpfIOl0',
#   '7wMq5n8mYSKlQIGECKUgTX',
#   '0laYHRpNTS6i8FXdupHkJ4',
#   '4lLtanYk6tkMvooU0tWzG8',
#   '1CmUZGtH29Kx36C1Hleqlz',
#   '7vFoFDWqTX0mHzLfrF1Cfy',
#   '2YWjW3wwQIBLNhxWKBQd16',
#   '5iNRPN7oYQvdB9AmeSW6d3',
#   '1zneM1cLjM6w8BFmukl2Lr',
#   '7p8wAUDFBSWPMh2KxfUDQk',
#   '1r3myKmjWoOqRip99CmSj1',
#   '49kjlZP49LMD1MrrcvXDET',
#   '5HOpkTTVcmZHnthgyxrIL8',
#   '3bC1ahPIYt1btJzSSEyyrF',
#   '2d8ctyCSbDMwrByGI6Ybpc',
#   '4LWrlMkj3nFceDhigJmBGf',
#   '6rmXhRIemCTPyMYZRDN7Qg',
#   '5RIVoVdkDLEygELLCniZFr',
#   '4SEZthmPtszZPaktPLRX6J',
#   '78TKtlSLWK8pZAKKW3MyQL',
#   '3zkWCteF82vJwv0hRLba76',
#   '0wwPcA6wtMf6HUMpIRdeP7',
#   '5MhsZlmKJG6X5kTHkdwC4B',
#   '0181HMomm7xM3Ks5YNlA9X',
#   '2V4bv1fNWfTcyRJKmej6Sj',
#   '3F9ByoUqu31xU0I3G5xfVg',
#   '76hfruVvmfQbw0eYn1nmeC',
#   '4Dio1t8RHzLv1nfPJTSZyP',
#   '1i1fxkWeaMmKEB4T7zqbzK',
#   '5kqIPrATaCc2LqxVWzQGbk',
#   '0vbtURX4qv1l7besfwmnD8',
#   '3MWGlCKyH4nILtXRnE9gd7',
#   '2ONIJ40u0Attbm3miIIpNO',
#   '2CpH1L4CUR47RARB3PgY1l',
#   '20I6sIOMTCkB6w7ryavxtO',
#   '5YEOzOojehCqxGQCcQiyR4',
#   '68EMU2RD1ECNeOeJ5qAXCV',
#   '7KxhSJOYiqCDclXDBNlFSZ',
#   '44ONERBHALxftQNWq6dmyd',
#   '6X5OFBbrsHRsyO1zP7udgr',
#   '4QVFtAswXqPoAWRLo5yu8a',
#   '0iOu4s8w3pE9vbpb1SHXsL',
#   '43ZyHQITOjhciSUUNPVRHc',
#   '7jLbTp3qZzah9kMIdW8e5M',
#   '5pyVqlqThcxI7tPDjHIzPh',
#   '22L7bfCiAkJo5xGSQgmiIO',
#   '4SYUUlkScpNR1QvPscXf8t',
#   '5tz69p7tJuGPeMGwNTxYuV',
#   '3Vo4wInECJQuz9BIBMOu8i',
#   '2RlgNHKcydI9sayD2Df2xp',
#   '6dbSBQXCctYSVryynHXaZ4',
#   '6XAA7T9VHcqKQSzjmXAJ8o',
#   '3c7vquF4xacCmFrxztLUVH',
#   '4SirgQCJZCCf5Qf7ZCaUO3',
#   '1zzxoZVylsna2BQB65Ppcb',
#   '5g1vtHqi9uV7xtYeCcFOBx',
#   '0iOZM63lendWRTTeKhZBSC',
#   '70eFcWOvlMObDhURTqT4Fv',
#   '4wuCQX7JvAZLlrcmH4AeZF',
#   '0hVXuCcriWRGvwMV1r5Yn9',
#   '3FHXUqaUer9o231Je1zxIN',
#   '0AtP8EkGPn6SwxKDaUuXec',
#   '1AI7UPw3fgwAFkvAlZWhE0',
#   '4vUmTMuQqjdnvlZmAH61Qk',
#   '2WwzQJt4hG7YC6x16ZTYFM',
#   '3gdewACMIVMEWVbyb8O9sY'],
#  ['2TVxnKdb3tqe1nhQWwwZCO',
#   '38zsOOcu31XbbYj9BIPUF1',
#   '1LkoYGxmYpO6QSEvY5C0Zl',
#   '7FIWs0pqAYbP91WWM0vlTQ',
#   '5lWUeSYO61UYgNlFlqcwYl',
#   '6Vw61rGpC1JQpBhlxaFbYC',
#   '6d8HN8MqqbqrEUI2bvx0aG',
#   '2zxEc1GCSCxbHIXTfhraRC',
#   '3mtaSob1BQO4HMSA8lWKRt',
#   '1Xapo8sq7KcQXdt0HrXX5B',
#   '3hX0ilh84w2KGaiNw2rRCV',
#   '24LS4lQShWyixJ0ZrJXfJ5',
#   '0KAzP1Rbp0Vz5pw8i1KDDI',
#   '2J0NXdHr6MYvKDSxB7k3V2',
#   '0RiRZpuVRbi7oqRdSMwhQY',
#   '5NLrhUIsvllyTIF3qNdwL9',
#   '0cnqc37nLcCiEuBeXLMHqt',
#   '5MrJiv4t8TrPlsiCtk89ur',
#   '0P88fVbvRQGgRQN1GulQNy',
#   '0ElmwRAsaxaUZXnMbaSllH',
#   '1auxYwYrFRqZP7t3s7w4um',
#   '78TTtXnFQPzwqlbtbwqN0y',
#   '44GokgCa37BTZP2NU2zkoJ',
#   '6DXEZzM4wBa3EOl0NCNSvz',
#   '3QjpO5xOB9ErJ95AxT0h0r',
#   '3p7XQpdt8Dr6oMXSvRZ9bg',
#   '5w40ZYhbBMAlHYNDaVJIUu',
#   '7ygpwy2qP3NbrxVkHvUhXY',
#   '75JFxkI2RXiU7L9VXzMkle',
#   '563SfWAHJs4FBZMkRN0IFN',
#   '0k73nWaD6RPx2sHFEkGPcn',
#   '6C0xucNj75wRdlejwWIEW1',
#   '4a15eseuGANesjXx68PuqA',
#   '0A5WqVkhofB9nBPjEBB82N',
#   '1PAYgOjp1c9rrZ2kVQg2vN',
#   '12dU3vAh6AFoJkisorfoUl',
#   '1VeBRxsj4k4tKmgnEdZywL',
#   '2A7GGXmTlXuH9LOvBXgOX4',
#   '25FTMokYEbEWHEdss5JLZS',
#   '6x4tKaOzfNJpEJHySoiJcs',
#   '3MrWxJaD2AT0W9DjWF64Vm',
#   '2fyIS6GXMgUcSv4oejx63f',
#   '60QLLec3yKDwloXCyummPy',
#   '4jJfa4mO5JjV9Tz2aAxE2M',
#   '0SlpFHdk4UHBDzCEoXzy14',
#   '12dU3vAh6AFoJkisorfoUl',
#   '0SlpFHdk4UHBDzCEoXzy14',
#   '5adjc9rGazKvYcyEHNtoz1',
#   '1XYLtiNehOF8D5NmlQknpI',
#   '5OWsea313ovaQoXvsgWq79',
#   '1RP85mAmvJ8baqjP53kFJu',
#   '1kOuWjfMqINsSqhYFKDdTM',
#   '2aibwv5hGXSgw7Yru8IYTO',
#   '3d9DChrdc6BOeFsbrZ3Is0',
#   '5hnyJvgoWiQUYZttV4wXy6',
#   '2fXKyAyPrEa24c6PJyqznF',
#   '70wYA8oYHoMzhRRkARoMhU',
#   '4YYbZODiJA7j53777zUjFj',
#   '5xoUgPXbMNUmoHU0Enwtwq',
#   '5CeL9C3bsoe4yzYS1Qz8cw',
#   '1dNIEtp7AY3oDAKCGg2XkH',
#   '06Jt4hlDLAwwdZLuanfPuI',
#   '6y468DyY1V67RBNCwzrMrC',
#   '1UZOjK1BwmwWU14Erba9CZ',
#   '3cfOd4CMv2snFaKAnMdnvK',
#   '2eF8pWbiivYsYRpbntYsnc',
#   '22eNdxGb4tEvBt0nBCp52o',
#   '5fVZC9GiM4e8vu99W0Xf6J',
#   '0JJP0IS4w0fJx01EcrfkDe',
#   '7j31rVgGX9Q2blT92VBEA0',
#   '7Ktt7hGxke6dEGNMDn5if2',
#   '3U5JVgI2x4rDyHGObzJfNf',
#   '0eehHRQY2nlimtLjCI9xRf',
#   '0mflMxspEfB0VbI1kyLiAv',
#   '213x4gsFDm04hSqIUkg88w',
#   '1D4PL9B8gOg78jiHg3FvBb',
#   '1SKPmfSYaPsETbRHaiA18G',
#   '4tKGFmENO69tZR9ahgZu48']]

# %%
af_list = []
for i in bp_ids_chopped:
    af_list.extend(sp.audio_features(i))
pd.DataFrame(af_list)
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.461   0.834    2    -4.868     1       0.0989      0.023200
# 1           0.825   0.652    1    -3.183     0       0.0802      0.581000
# 2           0.528   0.681    4    -9.056     0       0.0532      0.057000
# 3           0.486   0.898    3    -1.742     1       0.0550      0.000234
# 4           0.520   0.775    0    -5.803     1       0.0348      0.034000
# ..            ...     ...  ...       ...   ...          ...           ...
# 473         0.662   0.488    9    -6.894     1       0.0682      0.782000
# 474         0.631   0.924    0    -5.589     1       0.1460      0.084100
# 475         0.617   0.741    2    -3.970     1       0.0311      0.131000
# 476         0.448   0.665    9    -4.203     1       0.0260      0.060000
# 477         0.730   0.849    1    -5.281     0       0.0299      0.002340
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000011    0.1400    0.471  135.007  audio_features
# 1            0.000000    0.0931    0.931   95.977  audio_features
# 2            0.000004    0.1030    0.450   84.768  audio_features
# 3            0.001370    0.3430    0.381  122.002  audio_features
# 4            0.000000    0.3640    0.382  136.028  audio_features
# ..                ...       ...      ...      ...             ...
# 473          0.000000    0.1020    0.817  117.913  audio_features
# 474          0.000004    0.0840    0.755  100.045  audio_features
# 475          0.000000    0.0772    0.306  118.984  audio_features
# 476          0.000025    0.0828    0.304  172.004  audio_features
# 477          0.000026    0.3120    0.887  117.310  audio_features
#
#                          id                                   uri  \
# 0    6PCUP3dWmTjcTtXY02oFdT  spotify:track:6PCUP3dWmTjcTtXY02oFdT
# 1    7qiZfU4dY1lWllzX7mPBI3  spotify:track:7qiZfU4dY1lWllzX7mPBI3
# 2    4DzwSjtHtj52si3ndZ65tB  spotify:track:4DzwSjtHtj52si3ndZ65tB
# 3    6QacHGYy6dD6JVUYRof9Xg  spotify:track:6QacHGYy6dD6JVUYRof9Xg
# 4    6xpDh0dXrkVp0Po1qrHUd8  spotify:track:6xpDh0dXrkVp0Po1qrHUd8
# ..                      ...                                   ...
# 473  0mflMxspEfB0VbI1kyLiAv  spotify:track:0mflMxspEfB0VbI1kyLiAv
# 474  213x4gsFDm04hSqIUkg88w  spotify:track:213x4gsFDm04hSqIUkg88w
# 475  1D4PL9B8gOg78jiHg3FvBb  spotify:track:1D4PL9B8gOg78jiHg3FvBb
# 476  1SKPmfSYaPsETbRHaiA18G  spotify:track:1SKPmfSYaPsETbRHaiA18G
# 477  4tKGFmENO69tZR9ahgZu48  spotify:track:4tKGFmENO69tZR9ahgZu48
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/6PCUP3dWmTjc...
# 1    https://api.spotify.com/v1/tracks/7qiZfU4dY1lW...
# 2    https://api.spotify.com/v1/tracks/4DzwSjtHtj52...
# 3    https://api.spotify.com/v1/tracks/6QacHGYy6dD6...
# 4    https://api.spotify.com/v1/tracks/6xpDh0dXrkVp...
# ..                                                 ...
# 473  https://api.spotify.com/v1/tracks/0mflMxspEfB0...
# 474  https://api.spotify.com/v1/tracks/213x4gsFDm04...
# 475  https://api.spotify.com/v1/tracks/1D4PL9B8gOg7...
# 476  https://api.spotify.com/v1/tracks/1SKPmfSYaPsE...
# 477  https://api.spotify.com/v1/tracks/4tKGFmENO69t...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/6PCU...       261154
# 1    https://api.spotify.com/v1/audio-analysis/7qiZ...       233713
# 2    https://api.spotify.com/v1/audio-analysis/4Dzw...       242409
# 3    https://api.spotify.com/v1/audio-analysis/6Qac...       194280
# 4    https://api.spotify.com/v1/audio-analysis/6xpD...       249627
# ..                                                 ...          ...
# 473  https://api.spotify.com/v1/audio-analysis/0mfl...       182347
# 474  https://api.spotify.com/v1/audio-analysis/213x...       192280
# 475  https://api.spotify.com/v1/audio-analysis/1D4P...       236267
# 476  https://api.spotify.com/v1/audio-analysis/1SKP...       237147
# 477  https://api.spotify.com/v1/audio-analysis/4tKG...       230013
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 473               4
# 474               4
# 475               4
# 476               4
# 477               4
#
# [478 rows x 18 columns]

# %% [markdown]
# ### Example with rock

# %%
rock = get_playlist_tracks('Spotify','37i9dQZF1DWXRqgorJj26U')

# %%
rock_ids =[]
for i in rock:
    rock_ids.append(i['track']['id'])

# %%
len(rock_ids)
# Out:
# 200

# %%
chunk_size = 100
rock_ids_chopped = [rock_ids[i:i+chunk_size] for i in range(0,len(rock_ids), 100)]

# %%
rock_af = []
for i in rock_ids_chopped:
    rock_af.extend(sp.audio_features(i))

# %%
rock_df = pd.DataFrame(rock_af)
rock_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.475   0.899    9    -4.321     0       0.0637      0.003750
# 1           0.502   0.890    4    -5.175     1       0.0364      0.000147
# 2           0.535   0.716    4    -5.025     1       0.0431      0.326000
# 3           0.464   0.795    1    -9.267     1       0.0926      0.049300
# 4           0.505   0.754    4    -7.435     1       0.0366      0.132000
# ..            ...     ...  ...       ...   ...          ...           ...
# 195         0.595   0.996    2    -3.418     1       0.0599      0.195000
# 196         0.615   0.910   11    -4.248     1       0.0347      0.500000
# 197         0.532   0.767    7    -5.509     1       0.0574      0.002870
# 198         0.464   0.655    7    -9.058     0       0.0608      0.027200
# 199         0.730   0.487    4   -10.991     1       0.0303      0.258000
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000019    0.1400    0.603  152.445  audio_features
# 1            0.011700    0.2170    0.259  133.520  audio_features
# 2            0.000000    0.6590    0.901   94.379  audio_features
# 3            0.002440    0.3990    0.612  158.691  audio_features
# 4            0.000000    0.2040    0.510  119.204  audio_features
# ..                ...       ...      ...      ...             ...
# 195          0.034500    0.0351    0.376  152.049  audio_features
# 196          0.511000    0.2810    0.770  111.013  audio_features
# 197          0.000513    0.3900    0.755  127.361  audio_features
# 198          0.000001    0.3280    0.531  169.515  audio_features
# 199          0.010000    0.0852    0.731  114.965  audio_features
#
#                          id                                   uri  \
# 0    0X1sqQ652p1sceKM2nJlIJ  spotify:track:0X1sqQ652p1sceKM2nJlIJ
# 1    57bgtoPSgt236HzfBOd8kj  spotify:track:57bgtoPSgt236HzfBOd8kj
# 2    2Cdvbe2G4hZsnhNMKyGrie  spotify:track:2Cdvbe2G4hZsnhNMKyGrie
# 3    63T7DJ1AFDD6Bn8VzG6JE8  spotify:track:63T7DJ1AFDD6Bn8VzG6JE8
# 4    5RKQ5NdjSh2QzD4MaunT91  spotify:track:5RKQ5NdjSh2QzD4MaunT91
# ..                      ...                                   ...
# 195  5o37x6LpNSec4jSfPIChsQ  spotify:track:5o37x6LpNSec4jSfPIChsQ
# 196  4hq0S6wznq7SHDyMOFXL9i  spotify:track:4hq0S6wznq7SHDyMOFXL9i
# 197  2SiXAy7TuUkycRVbbWDEpo  spotify:track:2SiXAy7TuUkycRVbbWDEpo
# 198  3dmqIB2Qxe2XZobw9gXxJ6  spotify:track:3dmqIB2Qxe2XZobw9gXxJ6
# 199  254bXAqt3zP6P50BdQvEsq  spotify:track:254bXAqt3zP6P50BdQvEsq
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/0X1sqQ652p1s...
# 1    https://api.spotify.com/v1/tracks/57bgtoPSgt23...
# 2    https://api.spotify.com/v1/tracks/2Cdvbe2G4hZs...
# 3    https://api.spotify.com/v1/tracks/63T7DJ1AFDD6...
# 4    https://api.spotify.com/v1/tracks/5RKQ5NdjSh2Q...
# ..                                                 ...
# 195  https://api.spotify.com/v1/tracks/5o37x6LpNSec...
# 196  https://api.spotify.com/v1/tracks/4hq0S6wznq7S...
# 197  https://api.spotify.com/v1/tracks/2SiXAy7TuUky...
# 198  https://api.spotify.com/v1/tracks/3dmqIB2Qxe2X...
# 199  https://api.spotify.com/v1/tracks/254bXAqt3zP6...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/0X1s...       230667
# 1    https://api.spotify.com/v1/audio-analysis/57bg...       292880
# 2    https://api.spotify.com/v1/audio-analysis/2Cdv...       175173
# 3    https://api.spotify.com/v1/audio-analysis/63T7...       202267
# 4    https://api.spotify.com/v1/audio-analysis/5RKQ...       249600
# ..                                                 ...          ...
# 195  https://api.spotify.com/v1/audio-analysis/5o37...       151107
# 196  https://api.spotify.com/v1/audio-analysis/4hq0...       226333
# 197  https://api.spotify.com/v1/audio-analysis/2SiX...       210173
# 198  https://api.spotify.com/v1/audio-analysis/3dmq...       273600
# 199  https://api.spotify.com/v1/audio-analysis/254b...       226653
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 195               4
# 196               4
# 197               4
# 198               4
# 199               4
#
# [200 rows x 18 columns]

# %% [markdown]
# ## Optional(Extra)

# %% [markdown]
# ## Getting the artists of the playlist

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
#
# Cell In[56], line 2, in get_artists_from_playlist(playlist_id)
#       1 def get_artists_from_playlist(playlist_id):
# ----> 2     tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
#       3     return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))
#
# Cell In[35], line 5, in get_playlist_tracks(username, playlist_id)
#       3 tracks = results['items']
#       4 while results['next']:
# ----> 5     results = sp.next(results)
#       6     tracks.extend(results['items'])
#       7 return tracks
#
# File ~/anaconda3/lib/python3.11/site-packages/spotipy/client.py:347, in Spotify.next(self, result)
#     341 """ returns the next result given a paged result
#     342
#     343     Parameters:
#     344         - result - a previously returned paged result
#     345 """
#     346 if result["next"]:
# --> 347     return self._get(result["next"])
#     348 else:
#     349     return None
#
# File ~/anaconda3/lib/python3.11/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/spotipy/client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     262 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     263              method, url, args.get("params"), headers, args.get('data'))
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#     272     results = response.json()
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/anaconda3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Getting albums

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %%
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50,country="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Same for albums ids
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %% [markdown]
# Example: Coldplay

# %%
coldplay_id = "4gzpq5DPGxSnKTe4SA8HAU"
coldplay_albums = get_albums_from_artist(coldplay_id)
coldplay_album_ids = get_album_ids_from_artist(coldplay_id)

# Check artists that played with coldplay
set([artist["name"] for track in coldplay_albums for artist in track["artists"]])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[59], line 2
#       1 coldplay_id = "4gzpq5DPGxSnKTe4SA8HAU"
# ----> 2 coldplay_albums = get_albums_from_artist(coldplay_id)
#       3 coldplay_album_ids = get_album_ids_from_artist(coldplay_id)
#       5 # Check artists that played with coldplay
#
# Cell In[58], line 5, in get_albums_from_artist(artist_id)
#       3 tracks = results['items']
#       4 while results['next']:
# ----> 5     results = sp.next(results)
#       6     tracks.extend(results['items'])
#       7 return tracks
#
# File ~/anaconda3/lib/python3.11/site-packages/spotipy/client.py:347, in Spotify.next(self, result)
#     341 """ returns the next result given a paged result
#     342
#     343     Parameters:
#     344         - result - a previously returned paged result
#     345 """
#     346 if result["next"]:
# --> 347     return self._get(result["next"])
#     348 else:
#     349     return None
#
# File ~/anaconda3/lib/python3.11/site-packages/spotipy/client.py:323, in Spotify._get(self, url, args, payload, **kwargs)
#     320 if args:
#     321     kwargs.update(args)
# --> 323 return self._internal_call("GET", url, payload, kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/spotipy/client.py:266, in Spotify._internal_call(self, method, url, payload, params)
#     262 logger.debug('Sending %s to %s with Params: %s Headers: %s and Body: %r ',
#     263              method, url, args.get("params"), headers, args.get('data'))
#     265 try:
# --> 266     response = self._session.request(
#     267         method, url, headers=headers, proxies=self.proxies,
#     268         timeout=self.requests_timeout, **args
#     269     )
#     271     response.raise_for_status()
#     272     results = response.json()
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/anaconda3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Getting the songs of a given album

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
coldplay_songs = get_track_ids_from_albums(coldplay_album_ids)

len(coldplay_songs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 coldplay_songs = get_track_ids_from_albums(coldplay_album_ids)
#       3 len(coldplay_songs)
#
# NameError: name 'coldplay_album_ids' is not defined

# %% [markdown]
# # Creation of a database

# %% [markdown]
# ## Generate a database of audio features for at least 1000 songs

# %% [markdown]
# ### Jazz

# %%
jazz_pl = sp.search(q="jazz classics", limit = 3, type = "playlist") # Search playlists

# %%
jazz_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=jazz+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': 'The best tunes in Jazz history. Cover: Wayne Shorter',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXbITWG1ZJKYt'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXbITWG1ZJKYt',
#     'id': '37i9dQZF1DXbITWG1ZJKYt',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000384ea1f3cd372087893c9a614',
#       'width': None}],
#     'name': 'Jazz Classics',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTcwNzIyMTIxMywwMDAwMDAwMDMwNDkyYWU5ODY2YWVjZTk3NzZhZWRmZjY1M2FiNTVj',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXbITWG1ZJKYt/tracks',
#      'total': 250},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DXbITWG1ZJKYt'},
#    {'collaborative': False,
#     'description': 'The best music from one of the greatest jazz labels.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTR4ZOXTfd9K'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTR4ZOXTfd9K',
#     'id': '37i9dQZF1DWTR4ZOXTfd9K',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000039c58b368ca614e808faf3bbc',
#       'width': None}],
#     'name': 'Jazz Classics Blue Note Edition',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTcwNzg5NjUxOCwwMDAwMDAwMGU5YjViMjc5Nzc5YTkxZmY4YTE0NzE1ZTJhM2Y1YzMz',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTR4ZOXTfd9K/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWTR4ZOXTfd9K'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0aL2KWnxnP5raeGcwELKlL'},
#     'href': 'https://api.spotify.com/v1/playlists/0aL2KWnxnP5raeGcwELKlL',
#     'id': '0aL2KWnxnP5raeGcwELKlL',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2732cf2794ad1584dfe722cd482ab67616d0000b2738b2d14e250ea43a8f2c500b8ab67616d0000b273c0f74b53d4cf4b14f7f5d41aab67616d0000b273faafabb803ad093938f04048',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2732cf2794ad1584dfe722cd482ab67616d0000b2738b2d14e250ea43a8f2c500b8ab67616d0000b273c0f74b53d4cf4b14f7f5d41aab67616d0000b273faafabb803ad093938f04048',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2732cf2794ad1584dfe722cd482ab67616d0000b2738b2d14e250ea43a8f2c500b8ab67616d0000b273c0f74b53d4cf4b14f7f5d41aab67616d0000b273faafabb803ad093938f04048',
#       'width': 60}],
#     'name': '100 Greatest Jazz Classics',
#     'owner': {'display_name': 'Tim',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/vvs409mlaw9nc7ucomhb2r3or'},
#      'href': 'https://api.spotify.com/v1/users/vvs409mlaw9nc7ucomhb2r3or',
#      'id': 'vvs409mlaw9nc7ucomhb2r3or',
#      'type': 'user',
#      'uri': 'spotify:user:vvs409mlaw9nc7ucomhb2r3or'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MixiYzc0MDJiYzkyZDA3NzBhNjU0YTg5Y2M1MThkMmRkNWY0OGI2NzNi',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0aL2KWnxnP5raeGcwELKlL/tracks',
#      'total': 134},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0aL2KWnxnP5raeGcwELKlL'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=jazz+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 604}}

# %%
jazz_pl_tracks = get_playlist_tracks("spotify", "37i9dQZF1DXbITWG1ZJKYt") # Extract tracks from playlist

# %%
len(jazz_pl_tracks) # Check length
# Out:
# 250

# %%
jazz_pl_ids = []
for i in jazz_pl_tracks:
    jazz_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
jazz_pl_ids_chopped = [jazz_pl_ids[i:i+chunk_size] for i in range(0,len(jazz_pl_ids), 100)]

# %%
jazz_af_list = []
for i in jazz_pl_ids_chopped:
    jazz_af_list.extend(sp.audio_features(i))
jazz_df = pd.DataFrame(jazz_af_list)

# %% [markdown]
# ### Rock

# %%
rock_pl = sp.search(q="rock classics", limit = 3, type = "playlist")

# %%
rock_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=rock+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': 'Rock legends & epic songs that continue to inspire generations. Cover: Foo Fighters',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWXRqgorJj26U'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXRqgorJj26U',
#     'id': '37i9dQZF1DWXRqgorJj26U',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000035e81461d7898c4309ef0e02d',
#       'width': None}],
#     'name': 'Rock Classics',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTcwNjA3MjQwMCwwMDAwMDAwMGY3ODgzN2RhODEyMGExOTgxMjg0NGYwYTdjZjgyOWRm',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWXRqgorJj26U/tracks',
#      'total': 200},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWXRqgorJj26U'},
#    {'collaborative': False,
#     'description': 'Bring back the good old times of the 80&#x27;-90&#x27;!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7y530m4PO4T3KnPAQqoG9I'},
#     'href': 'https://api.spotify.com/v1/playlists/7y530m4PO4T3KnPAQqoG9I',
#     'id': '7y530m4PO4T3KnPAQqoG9I',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273255e131abc1410833be95673ab67616d0000b27352f532df7ba3269b0242fed9ab67616d0000b273b3994c94dfb241923664bb4dab67616d0000b273e8dd4db47e7177c63b0b7d53',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273255e131abc1410833be95673ab67616d0000b27352f532df7ba3269b0242fed9ab67616d0000b273b3994c94dfb241923664bb4dab67616d0000b273e8dd4db47e7177c63b0b7d53',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273255e131abc1410833be95673ab67616d0000b27352f532df7ba3269b0242fed9ab67616d0000b273b3994c94dfb241923664bb4dab67616d0000b273e8dd4db47e7177c63b0b7d53',
#       'width': 60}],
#     'name': "Rock Classics 80'-90'",
#     'owner': {'display_name': 'Axel Herman',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/1147747746'},
#      'href': 'https://api.spotify.com/v1/users/1147747746',
#      'id': '1147747746',
#      'type': 'user',
#      'uri': 'spotify:user:1147747746'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NzAyLDk4YmFiZDc3ZGZmZTg2YjhhMmNmM2RiZmFjNDVhNmJjODkzNGE2M2Q=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/7y530m4PO4T3KnPAQqoG9I/tracks',
#      'total': 548},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7y530m4PO4T3KnPAQqoG9I'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3DYUw0nHB9o8tLZKQup4zp'},
#     'href': 'https://api.spotify.com/v1/playlists/3DYUw0nHB9o8tLZKQup4zp',
#     'id': '3DYUw0nHB9o8tLZKQup4zp',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2733fa684e0f8fad563122ff6dcab67616d0000b2739e994564d5e7fff06c7c7fd5ab67616d0000b273a7af122cd50575f63a156586ab67616d0000b273d7d4922d7d2b7e596084075e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2733fa684e0f8fad563122ff6dcab67616d0000b2739e994564d5e7fff06c7c7fd5ab67616d0000b273a7af122cd50575f63a156586ab67616d0000b273d7d4922d7d2b7e596084075e',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2733fa684e0f8fad563122ff6dcab67616d0000b2739e994564d5e7fff06c7c7fd5ab67616d0000b273a7af122cd50575f63a156586ab67616d0000b273d7d4922d7d2b7e596084075e',
#       'width': 60}],
#     'name': 'Classic Rock #1 Hits',
#     'owner': {'display_name': 'junglenarwal',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/junglenarwal'},
#      'href': 'https://api.spotify.com/v1/users/junglenarwal',
#      'id': 'junglenarwal',
#      'type': 'user',
#      'uri': 'spotify:user:junglenarwal'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'Mjk0LGQ3YTQ5YWQ2NmZmNzA4ZTRmZjUzZjE3MDQ4MzY4YWE1ZjExZTNkNWM=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3DYUw0nHB9o8tLZKQup4zp/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3DYUw0nHB9o8tLZKQup4zp'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=rock+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 205}}

# %%
rock_pl_tracks = get_playlist_tracks("spotify", "37i9dQZF1DWXRqgorJj26U")

# %%
len(rock_pl_tracks)
# Out:
# 200

# %%
rock_pl_ids = []
for i in rock_pl_tracks:
    rock_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
rock_pl_ids_chopped = [rock_pl_ids[i:i+chunk_size] for i in range(0,len(rock_pl_ids), 100)]

# %%
rock_af_list = []
for i in rock_pl_ids_chopped:
    rock_af_list.extend(sp.audio_features(i))
rock_df = pd.DataFrame(rock_af_list)

# %% [markdown]
# ### R&B

# %%
rnb_pl = sp.search(q="r&b classics", limit = 3, type = "playlist")

# %%
rnb_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=r%26b+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': "Throw it back with these classic R&B jams. Cover: Destiny's Child",
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX04mASjTsvf0'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX04mASjTsvf0',
#     'id': '37i9dQZF1DX04mASjTsvf0',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000318a8f2da7d5bcb61e4503434',
#       'width': None}],
#     'name': 'R&B Classics',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY4NjkxODUzOSwwMDAwMDAwMDFmMjc4ZWUwN2I0ODkzMTNjZTliOGZhMmNhOTRiMzkx',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX04mASjTsvf0/tracks',
#      'total': 100},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX04mASjTsvf0'},
#    {'collaborative': False,
#     'description': '90s-00s Rnb Classics - Best r&amp;b Music - Best Rnb Love Songs of All Time - R&amp;b All Time Favorites / Favourites - Best of Neyo, Usher, Chris Brown, Ne-Yo, Sisqo, Craig David, Mario, Nelly, Akon, Mariah Carey, Boyz II Men',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2T3BSpqN34Z4sppHDNWoeE'},
#     'href': 'https://api.spotify.com/v1/playlists/2T3BSpqN34Z4sppHDNWoeE',
#     'id': '2T3BSpqN34Z4sppHDNWoeE',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbcdcaa5e273d90fdba839069b',
#       'width': None}],
#     'name': 'R&B Classics  90s & 2000s - Best Old School RnB Hits Playlist - Usher, Chris Brown, Ne-Yo, Mario',
#     'owner': {'display_name': 'Esydia',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/savz8vts72hqdy7von3mqc29g'},
#      'href': 'https://api.spotify.com/v1/users/savz8vts72hqdy7von3mqc29g',
#      'id': 'savz8vts72hqdy7von3mqc29g',
#      'type': 'user',
#      'uri': 'spotify:user:savz8vts72hqdy7von3mqc29g'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NTgsMzY5MDM3YWQyYjUwMzQ2M2VjZDFlOGI0ZjExZjZlN2M0MTNjMmM0ZQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2T3BSpqN34Z4sppHDNWoeE/tracks',
#      'total': 146},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2T3BSpqN34Z4sppHDNWoeE'},
#    {'collaborative': False,
#     'description': 'Contemporary R&amp;B, Soul, Quiet Storm, Funk, Synth-Funk, Disco, Post-disco, New Jack Swing, Hip Hop-Soul',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/08cdGwQLSYRdoxRJZ0L2Px'},
#     'href': 'https://api.spotify.com/v1/playlists/08cdGwQLSYRdoxRJZ0L2Px',
#     'id': '08cdGwQLSYRdoxRJZ0L2Px',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb9e2fb0e04b5f687f0dac7dde',
#       'width': None}],
#     'name': 'R&B/Soul Classics: 70’s, 80’s, 90’s',
#     'owner': {'display_name': 'Guydonavonjames',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/qus9rld4i5gghyb0a39tn7pku'},
#      'href': 'https://api.spotify.com/v1/users/qus9rld4i5gghyb0a39tn7pku',
#      'id': 'qus9rld4i5gghyb0a39tn7pku',
#      'type': 'user',
#      'uri': 'spotify:user:qus9rld4i5gghyb0a39tn7pku'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTE4NSw0ZjdjMGMwYzBkMzhjYTA3MzdlMTYzNmY2M2IxMjVhNDQ1ZmEyZDZm',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/08cdGwQLSYRdoxRJZ0L2Px/tracks',
#      'total': 360},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:08cdGwQLSYRdoxRJZ0L2Px'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=r%26b+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 801}}

# %%
rnb_pl_tracks = get_playlist_tracks("spotify", "37i9dQZF1DX04mASjTsvf0")

# %%
len(rnb_pl_tracks)
# Out:
# 100

# %%
rnb_pl_ids = []
for i in rnb_pl_tracks:
    rnb_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
rnb_pl_ids_chopped = [rnb_pl_ids[i:i+chunk_size] for i in range(0,len(rnb_pl_ids), 100)]

# %%
rnb_af_list = []
for i in rnb_pl_ids_chopped:
    rnb_af_list.extend(sp.audio_features(i))
rnb_df = pd.DataFrame(rnb_af_list)

# %% [markdown]
# ### Classical

# %%
classical_pl = sp.search(q="classical classics", limit = 3, type = "playlist")

# %%
classical_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=classical+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/60n5hxFlsFXsH0AM59UQfc'},
#     'href': 'https://api.spotify.com/v1/playlists/60n5hxFlsFXsH0AM59UQfc',
#     'id': '60n5hxFlsFXsH0AM59UQfc',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730b52f5048782f691e5abc7d6ab67616d0000b27385f51c3d16dd07bf741096c3ab67616d0000b273b6c3d59abc9a81b591ffd0bdab67616d0000b273c56f2a90a94445e08a4d7c96',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730b52f5048782f691e5abc7d6ab67616d0000b27385f51c3d16dd07bf741096c3ab67616d0000b273b6c3d59abc9a81b591ffd0bdab67616d0000b273c56f2a90a94445e08a4d7c96',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730b52f5048782f691e5abc7d6ab67616d0000b27385f51c3d16dd07bf741096c3ab67616d0000b273b6c3d59abc9a81b591ffd0bdab67616d0000b273c56f2a90a94445e08a4d7c96',
#       'width': 60}],
#     'name': 'Classical classics',
#     'owner': {'display_name': 'Pearly-Couture Wrey',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/rachelwrey'},
#      'href': 'https://api.spotify.com/v1/users/rachelwrey',
#      'id': 'rachelwrey',
#      'type': 'user',
#      'uri': 'spotify:user:rachelwrey'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjA2LDY2Mzc2MGNkY2RhMTVmYzQ4YTI1MWE3NWI3MDVkOGVlZjYyY2Y5MDI=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/60n5hxFlsFXsH0AM59UQfc/tracks',
#      'total': 206},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:60n5hxFlsFXsH0AM59UQfc'},
#    {'collaborative': False,
#     'description': 'Some of the most played pieces of each composer on Spotify: Chopin, Beethoven, Lizst, Bach, Haendel, Vivaldi, Mozart, Schubert,  Mendelsshon, Schumann, Wagner, J. Strauss, Brahms, Bizet, Tchaikovsky, Mahler, Debussy, Rachmaninoff, Elgar, Fauré, Grieg, Villa-Lobos, Saint-Saëns, Dvorák',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2shU0q1gKzX4dwpYkLFrPw'},
#     'href': 'https://api.spotify.com/v1/playlists/2shU0q1gKzX4dwpYkLFrPw',
#     'id': '2shU0q1gKzX4dwpYkLFrPw',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb2038ee74077ce5af005199c7',
#       'width': None}],
#     'name': 'Top Classical Music on Spotify',
#     'owner': {'display_name': 'Rogerio Tutti',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/rogeriotutti'},
#      'href': 'https://api.spotify.com/v1/users/rogeriotutti',
#      'id': 'rogeriotutti',
#      'type': 'user',
#      'uri': 'spotify:user:rogeriotutti'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NDE1LDQzNjIyMjAwOGVmZThlYzhlOWQyODgyMzI5M2MyYjkzY2FmOGUzZGM=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2shU0q1gKzX4dwpYkLFrPw/tracks',
#      'total': 90},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2shU0q1gKzX4dwpYkLFrPw'},
#    {'collaborative': False,
#     'description': 'The most popular classical music pieces of all time.  Classical masterpieces everyone should know.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3X49yu32N3kA5o8Qqb97dE'},
#     'href': 'https://api.spotify.com/v1/playlists/3X49yu32N3kA5o8Qqb97dE',
#     'id': '3X49yu32N3kA5o8Qqb97dE',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbd53e99aa65e7fb79ce594d84',
#       'width': None}],
#     'name': 'CLASSICAL CLASSICS',
#     'owner': {'display_name': 'MusicDiary.mp4',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/irikon7'},
#      'href': 'https://api.spotify.com/v1/users/irikon7',
#      'id': 'irikon7',
#      'type': 'user',
#      'uri': 'spotify:user:irikon7'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjI4LDkzMzg0NTYzMjg5OGZhMGI5NDE3Mzc0Yzg2NGNiOTgwYzExZTRkOTE=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3X49yu32N3kA5o8Qqb97dE/tracks',
#      'total': 62},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3X49yu32N3kA5o8Qqb97dE'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=classical+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 604}}

# %%
classical_pl_tracks = get_playlist_tracks("spotify", "60n5hxFlsFXsH0AM59UQfc")

# %%
len(classical_pl_tracks)
# Out:
# 206

# %%
classical_pl_ids = []
for i in classical_pl_tracks:
    classical_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
classical_pl_ids_chopped = [classical_pl_ids[i:i+chunk_size] for i in range(0,len(classical_pl_ids), 100)]

# %%
classical_af_list = []
for i in classical_pl_ids_chopped:
    classical_af_list.extend(sp.audio_features(i))
classical_df = pd.DataFrame(classical_af_list)

# %% [markdown]
# ### Soul

# %%
soul_pl = sp.search(q="soul classics", limit = 3, type = "playlist")

# %%
soul_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=soul+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': 'Chill out to our collection of sweet soul classics - full of love, sex and positve energy. Cover: Aretha Franklin ',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/73sIU7MIIIrSh664eygyjm'},
#     'href': 'https://api.spotify.com/v1/playlists/73sIU7MIIIrSh664eygyjm',
#     'id': '73sIU7MIIIrSh664eygyjm',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebba1f8d037fa9fcd9a158114b5',
#       'width': None}],
#     'name': 'Soul Classics - The Greatest Soul Songs',
#     'owner': {'display_name': 'Topsify Deutschland',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/warner.music.central.europe'},
#      'href': 'https://api.spotify.com/v1/users/warner.music.central.europe',
#      'id': 'warner.music.central.europe',
#      'type': 'user',
#      'uri': 'spotify:user:warner.music.central.europe'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTI3MSxhMmRjYzNlZDE4OTQwM2U0MDEzODA2ZjljMzQ5YzIzMGY3OWJjZGM0',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/73sIU7MIIIrSh664eygyjm/tracks',
#      'total': 58},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:73sIU7MIIIrSh664eygyjm'},
#    {'collaborative': False,
#     'description': '<a href=spotify:playlist:37i9dQZF1EIUtKBU0VH3EA>Benson Boone</a>, <a href=spotify:playlist:37i9dQZF1EIWOy07CS5ggP>The Temptations</a>, <a href=spotify:playlist:37i9dQZF1EIVvSCgZ9bYdx>Patrick Watson</a> and more',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EQntZpEGgfBif'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EQntZpEGgfBif',
#     'id': '37i9dQZF1EQntZpEGgfBif',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/soul/22wbnEMDvgVIAGdFeek6ET/en/large',
#       'width': None}],
#     'name': 'Soul Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MCwwMDAwMDAwMDE4ODIzNzk2YTcxMWZmOTNhNjM4NDgyZGM4ZDU4ZTU5',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EQntZpEGgfBif/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EQntZpEGgfBif'},
#    {'collaborative': False,
#     'description': 'A collection of the biggest soul tracks from the 1970s. Cover: The Isley Brothers',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWULEW2RfoSCi'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWULEW2RfoSCi',
#     'id': '37i9dQZF1DWULEW2RfoSCi',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f0000000346fedbbc2ef45129b9a708cf',
#       'width': None}],
#     'name': '70s Soul Classics',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY5NzE5OTg4NywwMDAwMDAwMDk5ODIxMGVmMTI4ZDFlNDE2ZTFmOTE5NTA3MzE2MjM4',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWULEW2RfoSCi/tracks',
#      'total': 75},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWULEW2RfoSCi'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=soul+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 206}}

# %%
soul_pl_tracks = get_playlist_tracks("spotify", "73sIU7MIIIrSh664eygyjm")

# %%
len(soul_pl_tracks)
# Out:
# 58

# %%
soul_pl_ids = []
for i in soul_pl_tracks:
    soul_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
soul_pl_ids_chopped = [soul_pl_ids[i:i+chunk_size] for i in range(0,len(soul_pl_ids), 100)]

# %%
soul_af_list = []
for i in soul_pl_ids_chopped:
    soul_af_list.extend(sp.audio_features(i))
soul_df = pd.DataFrame(soul_af_list)

# %% [markdown]
# ### Electronic

# %%
electronic_pl = sp.search(q="electronic classics", limit = 3, type = "playlist")

# %%
electronic_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=electronic+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': 'Todas aquellas canciones que escuchaste en tu infancia, están aquí',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0833AQWcqlWVFZexEgjnLp'},
#     'href': 'https://api.spotify.com/v1/playlists/0833AQWcqlWVFZexEgjnLp',
#     'id': '0833AQWcqlWVFZexEgjnLp',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb141828c7d5d59dddc391518f',
#       'width': None}],
#     'name': 'Electronic Classics',
#     'owner': {'display_name': 'ELECTRIC LINE MX',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/gmsxgtpuzm557sv2idgxligym'},
#      'href': 'https://api.spotify.com/v1/users/gmsxgtpuzm557sv2idgxligym',
#      'id': 'gmsxgtpuzm557sv2idgxligym',
#      'type': 'user',
#      'uri': 'spotify:user:gmsxgtpuzm557sv2idgxligym'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NjcsMDc0N2QyNTUyZDIyM2FhMmEzNjYyNDZlYjJmOTFmYzc0NmU0YjM5MQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0833AQWcqlWVFZexEgjnLp/tracks',
#      'total': 52},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0833AQWcqlWVFZexEgjnLp'},
#    {'collaborative': False,
#     'description': 'A playlist that is all about the high-energy, adrenaline-fueled beats of electronic dance music but!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2lByMbbXWaILu2cNHIpAWo'},
#     'href': 'https://api.spotify.com/v1/playlists/2lByMbbXWaILu2cNHIpAWo',
#     'id': '2lByMbbXWaILu2cNHIpAWo',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb289c70c21adbdf4f20f5131d',
#       'width': None}],
#     'name': 'Electronic Dance Music 2024',
#     'owner': {'display_name': 'Rhytm Beat',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31fjxs7vzk2rxnx6lqykdnnmm53a'},
#      'href': 'https://api.spotify.com/v1/users/31fjxs7vzk2rxnx6lqykdnnmm53a',
#      'id': '31fjxs7vzk2rxnx6lqykdnnmm53a',
#      'type': 'user',
#      'uri': 'spotify:user:31fjxs7vzk2rxnx6lqykdnnmm53a'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTIzLGNlNmI5MjU4ZWY4ZDE3YThkYmIwMTlkZDNmYTQwMDVjNzU5M2FkYzA=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2lByMbbXWaILu2cNHIpAWo/tracks',
#      'total': 51},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2lByMbbXWaILu2cNHIpAWo'},
#    {'collaborative': False,
#     'description': 'Collection of some nostalgic tracks to take you back to the glory days of EDM - EDM Classics - Nostalgic Music - Electronic Music Playlist - EDM Playlist - Dance Music Playlist',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2yZPVFOU4MJRm2Ifyg1zpJ'},
#     'href': 'https://api.spotify.com/v1/playlists/2yZPVFOU4MJRm2Ifyg1zpJ',
#     'id': '2yZPVFOU4MJRm2Ifyg1zpJ',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbae2481899f4fa4e432bcd9d5',
#       'width': None}],
#     'name': 'EDM Classics',
#     'owner': {'display_name': 'Proximity',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/prxmusic'},
#      'href': 'https://api.spotify.com/v1/users/prxmusic',
#      'id': 'prxmusic',
#      'type': 'user',
#      'uri': 'spotify:user:prxmusic'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzY3LDMwY2U1MTNmYWE2ZWY3ZWVlNDgxZjIzNzY5MzI5ZTQ0NTc0ODRhMzk=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2yZPVFOU4MJRm2Ifyg1zpJ/tracks',
#      'total': 106},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2yZPVFOU4MJRm2Ifyg1zpJ'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=electronic+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 753}}

# %%
electronic_pl_tracks = get_playlist_tracks("spotify", "2yZPVFOU4MJRm2Ifyg1zpJ")

# %%
len(electronic_pl_tracks)
# Out:
# 106

# %%
electronic_pl_ids = []
for i in electronic_pl_tracks:
    electronic_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
electronic_pl_ids_chopped = [electronic_pl_ids[i:i+chunk_size] for i in range(0,len(electronic_pl_ids), 100)]

# %%
electronic_af_list = []
for i in electronic_pl_ids_chopped:
    electronic_af_list.extend(sp.audio_features(i))
electronic_df = pd.DataFrame(electronic_af_list)

# %% [markdown]
# ### Funk

# %%
funk_pl = sp.search(q="funk classics", limit = 3, type = "playlist")

# %%
funk_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=funk+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': 'A playlist of some of our favourite funk tracks, enjoy!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2mo0m9v49zuZMvES6439WU'},
#     'href': 'https://api.spotify.com/v1/playlists/2mo0m9v49zuZMvES6439WU',
#     'id': '2mo0m9v49zuZMvES6439WU',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730b1804895a3ce499c4212bcaab67616d0000b273309e64d0bfd9cf7ff9827f72ab67616d0000b273a4c51affb9a29adc001a1853ab67616d0000b273dc6b1a7c9f5a7049c01926bc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730b1804895a3ce499c4212bcaab67616d0000b273309e64d0bfd9cf7ff9827f72ab67616d0000b273a4c51affb9a29adc001a1853ab67616d0000b273dc6b1a7c9f5a7049c01926bc',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730b1804895a3ce499c4212bcaab67616d0000b273309e64d0bfd9cf7ff9827f72ab67616d0000b273a4c51affb9a29adc001a1853ab67616d0000b273dc6b1a7c9f5a7049c01926bc',
#       'width': 60}],
#     'name': 'Funk Classics',
#     'owner': {'display_name': 'Brooklyn Funk Essentials',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/bfemusic'},
#      'href': 'https://api.spotify.com/v1/users/bfemusic',
#      'id': 'bfemusic',
#      'type': 'user',
#      'uri': 'spotify:user:bfemusic'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NzAsODVhNmMwMWU1Mjg3MjM3MmVjMDAzYmU3M2Q2ZTM3YjZmMWU5OTEzOA==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2mo0m9v49zuZMvES6439WU/tracks',
#      'total': 44},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2mo0m9v49zuZMvES6439WU'},
#    {'collaborative': False,
#     'description': 'Old School Funk music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIfqkfSDVB2GV'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIfqkfSDVB2GV',
#     'id': '37i9dQZF1EIfqkfSDVB2GV',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/Old%20School%20Funk/en/large',
#       'width': None}],
#     'name': 'Old School Funk Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3NjcsMDAwMDAwMDA5ZWZiNWQzZjYwMTAzYzA4NWYwOGVjYjVlZjY1OTRiMw==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIfqkfSDVB2GV/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIfqkfSDVB2GV'},
#    {'collaborative': False,
#     'description': 'Taking you back to the disco days one funky song at a time! This playlist includes hits from Zapp, Tina Marie, The Paliment, The Gap Band, Cameo, Rick James, The S.O.S Band, Earth, Wind, and Fire, and so many other classic hits from the era. Throw on this playlist and have a good time!! Enjoy!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2AZUHDZFQDYmltl29G8rn0'},
#     'href': 'https://api.spotify.com/v1/playlists/2AZUHDZFQDYmltl29G8rn0',
#     'id': '2AZUHDZFQDYmltl29G8rn0',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb68a08889dd6a8d710c63cea3',
#       'width': None}],
#     'name': "70's, 80's, and 90's Funk Classics",
#     'owner': {'display_name': 'LG',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/lgonzales6903'},
#      'href': 'https://api.spotify.com/v1/users/lgonzales6903',
#      'id': 'lgonzales6903',
#      'type': 'user',
#      'uri': 'spotify:user:lgonzales6903'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjkxLDIyMmRlZGIyYjZmMjVlYjM5OGUxNjQwODI0NTliYTU3MjQ3NmYwODM=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2AZUHDZFQDYmltl29G8rn0/tracks',
#      'total': 251},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2AZUHDZFQDYmltl29G8rn0'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=funk+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 605}}

# %%
funk_pl_tracks = get_playlist_tracks("spotify", "2AZUHDZFQDYmltl29G8rn0")

# %%
len(funk_pl_tracks)
# Out:
# 251

# %%
funk_pl_ids = []
for i in funk_pl_tracks:
    funk_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
funk_pl_ids_chopped = [funk_pl_ids[i:i+chunk_size] for i in range(0,len(funk_pl_ids), 100)]

# %%
funk_af_list = []
for i in funk_pl_ids_chopped:
    funk_af_list.extend(sp.audio_features(i))
funk_df = pd.DataFrame(funk_af_list)

# %% [markdown]
# ### Rap

# %%
rap_pl = sp.search(q="rap classics", limit = 3, type = "playlist")

# %%
rap_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=rap+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': 'Best of rap classics and old school rap',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0h9Gaqt2sNJ8M5aMV3h9BO'},
#     'href': 'https://api.spotify.com/v1/playlists/0h9Gaqt2sNJ8M5aMV3h9BO',
#     'id': '0h9Gaqt2sNJ8M5aMV3h9BO',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730b69fe379d73fd385175ef33ab67616d0000b2733b5e11ca1b063583df9492dbab67616d0000b273d843fabb75fef14010e30caeab67616d0000b273e1006755aa74151e4e04775d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730b69fe379d73fd385175ef33ab67616d0000b2733b5e11ca1b063583df9492dbab67616d0000b273d843fabb75fef14010e30caeab67616d0000b273e1006755aa74151e4e04775d',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730b69fe379d73fd385175ef33ab67616d0000b2733b5e11ca1b063583df9492dbab67616d0000b273d843fabb75fef14010e30caeab67616d0000b273e1006755aa74151e4e04775d',
#       'width': 60}],
#     'name': 'Rap Classics 1990 - 2010',
#     'owner': {'display_name': 'alphamale21',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/j5t5jqg3imunyy978cl67frd9'},
#      'href': 'https://api.spotify.com/v1/users/j5t5jqg3imunyy978cl67frd9',
#      'id': 'j5t5jqg3imunyy978cl67frd9',
#      'type': 'user',
#      'uri': 'spotify:user:j5t5jqg3imunyy978cl67frd9'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY2MCw4NDNmMGYzZjc4YmNjMDcyYTM4NGJiZTExNTQyODQ1YmZhZWU5M2Vh',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0h9Gaqt2sNJ8M5aMV3h9BO/tracks',
#      'total': 81},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0h9Gaqt2sNJ8M5aMV3h9BO'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/4K99Kk1PLl10SHd3XwI8QG'},
#     'href': 'https://api.spotify.com/v1/playlists/4K99Kk1PLl10SHd3XwI8QG',
#     'id': '4K99Kk1PLl10SHd3XwI8QG',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb157aab8912f0cf0f32d65d96',
#       'width': None}],
#     'name': '2010-2023 Rap Classics',
#     'owner': {'display_name': 'Conner Norsworthy',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31ryykzjaaakh4rfyepec7hyoyj4'},
#      'href': 'https://api.spotify.com/v1/users/31ryykzjaaakh4rfyepec7hyoyj4',
#      'id': '31ryykzjaaakh4rfyepec7hyoyj4',
#      'type': 'user',
#      'uri': 'spotify:user:31ryykzjaaakh4rfyepec7hyoyj4'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NjIsZWFiNzFmZjdmZTQwOTg0OTdiMjM5ODE4YzhjNDFkNmYzMGM3ZDBiZg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/4K99Kk1PLl10SHd3XwI8QG/tracks',
#      'total': 348},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:4K99Kk1PLl10SHd3XwI8QG'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2b4FnuDyXXgl7Sye8e8Nvc'},
#     'href': 'https://api.spotify.com/v1/playlists/2b4FnuDyXXgl7Sye8e8Nvc',
#     'id': '2b4FnuDyXXgl7Sye8e8Nvc',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb11c503dcaddeace0d287d2ed',
#       'width': None}],
#     'name': 'RAP CLASSICS 900+ SONGS',
#     'owner': {'display_name': 'Eemil Kärkkäinen',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/embyyyz'},
#      'href': 'https://api.spotify.com/v1/users/embyyyz',
#      'id': 'embyyyz',
#      'type': 'user',
#      'uri': 'spotify:user:embyyyz'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjgwNSw1MmEzY2ZjNGIzNWNlM2Y1Yzc2MGI4ODI0OTM4Y2U3NDIyMjZiZjVh',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2b4FnuDyXXgl7Sye8e8Nvc/tracks',
#      'total': 910},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2b4FnuDyXXgl7Sye8e8Nvc'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=rap+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 604}}

# %%
rap_pl_tracks = get_playlist_tracks("spotify", "4K99Kk1PLl10SHd3XwI8QG")

# %%
len(rap_pl_tracks)
# Out:
# 348

# %%
rap_pl_ids = []
for i in rap_pl_tracks:
    rap_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
rap_pl_ids_chopped = [rap_pl_ids[i:i+chunk_size] for i in range(0,len(rap_pl_ids), 100)]

# %%
rap_af_list = []
for i in rap_pl_ids_chopped:
    rap_af_list.extend(sp.audio_features(i))
rap_df = pd.DataFrame(rap_af_list)

# %% [markdown]
# ### Swing

# %%
swing_pl = sp.search(q="swing classics", limit = 3, type = "playlist")

# %%
swing_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=swing+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/29m5kPlOLbTJv3yjQpXVzz'},
#     'href': 'https://api.spotify.com/v1/playlists/29m5kPlOLbTJv3yjQpXVzz',
#     'id': '29m5kPlOLbTJv3yjQpXVzz',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2737167de1e674916f63defe96cab67616d0000b27377493407c6c36befcbc30de7ab67616d0000b273e774643594281699bde1e4edab67616d0000b273ff0dae802acb38075786b58c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2737167de1e674916f63defe96cab67616d0000b27377493407c6c36befcbc30de7ab67616d0000b273e774643594281699bde1e4edab67616d0000b273ff0dae802acb38075786b58c',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2737167de1e674916f63defe96cab67616d0000b27377493407c6c36befcbc30de7ab67616d0000b273e774643594281699bde1e4edab67616d0000b273ff0dae802acb38075786b58c',
#       'width': 60}],
#     'name': 'Swing Classics',
#     'owner': {'display_name': 'davidpatrickgeier',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/davidpatrickgeier'},
#      'href': 'https://api.spotify.com/v1/users/davidpatrickgeier',
#      'id': 'davidpatrickgeier',
#      'type': 'user',
#      'uri': 'spotify:user:davidpatrickgeier'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'Miw4MGY5OTJlMjA4MmNlOTU5ODJmY2YxNDFhNGQ4YWQ4ZWMxZDEzMzBj',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/29m5kPlOLbTJv3yjQpXVzz/tracks',
#      'total': 156},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:29m5kPlOLbTJv3yjQpXVzz'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/3NUSByg8UpRkMtlKbLLb8J'},
#     'href': 'https://api.spotify.com/v1/playlists/3NUSByg8UpRkMtlKbLLb8J',
#     'id': '3NUSByg8UpRkMtlKbLLb8J',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730f34b77050443bd07106e3c1ab67616d0000b2733335fd63e5720e19d7c08204ab67616d0000b2738cf5cdf2a3ed6729f573154cab67616d0000b273b81d66d1416afa139d12767b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730f34b77050443bd07106e3c1ab67616d0000b2733335fd63e5720e19d7c08204ab67616d0000b2738cf5cdf2a3ed6729f573154cab67616d0000b273b81d66d1416afa139d12767b',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730f34b77050443bd07106e3c1ab67616d0000b2733335fd63e5720e19d7c08204ab67616d0000b2738cf5cdf2a3ed6729f573154cab67616d0000b273b81d66d1416afa139d12767b',
#       'width': 60}],
#     'name': 'Best Swing Dance Music',
#     'owner': {'display_name': '1211974887',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/1211974887'},
#      'href': 'https://api.spotify.com/v1/users/1211974887',
#      'id': '1211974887',
#      'type': 'user',
#      'uri': 'spotify:user:1211974887'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTU5LGIyNTA0MzhjYmI5ZWEyOTBlMjk3OTJmYmQwMmRiZGUyNDg1MDg5NzQ=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/3NUSByg8UpRkMtlKbLLb8J/tracks',
#      'total': 107},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:3NUSByg8UpRkMtlKbLLb8J'},
#    {'collaborative': False,
#     'description': 'Big Band Classics',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/4NhVQcxtaFiIsNCI7eNg3N'},
#     'href': 'https://api.spotify.com/v1/playlists/4NhVQcxtaFiIsNCI7eNg3N',
#     'id': '4NhVQcxtaFiIsNCI7eNg3N',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2736a07ae0cc876b3d0dc4d076fab67616d0000b273931d322311d03a8294c93740ab67616d0000b2739675ba265c48533a19c64cbfab67616d0000b273a3559a3ebc86b509392dc6b9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2736a07ae0cc876b3d0dc4d076fab67616d0000b273931d322311d03a8294c93740ab67616d0000b2739675ba265c48533a19c64cbfab67616d0000b273a3559a3ebc86b509392dc6b9',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2736a07ae0cc876b3d0dc4d076fab67616d0000b273931d322311d03a8294c93740ab67616d0000b2739675ba265c48533a19c64cbfab67616d0000b273a3559a3ebc86b509392dc6b9',
#       'width': 60}],
#     'name': 'BIG BAND CLASSICS',
#     'owner': {'display_name': 'jaydonsr',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/jaydonsr'},
#      'href': 'https://api.spotify.com/v1/users/jaydonsr',
#      'id': 'jaydonsr',
#      'type': 'user',
#      'uri': 'spotify:user:jaydonsr'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjQ0LDI5MzJmNjk5Yzk3MTViYjJhNGFlMjc0NmExNzRiMmRmZDJhYzJhNmY=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/4NhVQcxtaFiIsNCI7eNg3N/tracks',
#      'total': 94},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:4NhVQcxtaFiIsNCI7eNg3N'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=swing+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 603}}

# %%
swing_pl_tracks = get_playlist_tracks("spotify", "29m5kPlOLbTJv3yjQpXVzz")

# %%
len(swing_pl_tracks)
# Out:
# 156

# %%
swing_pl_ids = []
for i in swing_pl_tracks:
    swing_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
swing_pl_ids_chopped = [swing_pl_ids[i:i+chunk_size] for i in range(0,len(swing_pl_ids), 100)]

# %%
swing_af_list = []
for i in swing_pl_ids_chopped:
    swing_af_list.extend(sp.audio_features(i))
swing_df = pd.DataFrame(swing_af_list)

# %% [markdown]
# ### Dance

# %%
dance_pl = sp.search(q="dance classics", limit = 3, type = "playlist")

# %%
dance_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=dance+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': '<a href="spotify:genre:edm_dance">Dance</a> hits from the 90s and 00s!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX8a1tdzq5tbM'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8a1tdzq5tbM',
#     'id': '37i9dQZF1DX8a1tdzq5tbM',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000032da2d07c587623848d44b52d',
#       'width': None}],
#     'name': 'Dance Classics',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTcwNzc1MjAzNCwwMDAwMDAwMDAyNWVhZmQwZmI2NTY1N2U0NjVlZmFiOTU4YzA5YjI1',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX8a1tdzq5tbM/tracks',
#      'total': 120},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX8a1tdzq5tbM'},
#    {'collaborative': False,
#     'description': 'La playlist des plus grands hits Electro & Dance.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX1zcQs2sF77z'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1zcQs2sF77z',
#     'id': '37i9dQZF1DX1zcQs2sF77z',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003d8db6512f85a1557af713bca',
#       'width': None}],
#     'name': 'Dancefloor Classics',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTcwNzMyNDA3NiwwMDAwMDAwMGI1ZmJhMDIzNzBmYTFiOGJiZjc3MzUwOThiMTk2MjQx',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX1zcQs2sF77z/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX1zcQs2sF77z'},
#    {'collaborative': False,
#     'description': 'PLAYLIST WILL BE CONSTANTLY UPDATED ... Ibiza Records ® DANCE CLASSICS',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0DzNT0PnPs7rA4THSGLGX8'},
#     'href': 'https://api.spotify.com/v1/playlists/0DzNT0PnPs7rA4THSGLGX8',
#     'id': '0DzNT0PnPs7rA4THSGLGX8',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb802980967f0c50afdf92e8f7',
#       'width': None}],
#     'name': 'DANCE CLASSICS',
#     'owner': {'display_name': 'Ibiza Records',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31aakarzdgsyneqlmnx7lyqotuim'},
#      'href': 'https://api.spotify.com/v1/users/31aakarzdgsyneqlmnx7lyqotuim',
#      'id': '31aakarzdgsyneqlmnx7lyqotuim',
#      'type': 'user',
#      'uri': 'spotify:user:31aakarzdgsyneqlmnx7lyqotuim'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NTksMWEzMzIyMjdhOTQ3MjA5MGM5ZGU0M2Q1N2M3MmU3ZDNhZTcyYWM1OQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0DzNT0PnPs7rA4THSGLGX8/tracks',
#      'total': 52},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0DzNT0PnPs7rA4THSGLGX8'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=dance+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 404}}

# %%
dance_pl_tracks = get_playlist_tracks("spotify", "37i9dQZF1DX8a1tdzq5tbM")

# %%
len(dance_pl_tracks)
# Out:
# 120

# %%
dance_pl_ids = []
for i in dance_pl_tracks:
    dance_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
dance_pl_ids_chopped = [dance_pl_ids[i:i+chunk_size] for i in range(0,len(dance_pl_ids), 100)]

# %%
dance_af_list = []
for i in dance_pl_ids_chopped:
    dance_af_list.extend(sp.audio_features(i))
dance_df = pd.DataFrame(dance_af_list)

# %% [markdown]
# ### Folk

# %%
folk_pl = sp.search(q="folk classics", limit = 3, type = "playlist")

# %%
folk_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=folk+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': 'A collection of classics from the height of the folk revival to the rise of the folk rock era. Cover: Bob Dylan',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWVmps5U8gHNv'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVmps5U8gHNv',
#     'id': '37i9dQZF1DWVmps5U8gHNv',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000039580c19572e987e193bac6ca',
#       'width': None}],
#     'name': 'Essential Folk',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY5MTU5OTY0MSwwMDAwMDAwMDhkMGIwZmQyZmNjMmQyOGFiMTdhYjdhNzdmYWZiMzQy',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWVmps5U8gHNv/tracks',
#      'total': 115},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DWVmps5U8gHNv'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6VmAVUtfvFS3fOhf3baX6o'},
#     'href': 'https://api.spotify.com/v1/playlists/6VmAVUtfvFS3fOhf3baX6o',
#     'id': '6VmAVUtfvFS3fOhf3baX6o',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2732dfe9ba6abd85c654f6c5cf1ab67616d0000b2734d7a73d8cfbe69b4c3fad5a1ab67616d0000b273716eefe293995fc9c4bc6827ab67616d0000b2737943746f867dbdcbcf1c1772',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2732dfe9ba6abd85c654f6c5cf1ab67616d0000b2734d7a73d8cfbe69b4c3fad5a1ab67616d0000b273716eefe293995fc9c4bc6827ab67616d0000b2737943746f867dbdcbcf1c1772',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2732dfe9ba6abd85c654f6c5cf1ab67616d0000b2734d7a73d8cfbe69b4c3fad5a1ab67616d0000b273716eefe293995fc9c4bc6827ab67616d0000b2737943746f867dbdcbcf1c1772',
#       'width': 60}],
#     'name': 'American folk classics',
#     'owner': {'display_name': 'Grant Rielly',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/e0132370'},
#      'href': 'https://api.spotify.com/v1/users/e0132370',
#      'id': 'e0132370',
#      'type': 'user',
#      'uri': 'spotify:user:e0132370'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTMwLDFiYjc3MDA0NzNlNTBjYmY2MTkxZjYyOWY5ZDFkM2M0MDY5NmYyYzU=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6VmAVUtfvFS3fOhf3baX6o/tracks',
#      'total': 127},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6VmAVUtfvFS3fOhf3baX6o'},
#    {'collaborative': False,
#     'description': '<a href=spotify:playlist:37i9dQZF1EIVEXZTzSrj43>Richy Mitch & The Coal Miners</a>, <a href=spotify:playlist:37i9dQZF1EIYJL0ip01fjK>Tracy Chapman</a>, <a href=spotify:playlist:37i9dQZF1EIXDGo0vWYROm>Noah Kahan</a> et bien plus',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EQp62d3Dl7ECY'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EQp62d3Dl7ECY',
#     'id': '37i9dQZF1EQp62d3Dl7ECY',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/folk_acoustic/4qU7IJSReZnsLy5907Mtau/en/large',
#       'width': None}],
#     'name': 'Folk & Acoustic Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MCwwMDAwMDAwMDZkMWEwZjBhYzI4YWI3YzliZDllNjFkMDQzYWFkMzY4',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EQp62d3Dl7ECY/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EQp62d3Dl7ECY'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=folk+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 625}}

# %%
folk_pl_tracks = get_playlist_tracks("spotify", "37i9dQZF1DWVmps5U8gHNv")

# %%
len(folk_pl_tracks)
# Out:
# 115

# %%
folk_pl_ids = []
for i in folk_pl_tracks:
    folk_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
folk_pl_ids_chopped = [folk_pl_ids[i:i+chunk_size] for i in range(0,len(folk_pl_ids), 100)]

# %%
folk_af_list = []
for i in folk_pl_ids_chopped:
    folk_af_list.extend(sp.audio_features(i))
folk_df = pd.DataFrame(folk_af_list)

# %% [markdown]
# ### Pop

# %%
pop_pl = sp.search(q="pop classics", limit = 3, type = "playlist")

# %%
pop_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=pop+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7iUGicmg9AkkFhkLiYqYpA'},
#     'href': 'https://api.spotify.com/v1/playlists/7iUGicmg9AkkFhkLiYqYpA',
#     'id': '7iUGicmg9AkkFhkLiYqYpA',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbb3d8b2e3af31967186d9e3f0',
#       'width': None}],
#     'name': 'Pop classics 2010-2023',
#     'owner': {'display_name': 'Nanga',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/pq4yjx8ygqab8vyv4kz5m0szr'},
#      'href': 'https://api.spotify.com/v1/users/pq4yjx8ygqab8vyv4kz5m0szr',
#      'id': 'pq4yjx8ygqab8vyv4kz5m0szr',
#      'type': 'user',
#      'uri': 'spotify:user:pq4yjx8ygqab8vyv4kz5m0szr'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'ODk3LDQ0MDcxODJjNmU5MjViYzExZWEwMWUzMjI5ZTEwMDBhMTc1M2NjNTc=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/7iUGicmg9AkkFhkLiYqYpA/tracks',
#      'total': 480},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7iUGicmg9AkkFhkLiYqYpA'},
#    {'collaborative': False,
#     'description': "A trip down pop's memory lane.",
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX4v0Y84QklHD'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4v0Y84QklHD',
#     'id': '37i9dQZF1DX4v0Y84QklHD',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f000000039a301b01b8ececc2159108eb',
#       'width': None}],
#     'name': 'Classic Pop Picks',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY4NjgzNTQ1MywwMDAwMDAwMDFiN2NlODMwOTRiZmQ0ZGFmOGQxMjU4OTEyODliZmMy',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX4v0Y84QklHD/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX4v0Y84QklHD'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/55OXRZi5CH4pRD6YA8vrY2'},
#     'href': 'https://api.spotify.com/v1/playlists/55OXRZi5CH4pRD6YA8vrY2',
#     'id': '55OXRZi5CH4pRD6YA8vrY2',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b27305fb4e9947c6edaf3836766eab67616d0000b27313c6cb6a81c8db4dbc8b9924ab67616d0000b273604f8ac39f15d287e251f193ab67616d0000b273a9929deb093a6617d2493b03',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b27305fb4e9947c6edaf3836766eab67616d0000b27313c6cb6a81c8db4dbc8b9924ab67616d0000b273604f8ac39f15d287e251f193ab67616d0000b273a9929deb093a6617d2493b03',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b27305fb4e9947c6edaf3836766eab67616d0000b27313c6cb6a81c8db4dbc8b9924ab67616d0000b273604f8ac39f15d287e251f193ab67616d0000b273a9929deb093a6617d2493b03',
#       'width': 60}],
#     'name': 'Pop Classics ',
#     'owner': {'display_name': 'Omar Zeta',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/1283928719'},
#      'href': 'https://api.spotify.com/v1/users/1283928719',
#      'id': '1283928719',
#      'type': 'user',
#      'uri': 'spotify:user:1283928719'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NTUsODk1YTk5ZjQ5NDlkNTQ4NTU1OGE0NDA0N2Q5ZGRiOWRhNDJhZTZlZA==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/55OXRZi5CH4pRD6YA8vrY2/tracks',
#      'total': 43},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:55OXRZi5CH4pRD6YA8vrY2'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=pop+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 802}}

# %%
pop_pl_tracks = get_playlist_tracks("spotify", "7iUGicmg9AkkFhkLiYqYpA")

# %%
len(pop_pl_tracks)
# Out:
# 480

# %%
pop_pl_ids = []
for i in pop_pl_tracks:
    pop_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
pop_pl_ids_chopped = [pop_pl_ids[i:i+chunk_size] for i in range(0,len(pop_pl_ids), 100)]

# %%
pop_af_list = []
for i in pop_pl_ids_chopped:
    pop_af_list.extend(sp.audio_features(i))
pop_df = pd.DataFrame(pop_af_list)

# %% [markdown]
# ### Christmas

# %%
christmas_pl = sp.search(q="christmas classics", limit = 3, type = "playlist")

# %%
christmas_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=christmas+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': 'Timeless heart-warming classics from 1940- 1980 for the holiday season.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX6R7QUWePReA'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6R7QUWePReA',
#     'id': '37i9dQZF1DX6R7QUWePReA',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003b70e0f51ac4cf9d62cee4977',
#       'width': None}],
#     'name': 'Christmas Classics',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTcwMTk3MzE4OCwwMDAwMDAwMDYwMzE0MjZjOTdjMWE1NTU0MzRjYTA5M2Y4ZWFmNzgz',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX6R7QUWePReA/tracks',
#      'total': 75},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX6R7QUWePReA'},
#    {'collaborative': False,
#     'description': 'Best compilation Christmas songs on the planet!!',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/1zOEqfxkCekU1Y6nZoeuyI'},
#     'href': 'https://api.spotify.com/v1/playlists/1zOEqfxkCekU1Y6nZoeuyI',
#     'id': '1zOEqfxkCekU1Y6nZoeuyI',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebba4868d2b7b9ead5ce1cad182',
#       'width': None}],
#     'name': 'World’s Best Christmas Playlist',
#     'owner': {'display_name': 'Henry Janzen',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/mrvideoman619'},
#      'href': 'https://api.spotify.com/v1/users/mrvideoman619',
#      'id': 'mrvideoman619',
#      'type': 'user',
#      'uri': 'spotify:user:mrvideoman619'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'Mjc3NSw2ZjI5MzVmZWNhZjg5YzM1YTQ1NWFkMjFiZGVhYzA1YTgxOGQwNjEy',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/1zOEqfxkCekU1Y6nZoeuyI/tracks',
#      'total': 194},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1zOEqfxkCekU1Y6nZoeuyI'},
#    {'collaborative': False,
#     'description': 'a holly jolly christmas ',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/0CAGIfUBfztBRBnM4O7Yn5'},
#     'href': 'https://api.spotify.com/v1/playlists/0CAGIfUBfztBRBnM4O7Yn5',
#     'id': '0CAGIfUBfztBRBnM4O7Yn5',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb5096159143825df6750abc30',
#       'width': None}],
#     'name': 'christmas classics',
#     'owner': {'display_name': 'Renee Amberg',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/499i88qeschl8yz5pkjnx3yqs'},
#      'href': 'https://api.spotify.com/v1/users/499i88qeschl8yz5pkjnx3yqs',
#      'id': '499i88qeschl8yz5pkjnx3yqs',
#      'type': 'user',
#      'uri': 'spotify:user:499i88qeschl8yz5pkjnx3yqs'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjEsYjA4NzUxNjQ4MWMzYmQ4MWNlNzM5YzM4Zjk4MjA5OGIwMmE2ZWZlMQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/0CAGIfUBfztBRBnM4O7Yn5/tracks',
#      'total': 70},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:0CAGIfUBfztBRBnM4O7Yn5'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=christmas+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 804}}

# %%
christmas_pl_tracks = get_playlist_tracks("spotify", "37i9dQZF1DX0Yxoavh5qJV")

# %%
len(christmas_pl_tracks)
# Out:
# 100

# %%
christmas_pl_ids = []
for i in christmas_pl_tracks:
    christmas_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
christmas_pl_ids_chopped = [christmas_pl_ids[i:i+chunk_size] for i in range(0,len(pop_pl_ids), 100)]

# %%
christmas_af_list = []
for i in pop_pl_ids_chopped:
    christmas_af_list.extend(sp.audio_features(i))
christmas_df = pd.DataFrame(christmas_af_list)

# %% [markdown]
# ### Kids music

# %%
kids_pl = sp.search(q="childrens classics", limit = 3, type = "playlist")

# %%
kids_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=childrens+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/44G5Bbh908McrE13iZV35k'},
#     'href': 'https://api.spotify.com/v1/playlists/44G5Bbh908McrE13iZV35k',
#     'id': '44G5Bbh908McrE13iZV35k',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273176ba9c42986c520b5983dcbab67616d0000b273206c58c0eb9916d4eb32c1feab67616d0000b27332351dbb591547b22380ce1dab67616d0000b2735e7bedcd37361fbd0cb7b5fa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273176ba9c42986c520b5983dcbab67616d0000b273206c58c0eb9916d4eb32c1feab67616d0000b27332351dbb591547b22380ce1dab67616d0000b2735e7bedcd37361fbd0cb7b5fa',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273176ba9c42986c520b5983dcbab67616d0000b273206c58c0eb9916d4eb32c1feab67616d0000b27332351dbb591547b22380ce1dab67616d0000b2735e7bedcd37361fbd0cb7b5fa',
#       'width': 60}],
#     'name': "Children's classics",
#     'owner': {'display_name': 'Matana',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/7hip4r5cyzdiu6xn3z9a7tbve'},
#      'href': 'https://api.spotify.com/v1/users/7hip4r5cyzdiu6xn3z9a7tbve',
#      'id': '7hip4r5cyzdiu6xn3z9a7tbve',
#      'type': 'user',
#      'uri': 'spotify:user:7hip4r5cyzdiu6xn3z9a7tbve'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjcwLDZlZmI1MGI2NjIyOWRjMmE2MjkxZTM0M2U1ZDQ3NWZjOGU4ODc4MjA=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/44G5Bbh908McrE13iZV35k/tracks',
#      'total': 70},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:44G5Bbh908McrE13iZV35k'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/7qKQlC02CdmqBsEgLw5IjD'},
#     'href': 'https://api.spotify.com/v1/playlists/7qKQlC02CdmqBsEgLw5IjD',
#     'id': '7qKQlC02CdmqBsEgLw5IjD',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b27345ac313a864335afe37a7a0aab67616d0000b2735d0eae0df49b85e0120271fbab67616d0000b27393c2aa7b2bbed7b568b5d406ab67616d0000b273cc72ab8af8e579b2fb5ac81a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b27345ac313a864335afe37a7a0aab67616d0000b2735d0eae0df49b85e0120271fbab67616d0000b27393c2aa7b2bbed7b568b5d406ab67616d0000b273cc72ab8af8e579b2fb5ac81a',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b27345ac313a864335afe37a7a0aab67616d0000b2735d0eae0df49b85e0120271fbab67616d0000b27393c2aa7b2bbed7b568b5d406ab67616d0000b273cc72ab8af8e579b2fb5ac81a',
#       'width': 60}],
#     'name': 'Classic Children’s Stories',
#     'owner': {'display_name': 'Alex Anne Walter',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/1144466279'},
#      'href': 'https://api.spotify.com/v1/users/1144466279',
#      'id': '1144466279',
#      'type': 'user',
#      'uri': 'spotify:user:1144466279'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzEsMzUyODIyMzM5MTQzMjgwNTQyYTVjNWMzZWM3MTNjZGY4MjdlMjgzNw==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/7qKQlC02CdmqBsEgLw5IjD/tracks',
#      'total': 30},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:7qKQlC02CdmqBsEgLw5IjD'},
#    {'collaborative': False,
#     'description': 'Discover this mindfully curated and inspirational playlist for young listeners with numerous key works out of the fascinating world of classical music. This collection is designed for the colourful everyday life of youngsters: dancing, playing, or even spending a long car ride in the back seat.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6imHrBwBAleXByajtH5NXI'},
#     'href': 'https://api.spotify.com/v1/playlists/6imHrBwBAleXByajtH5NXI',
#     'id': '6imHrBwBAleXByajtH5NXI',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb64e23188ba1581008070f98b',
#       'width': None}],
#     'name': 'Classical Music for Children',
#     'owner': {'display_name': 'Deutsche Grammophon (DG)',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/deutschegrammophon'},
#      'href': 'https://api.spotify.com/v1/users/deutschegrammophon',
#      'id': 'deutschegrammophon',
#      'type': 'user',
#      'uri': 'spotify:user:deutschegrammophon'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzEsOWFjYjAyMGEwZTUwMDUyZTI5NzAzNmI3YmI5M2ZiZmE3ODU2YjU5NQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6imHrBwBAleXByajtH5NXI/tracks',
#      'total': 54},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6imHrBwBAleXByajtH5NXI'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=childrens+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 646}}

# %%
kids_pl_tracks = get_playlist_tracks("spotify", "44G5Bbh908McrE13iZV35k")

# %%
len(kids_pl_tracks)
# Out:
# 70

# %%
kids_pl_ids = []
for i in kids_pl_tracks:
    kids_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
kids_pl_ids_chopped = [kids_pl_ids[i:i+chunk_size] for i in range(0,len(kids_pl_ids), 100)]

# %%
kids_af_list = []
for i in kids_pl_ids_chopped:
    kids_af_list.extend(sp.audio_features(i))
kids_df = pd.DataFrame(kids_af_list)

# %% [markdown]
# ### Schlager music

# %%
schlager_pl = sp.search(q="german schlager classics", limit = 3, type = "playlist")

# %%
schlager_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=german+schlager+classics&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': 'Munich beer tent festival XXL Marquee Music Polka Classics fest',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/4XjTSrjyN9I0uZbrDcMVwX'},
#     'href': 'https://api.spotify.com/v1/playlists/4XjTSrjyN9I0uZbrDcMVwX',
#     'id': '4XjTSrjyN9I0uZbrDcMVwX',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb44dedbc99ff18a7760d48ec5',
#       'width': None}],
#     'name': 'Octoberfest 2023 - German Oktoberfest Hits 2023 After Wiesn Beerfest Schlager - Bavarian Wiesn Hits',
#     'owner': {'display_name': 'HITMIX Music',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/hitmix.music_official.label'},
#      'href': 'https://api.spotify.com/v1/users/hitmix.music_official.label',
#      'id': 'hitmix.music_official.label',
#      'type': 'user',
#      'uri': 'spotify:user:hitmix.music_official.label'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MjMsNGY5ODA0MzFjOTYwMGIxYTI4MjgwNWExMmRhNzRhNGRmNTNiNWNhNg==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/4XjTSrjyN9I0uZbrDcMVwX/tracks',
#      'total': 156},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:4XjTSrjyN9I0uZbrDcMVwX'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/5lS5fb5u4xAL0qhcuJRVpm'},
#     'href': 'https://api.spotify.com/v1/playlists/5lS5fb5u4xAL0qhcuJRVpm',
#     'id': '5lS5fb5u4xAL0qhcuJRVpm',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273460a81d1d18001e652419dcdab67616d0000b273659cf6e857f69d0a181f897aab67616d0000b273a925d6425e8c3683893d027cab67616d0000b273bb867971b24264e990e7d8e9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273460a81d1d18001e652419dcdab67616d0000b273659cf6e857f69d0a181f897aab67616d0000b273a925d6425e8c3683893d027cab67616d0000b273bb867971b24264e990e7d8e9',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273460a81d1d18001e652419dcdab67616d0000b273659cf6e857f69d0a181f897aab67616d0000b273a925d6425e8c3683893d027cab67616d0000b273bb867971b24264e990e7d8e9',
#       'width': 60}],
#     'name': 'Best of SchlagerParty 🤩',
#     'owner': {'display_name': 'Jacqueline Quinz',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/215uz3atnwbglzfahs54xw33q'},
#      'href': 'https://api.spotify.com/v1/users/215uz3atnwbglzfahs54xw33q',
#      'id': '215uz3atnwbglzfahs54xw33q',
#      'type': 'user',
#      'uri': 'spotify:user:215uz3atnwbglzfahs54xw33q'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTA5LDA0YmEwZDAxNzdjMmRiNzIxNmMyMjdhZWZhNDU2ZmRhMDA0YzEyZjY=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/5lS5fb5u4xAL0qhcuJRVpm/tracks',
#      'total': 96},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:5lS5fb5u4xAL0qhcuJRVpm'},
#    {'collaborative': False,
#     'description': '#Deutsche Welle, #Schlager, other memorable German pop songs from 70s, 80s, 90s and some exceptional hits from the 2000s etc.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2RZScmj5chhT4QrskCLkkY'},
#     'href': 'https://api.spotify.com/v1/playlists/2RZScmj5chhT4QrskCLkkY',
#     'id': '2RZScmj5chhT4QrskCLkkY',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730a043c8c45330aa972c46339ab67616d0000b273486424f6af211cb4f7e46585ab67616d0000b2734db9d010717d936878757c97ab67616d0000b273ed4b6d22cb8de1aef4dc1927',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730a043c8c45330aa972c46339ab67616d0000b273486424f6af211cb4f7e46585ab67616d0000b2734db9d010717d936878757c97ab67616d0000b273ed4b6d22cb8de1aef4dc1927',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730a043c8c45330aa972c46339ab67616d0000b273486424f6af211cb4f7e46585ab67616d0000b2734db9d010717d936878757c97ab67616d0000b273ed4b6d22cb8de1aef4dc1927',
#       'width': 60}],
#     'name': 'German Pop classics',
#     'owner': {'display_name': 'Maria Jose Perea Marquez',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/11145708019'},
#      'href': 'https://api.spotify.com/v1/users/11145708019',
#      'id': '11145708019',
#      'type': 'user',
#      'uri': 'spotify:user:11145708019'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MzksMTlmMTVhMzBiNTMzNzM0ZWVjYjdhNjEwNDc2OTcxN2Q3OGIzMTA5MQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2RZScmj5chhT4QrskCLkkY/tracks',
#      'total': 34},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2RZScmj5chhT4QrskCLkkY'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=german+schlager+classics&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 809}}

# %%
schlager_pl_tracks = get_playlist_tracks("spotify", "4XjTSrjyN9I0uZbrDcMVwX")

# %%
len(schlager_pl_tracks)
# Out:
# 156

# %%
schlager_pl_ids = []
for i in schlager_pl_tracks:
    schlager_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
schlager_pl_ids_chopped = [schlager_pl_ids[i:i+chunk_size] for i in range(0,len(schlager_pl_ids), 100)]

# %%
schlager_af_list = []
for i in schlager_pl_ids_chopped:
    schlager_af_list.extend(sp.audio_features(i))
schlager_df = pd.DataFrame(schlager_af_list)

# %% [markdown]
# ### 60s, 70s, 80s, 90s

# %%
retro_pl = sp.search(q="60s, 70s, 80s, 90s", limit = 3, type = "playlist")

# %%
retro_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=60s%2C+70s%2C+80s%2C+90s&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': '60s 70s 80s 90s and a ittle bit of 00s',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/2adiR6pqQVeujq3mc1X8tr'},
#     'href': 'https://api.spotify.com/v1/playlists/2adiR6pqQVeujq3mc1X8tr',
#     'id': '2adiR6pqQVeujq3mc1X8tr',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b2730b51f8d91f3a21e8426361aeab67616d0000b27317e1907923e91181f38290acab67616d0000b273678a26a96df9b26f57525ce7ab67616d0000b2738900b4e0a2a8fb978df9b040',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b2730b51f8d91f3a21e8426361aeab67616d0000b27317e1907923e91181f38290acab67616d0000b273678a26a96df9b26f57525ce7ab67616d0000b2738900b4e0a2a8fb978df9b040',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b2730b51f8d91f3a21e8426361aeab67616d0000b27317e1907923e91181f38290acab67616d0000b273678a26a96df9b26f57525ce7ab67616d0000b2738900b4e0a2a8fb978df9b040',
#       'width': 60}],
#     'name': 'Top 60s, 70s, 80s, 90s hits',
#     'owner': {'display_name': 'Yarden',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/br3m8qhisb46ld1qxhlgmobdk'},
#      'href': 'https://api.spotify.com/v1/users/br3m8qhisb46ld1qxhlgmobdk',
#      'id': 'br3m8qhisb46ld1qxhlgmobdk',
#      'type': 'user',
#      'uri': 'spotify:user:br3m8qhisb46ld1qxhlgmobdk'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NDExLDBjMzhlNGJkMmFjNzc5NTNjMmQxNzQzNTYyZjUyYzg3ZmFkYmZkYTI=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/2adiR6pqQVeujq3mc1X8tr/tracks',
#      'total': 367},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:2adiR6pqQVeujq3mc1X8tr'},
#    {'collaborative': False,
#     'description': '',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/6tZcYKdup8XODbajwbWsno'},
#     'href': 'https://api.spotify.com/v1/playlists/6tZcYKdup8XODbajwbWsno',
#     'id': '6tZcYKdup8XODbajwbWsno',
#     'images': [{'height': 640,
#       'url': 'https://mosaic.scdn.co/640/ab67616d0000b273214f0bd9dc1ed0c65ae81760ab67616d0000b273cb6fdb35aac14a4dcc437f5bab67616d0000b273d34d5242430b9b6297879286ab67616d0000b273f43547de689aabc4c44ab62d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://mosaic.scdn.co/300/ab67616d0000b273214f0bd9dc1ed0c65ae81760ab67616d0000b273cb6fdb35aac14a4dcc437f5bab67616d0000b273d34d5242430b9b6297879286ab67616d0000b273f43547de689aabc4c44ab62d',
#       'width': 300},
#      {'height': 60,
#       'url': 'https://mosaic.scdn.co/60/ab67616d0000b273214f0bd9dc1ed0c65ae81760ab67616d0000b273cb6fdb35aac14a4dcc437f5bab67616d0000b273d34d5242430b9b6297879286ab67616d0000b273f43547de689aabc4c44ab62d',
#       'width': 60}],
#     'name': '60s/70s/80s/90s smash hits!',
#     'owner': {'display_name': 'poop75-ca',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/poop75-ca'},
#      'href': 'https://api.spotify.com/v1/users/poop75-ca',
#      'id': 'poop75-ca',
#      'type': 'user',
#      'uri': 'spotify:user:poop75-ca'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTQ5LDIzMjlkOTZhMGVkMzNkYWViMzEwYWI1NWMwOTMxYWYwOTRlOTlmYmY=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/6tZcYKdup8XODbajwbWsno/tracks',
#      'total': 140},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:6tZcYKdup8XODbajwbWsno'},
#    {'collaborative': False,
#     'description': 'One of the many biggest playlists with some of the most popular classics from the best 3 decades. Happy listening!💿',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/1RIT1teUVDpgy4DjnHwYbj'},
#     'href': 'https://api.spotify.com/v1/playlists/1RIT1teUVDpgy4DjnHwYbj',
#     'id': '1RIT1teUVDpgy4DjnHwYbj',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebb6b6a9a193789ff358bfa3db0',
#       'width': None}],
#     'name': '70s, 80s, 90s Hits and More',
#     'owner': {'display_name': '✞ ᎷᎯᏒᎨᏕᎯ ✞',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/31h56qv5n6t6xch7sddcrtq7oazu'},
#      'href': 'https://api.spotify.com/v1/users/31h56qv5n6t6xch7sddcrtq7oazu',
#      'id': '31h56qv5n6t6xch7sddcrtq7oazu',
#      'type': 'user',
#      'uri': 'spotify:user:31h56qv5n6t6xch7sddcrtq7oazu'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'NzI4LDM5NGFiY2E1ODJhZGRhMmM1YWE1MmI3YTJmM2YxMjI2MjNmMGY1MDU=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/1RIT1teUVDpgy4DjnHwYbj/tracks',
#      'total': 424},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:1RIT1teUVDpgy4DjnHwYbj'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=60s%2C+70s%2C+80s%2C+90s&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 604}}

# %%
retro_pl_tracks = get_playlist_tracks("spotify", "2adiR6pqQVeujq3mc1X8tr")

# %%
len(retro_pl_tracks)
# Out:
# 367

# %%
retro_pl_ids = []
for i in retro_pl_tracks:
    retro_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
retro_pl_ids_chopped = [retro_pl_ids[i:i+chunk_size] for i in range(0,len(retro_pl_ids), 100)]

# %%
retro_af_list = []
for i in retro_pl_ids_chopped:
    retro_af_list.extend(sp.audio_features(i))
retro_df = pd.DataFrame(retro_af_list)

# %% [markdown]
# ### Choral

# %%
choral_pl = sp.search(q="choir", limit = 3, type = "playlist")

# %%
choral_pl
# Out:
# {'playlists': {'href': 'https://api.spotify.com/v1/search?query=choir&type=playlist&offset=0&limit=3',
#   'items': [{'collaborative': False,
#     'description': 'I’m ascending',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/5CO9oLt8EwezJmpwl54guw'},
#     'href': 'https://api.spotify.com/v1/playlists/5CO9oLt8EwezJmpwl54guw',
#     'id': '5CO9oLt8EwezJmpwl54guw',
#     'images': [{'height': None,
#       'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000bebbf523fd38a069918e19a6410d',
#       'width': None}],
#     'name': 'Choir songs that give me chills',
#     'owner': {'display_name': 'Alexa👹',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/giraffe02213'},
#      'href': 'https://api.spotify.com/v1/users/giraffe02213',
#      'id': 'giraffe02213',
#      'type': 'user',
#      'uri': 'spotify:user:giraffe02213'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTA1LDAyMDRkNWQyZGQxZDMyY2IwZmYwZWEzMmI5MzMxZDRmMmJkYjdmOGQ=',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/5CO9oLt8EwezJmpwl54guw/tracks',
#      'total': 79},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:5CO9oLt8EwezJmpwl54guw'},
#    {'collaborative': False,
#     'description': 'Choir Vocal music picked just for you',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1EIdph5qmrE8MZ'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIdph5qmrE8MZ',
#     'id': '37i9dQZF1EIdph5qmrE8MZ',
#     'images': [{'height': None,
#       'url': 'https://seed-mix-image.spotifycdn.com/v6/img/desc/Choir%20Vocal/en/large',
#       'width': None}],
#     'name': 'Choir Vocal Mix',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTk3NjcsMDAwMDAwMDAxMDJjMzIzZmNkMjU0Y2NlZTVkNWMyNjk1NmQzNjlkOQ==',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1EIdph5qmrE8MZ/tracks',
#      'total': 50},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1EIdph5qmrE8MZ'},
#    {'collaborative': False,
#     'description': 'Relax to the calming sounds of choral music.',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX9WxEZbyU6MA'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9WxEZbyU6MA',
#     'id': '37i9dQZF1DX9WxEZbyU6MA',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003ae8cdef5c98c6594561a89c1',
#       'width': None}],
#     'name': 'Choir Classics',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': None,
#     'public': None,
#     'snapshot_id': 'MTY5Nzc5MjQ3NywwMDAwMDAwMGU1YjM4NjQ4OWI1NzFlNDgyNzYxZDVhYzExZGY0YTFi',
#     'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX9WxEZbyU6MA/tracks',
#      'total': 92},
#     'type': 'playlist',
#     'uri': 'spotify:playlist:37i9dQZF1DX9WxEZbyU6MA'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=choir&type=playlist&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 4}}

# %%
choral_pl_tracks = get_playlist_tracks("spotify", "37i9dQZF1DX9WxEZbyU6MA")

# %%
len(choral_pl_tracks)
# Out:
# 92

# %%
choral_pl_ids = []
for i in choral_pl_tracks:
    choral_pl_ids.append(i['track']['id'])

# %%
chunk_size = 100
choral_pl_ids_chopped = [choral_pl_ids[i:i+chunk_size] for i in range(0,len(choral_pl_ids), 100)]

# %%
choral_af_list = []
for i in choral_pl_ids_chopped:
    choral_af_list.extend(sp.audio_features(i))
choral_df = pd.DataFrame(choral_af_list)

# %% [markdown]
# # Concatenate the dataframes

# %%
music_df = pd.concat([choral_df,retro_df,schlager_df,kids_df,christmas_df,pop_df,folk_df,dance_df,swing_df,rap_df,funk_df,electronic_df,soul_df,classical_df,rnb_df,rock_df,jazz_df], axis=0)
# music_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.0623  0.0116    2   -27.893     1       0.0567         0.991
# 1          0.2330  0.0217    1   -29.785     1       0.0413         0.988
# 2          0.1960  0.0539    5   -28.217     1       0.0438         0.993
# 3          0.0986  0.0949    1   -21.002     1       0.0441         0.993
# 4          0.1370  0.0759   11   -25.740     0       0.0401         0.975
# ..            ...     ...  ...       ...   ...          ...           ...
# 245        0.4580  0.1550   10   -17.853     1       0.0405         0.908
# 246        0.6490  0.2710    5   -15.198     0       0.0498         0.708
# 247        0.3500  0.6070    5   -11.141     0       0.0498         0.794
# 248        0.3550  0.1520    5   -14.864     0       0.0401         0.924
# 249        0.4620  0.0536    8   -17.550     1       0.0321         0.960
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.445000    0.0816   0.0331   65.057  audio_features
# 1            0.819000    0.0836   0.0710   66.349  audio_features
# 2            0.031600    0.1160   0.0482  132.747  audio_features
# 3            0.353000    0.0847   0.0363  174.628  audio_features
# 4            0.263000    0.1050   0.0363  142.767  audio_features
# ..                ...       ...      ...      ...             ...
# 245          0.621000    0.2990   0.2760  126.281  audio_features
# 246          0.000005    0.1240   0.6260  126.026  audio_features
# 247          0.446000    0.1160   0.5970  187.101  audio_features
# 248          0.077100    0.1260   0.1450   65.215  audio_features
# 249          0.000219    0.1210   0.1380   63.118  audio_features
#
#                          id                                   uri  \
# 0    0S0YKiEdR9cT9pYgEaTevF  spotify:track:0S0YKiEdR9cT9pYgEaTevF
# 1    1ZqzUiCQICQmjtpbFZYwnt  spotify:track:1ZqzUiCQICQmjtpbFZYwnt
# 2    3vA1AS2PWl4RePRCiR36lb  spotify:track:3vA1AS2PWl4RePRCiR36lb
# 3    1aJcDNDrKduMegTZzOemVd  spotify:track:1aJcDNDrKduMegTZzOemVd
# 4    4htAzv3rkpAzCjo2pW12id  spotify:track:4htAzv3rkpAzCjo2pW12id
# ..                      ...                                   ...
# 245  2bPeAxNC1S1C359ds8Tw3X  spotify:track:2bPeAxNC1S1C359ds8Tw3X
# 246  4jCoxXaEKeTWkQ7HL1d5de  spotify:track:4jCoxXaEKeTWkQ7HL1d5de
# 247  1QlTNF43OyKK9BorIRsJ8o  spotify:track:1QlTNF43OyKK9BorIRsJ8o
# 248  6x8XKDM8Rnid4TyOUg9kj3  spotify:track:6x8XKDM8Rnid4TyOUg9kj3
# 249  7981FAW8DbDs1ueK4Ha8R2  spotify:track:7981FAW8DbDs1ueK4Ha8R2
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/0S0YKiEdR9cT...
# 1    https://api.spotify.com/v1/tracks/1ZqzUiCQICQm...
# 2    https://api.spotify.com/v1/tracks/3vA1AS2PWl4R...
# 3    https://api.spotify.com/v1/tracks/1aJcDNDrKduM...
# 4    https://api.spotify.com/v1/tracks/4htAzv3rkpAz...
# ..                                                 ...
# 245  https://api.spotify.com/v1/tracks/2bPeAxNC1S1C...
# 246  https://api.spotify.com/v1/tracks/4jCoxXaEKeTW...
# 247  https://api.spotify.com/v1/tracks/1QlTNF43OyKK...
# 248  https://api.spotify.com/v1/tracks/6x8XKDM8Rnid...
# 249  https://api.spotify.com/v1/tracks/7981FAW8DbDs...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/0S0Y...       415800
# 1    https://api.spotify.com/v1/audio-analysis/1Zqz...       253293
# 2    https://api.spotify.com/v1/audio-analysis/3vA1...       236907
# 3    https://api.spotify.com/v1/audio-analysis/1aJc...       232667
# 4    https://api.spotify.com/v1/audio-analysis/4htA...       180000
# ..                                                 ...          ...
# 245  https://api.spotify.com/v1/audio-analysis/2bPe...       526893
# 246  https://api.spotify.com/v1/audio-analysis/4jCo...       441027
# 247  https://api.spotify.com/v1/audio-analysis/1QlT...       422640
# 248  https://api.spotify.com/v1/audio-analysis/6x8X...       320773
# 249  https://api.spotify.com/v1/audio-analysis/7981...       332120
#
#      time_signature
# 0                 3
# 1                 3
# 2                 3
# 3                 4
# 4                 4
# ..              ...
# 245               4
# 246               4
# 247               4
# 248               4
# 249               4
#
# [3555 rows x 18 columns]

# %%
# Check for duplicates 

import pandas as pd

# Check for duplicates
has_duplicates = music_df.duplicated().any()

if has_duplicates:
    print("DataFrame contains duplicates.")
else:
    print("DataFrame does not contain duplicates.")
# Out:
# DataFrame contains duplicates.

# %%
# Check for duplicates in the 'id' column
has_duplicates = music_df['id'].duplicated().any()

if has_duplicates:
    print("Column 'id' contains duplicates.")
else:
    print("Column 'id' does not contain duplicates.")
# Out:
# Column 'id' contains duplicates.

# %%
# Count duplicates in the 'id' column
num_duplicates = music_df['id'].duplicated().sum()

print("Number of duplicates in column 'id':", num_duplicates)
# Out:
# Number of duplicates in column 'id': 626

# %%
music_df_no_dup = music_df.drop_duplicates()

# %%
music_df_no_dup
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.0623  0.0116    2   -27.893     1       0.0567         0.991
# 1          0.2330  0.0217    1   -29.785     1       0.0413         0.988
# 2          0.1960  0.0539    5   -28.217     1       0.0438         0.993
# 3          0.0986  0.0949    1   -21.002     1       0.0441         0.993
# 4          0.1370  0.0759   11   -25.740     0       0.0401         0.975
# ..            ...     ...  ...       ...   ...          ...           ...
# 245        0.4580  0.1550   10   -17.853     1       0.0405         0.908
# 246        0.6490  0.2710    5   -15.198     0       0.0498         0.708
# 247        0.3500  0.6070    5   -11.141     0       0.0498         0.794
# 248        0.3550  0.1520    5   -14.864     0       0.0401         0.924
# 249        0.4620  0.0536    8   -17.550     1       0.0321         0.960
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.445000    0.0816   0.0331   65.057  audio_features
# 1            0.819000    0.0836   0.0710   66.349  audio_features
# 2            0.031600    0.1160   0.0482  132.747  audio_features
# 3            0.353000    0.0847   0.0363  174.628  audio_features
# 4            0.263000    0.1050   0.0363  142.767  audio_features
# ..                ...       ...      ...      ...             ...
# 245          0.621000    0.2990   0.2760  126.281  audio_features
# 246          0.000005    0.1240   0.6260  126.026  audio_features
# 247          0.446000    0.1160   0.5970  187.101  audio_features
# 248          0.077100    0.1260   0.1450   65.215  audio_features
# 249          0.000219    0.1210   0.1380   63.118  audio_features
#
#                          id                                   uri  \
# 0    0S0YKiEdR9cT9pYgEaTevF  spotify:track:0S0YKiEdR9cT9pYgEaTevF
# 1    1ZqzUiCQICQmjtpbFZYwnt  spotify:track:1ZqzUiCQICQmjtpbFZYwnt
# 2    3vA1AS2PWl4RePRCiR36lb  spotify:track:3vA1AS2PWl4RePRCiR36lb
# 3    1aJcDNDrKduMegTZzOemVd  spotify:track:1aJcDNDrKduMegTZzOemVd
# 4    4htAzv3rkpAzCjo2pW12id  spotify:track:4htAzv3rkpAzCjo2pW12id
# ..                      ...                                   ...
# 245  2bPeAxNC1S1C359ds8Tw3X  spotify:track:2bPeAxNC1S1C359ds8Tw3X
# 246  4jCoxXaEKeTWkQ7HL1d5de  spotify:track:4jCoxXaEKeTWkQ7HL1d5de
# 247  1QlTNF43OyKK9BorIRsJ8o  spotify:track:1QlTNF43OyKK9BorIRsJ8o
# 248  6x8XKDM8Rnid4TyOUg9kj3  spotify:track:6x8XKDM8Rnid4TyOUg9kj3
# 249  7981FAW8DbDs1ueK4Ha8R2  spotify:track:7981FAW8DbDs1ueK4Ha8R2
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/0S0YKiEdR9cT...
# 1    https://api.spotify.com/v1/tracks/1ZqzUiCQICQm...
# 2    https://api.spotify.com/v1/tracks/3vA1AS2PWl4R...
# 3    https://api.spotify.com/v1/tracks/1aJcDNDrKduM...
# 4    https://api.spotify.com/v1/tracks/4htAzv3rkpAz...
# ..                                                 ...
# 245  https://api.spotify.com/v1/tracks/2bPeAxNC1S1C...
# 246  https://api.spotify.com/v1/tracks/4jCoxXaEKeTW...
# 247  https://api.spotify.com/v1/tracks/1QlTNF43OyKK...
# 248  https://api.spotify.com/v1/tracks/6x8XKDM8Rnid...
# 249  https://api.spotify.com/v1/tracks/7981FAW8DbDs...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/0S0Y...       415800
# 1    https://api.spotify.com/v1/audio-analysis/1Zqz...       253293
# 2    https://api.spotify.com/v1/audio-analysis/3vA1...       236907
# 3    https://api.spotify.com/v1/audio-analysis/1aJc...       232667
# 4    https://api.spotify.com/v1/audio-analysis/4htA...       180000
# ..                                                 ...          ...
# 245  https://api.spotify.com/v1/audio-analysis/2bPe...       526893
# 246  https://api.spotify.com/v1/audio-analysis/4jCo...       441027
# 247  https://api.spotify.com/v1/audio-analysis/1QlT...       422640
# 248  https://api.spotify.com/v1/audio-analysis/6x8X...       320773
# 249  https://api.spotify.com/v1/audio-analysis/7981...       332120
#
#      time_signature
# 0                 3
# 1                 3
# 2                 3
# 3                 4
# 4                 4
# ..              ...
# 245               4
# 246               4
# 247               4
# 248               4
# 249               4
#
# [2929 rows x 18 columns]

# %%
music_df_no_dup.time_signature
# Out:
# 0      3
# 1      3
# 2      3
# 3      4
# 4      4
#       ..
# 245    4
# 246    4
# 247    4
# 248    4
# 249    4
# Name: time_signature, Length: 2929, dtype: int64

# %%
music_df_no_dup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2929 entries, 0 to 249
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      2929 non-null   float64
#  1   energy            2929 non-null   float64
#  2   key               2929 non-null   int64
#  3   loudness          2929 non-null   float64
#  4   mode              2929 non-null   int64
#  5   speechiness       2929 non-null   float64
#  6   acousticness      2929 non-null   float64
#  7   instrumentalness  2929 non-null   float64
#  8   liveness          2929 non-null   float64
#  9   valence           2929 non-null   float64
#  10  tempo             2929 non-null   float64
#  11  type              2929 non-null   object
#  12  id                2929 non-null   object
#  13  uri               2929 non-null   object
#  14  track_href        2929 non-null   object
#  15  analysis_url      2929 non-null   object
#  16  duration_ms       2929 non-null   int64
#  17  time_signature    2929 non-null   int64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 434.8+ KB

# %%
music_df_clean = music_df_no_dup.drop(columns = ["type","uri","track_href","analysis_url"])
music_df_clean
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.0623  0.0116    2   -27.893     1       0.0567         0.991
# 1          0.2330  0.0217    1   -29.785     1       0.0413         0.988
# 2          0.1960  0.0539    5   -28.217     1       0.0438         0.993
# 3          0.0986  0.0949    1   -21.002     1       0.0441         0.993
# 4          0.1370  0.0759   11   -25.740     0       0.0401         0.975
# ..            ...     ...  ...       ...   ...          ...           ...
# 245        0.4580  0.1550   10   -17.853     1       0.0405         0.908
# 246        0.6490  0.2710    5   -15.198     0       0.0498         0.708
# 247        0.3500  0.6070    5   -11.141     0       0.0498         0.794
# 248        0.3550  0.1520    5   -14.864     0       0.0401         0.924
# 249        0.4620  0.0536    8   -17.550     1       0.0321         0.960
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.445000    0.0816   0.0331   65.057  0S0YKiEdR9cT9pYgEaTevF
# 1            0.819000    0.0836   0.0710   66.349  1ZqzUiCQICQmjtpbFZYwnt
# 2            0.031600    0.1160   0.0482  132.747  3vA1AS2PWl4RePRCiR36lb
# 3            0.353000    0.0847   0.0363  174.628  1aJcDNDrKduMegTZzOemVd
# 4            0.263000    0.1050   0.0363  142.767  4htAzv3rkpAzCjo2pW12id
# ..                ...       ...      ...      ...                     ...
# 245          0.621000    0.2990   0.2760  126.281  2bPeAxNC1S1C359ds8Tw3X
# 246          0.000005    0.1240   0.6260  126.026  4jCoxXaEKeTWkQ7HL1d5de
# 247          0.446000    0.1160   0.5970  187.101  1QlTNF43OyKK9BorIRsJ8o
# 248          0.077100    0.1260   0.1450   65.215  6x8XKDM8Rnid4TyOUg9kj3
# 249          0.000219    0.1210   0.1380   63.118  7981FAW8DbDs1ueK4Ha8R2
#
#      duration_ms  time_signature
# 0         415800               3
# 1         253293               3
# 2         236907               3
# 3         232667               4
# 4         180000               4
# ..           ...             ...
# 245       526893               4
# 246       441027               4
# 247       422640               4
# 248       320773               4
# 249       332120               4
#
# [2929 rows x 14 columns]

# %%
music_df_reset_drop = music_df_clean.reset_index(drop=True)
music_df_reset_drop
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.0623  0.0116    2   -27.893     1       0.0567         0.991
# 1           0.2330  0.0217    1   -29.785     1       0.0413         0.988
# 2           0.1960  0.0539    5   -28.217     1       0.0438         0.993
# 3           0.0986  0.0949    1   -21.002     1       0.0441         0.993
# 4           0.1370  0.0759   11   -25.740     0       0.0401         0.975
# ...            ...     ...  ...       ...   ...          ...           ...
# 2924        0.4580  0.1550   10   -17.853     1       0.0405         0.908
# 2925        0.6490  0.2710    5   -15.198     0       0.0498         0.708
# 2926        0.3500  0.6070    5   -11.141     0       0.0498         0.794
# 2927        0.3550  0.1520    5   -14.864     0       0.0401         0.924
# 2928        0.4620  0.0536    8   -17.550     1       0.0321         0.960
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.445000    0.0816   0.0331   65.057  0S0YKiEdR9cT9pYgEaTevF
# 1             0.819000    0.0836   0.0710   66.349  1ZqzUiCQICQmjtpbFZYwnt
# 2             0.031600    0.1160   0.0482  132.747  3vA1AS2PWl4RePRCiR36lb
# 3             0.353000    0.0847   0.0363  174.628  1aJcDNDrKduMegTZzOemVd
# 4             0.263000    0.1050   0.0363  142.767  4htAzv3rkpAzCjo2pW12id
# ...                ...       ...      ...      ...                     ...
# 2924          0.621000    0.2990   0.2760  126.281  2bPeAxNC1S1C359ds8Tw3X
# 2925          0.000005    0.1240   0.6260  126.026  4jCoxXaEKeTWkQ7HL1d5de
# 2926          0.446000    0.1160   0.5970  187.101  1QlTNF43OyKK9BorIRsJ8o
# 2927          0.077100    0.1260   0.1450   65.215  6x8XKDM8Rnid4TyOUg9kj3
# 2928          0.000219    0.1210   0.1380   63.118  7981FAW8DbDs1ueK4Ha8R2
#
#       duration_ms  time_signature
# 0          415800               3
# 1          253293               3
# 2          236907               3
# 3          232667               4
# 4          180000               4
# ...           ...             ...
# 2924       526893               4
# 2925       441027               4
# 2926       422640               4
# 2927       320773               4
# 2928       332120               4
#
# [2929 rows x 14 columns]

# %%
null_counts = music_df_reset_drop.isnull().sum()

print("Null values in each column:")
print(null_counts)
# Out:
# Null values in each column:
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# id                  0
# duration_ms         0
# time_signature      0
# dtype: int64

# %%
my_music_df = music_df_reset_drop
my_music_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.0623  0.0116    2   -27.893     1       0.0567         0.991
# 1           0.2330  0.0217    1   -29.785     1       0.0413         0.988
# 2           0.1960  0.0539    5   -28.217     1       0.0438         0.993
# 3           0.0986  0.0949    1   -21.002     1       0.0441         0.993
# 4           0.1370  0.0759   11   -25.740     0       0.0401         0.975
# ...            ...     ...  ...       ...   ...          ...           ...
# 2924        0.4580  0.1550   10   -17.853     1       0.0405         0.908
# 2925        0.6490  0.2710    5   -15.198     0       0.0498         0.708
# 2926        0.3500  0.6070    5   -11.141     0       0.0498         0.794
# 2927        0.3550  0.1520    5   -14.864     0       0.0401         0.924
# 2928        0.4620  0.0536    8   -17.550     1       0.0321         0.960
#
#       instrumentalness  liveness  valence    tempo                      id  \
# 0             0.445000    0.0816   0.0331   65.057  0S0YKiEdR9cT9pYgEaTevF
# 1             0.819000    0.0836   0.0710   66.349  1ZqzUiCQICQmjtpbFZYwnt
# 2             0.031600    0.1160   0.0482  132.747  3vA1AS2PWl4RePRCiR36lb
# 3             0.353000    0.0847   0.0363  174.628  1aJcDNDrKduMegTZzOemVd
# 4             0.263000    0.1050   0.0363  142.767  4htAzv3rkpAzCjo2pW12id
# ...                ...       ...      ...      ...                     ...
# 2924          0.621000    0.2990   0.2760  126.281  2bPeAxNC1S1C359ds8Tw3X
# 2925          0.000005    0.1240   0.6260  126.026  4jCoxXaEKeTWkQ7HL1d5de
# 2926          0.446000    0.1160   0.5970  187.101  1QlTNF43OyKK9BorIRsJ8o
# 2927          0.077100    0.1260   0.1450   65.215  6x8XKDM8Rnid4TyOUg9kj3
# 2928          0.000219    0.1210   0.1380   63.118  7981FAW8DbDs1ueK4Ha8R2
#
#       duration_ms  time_signature
# 0          415800               3
# 1          253293               3
# 2          236907               3
# 3          232667               4
# 4          180000               4
# ...           ...             ...
# 2924       526893               4
# 2925       441027               4
# 2926       422640               4
# 2927       320773               4
# 2928       332120               4
#
# [2929 rows x 14 columns]

# %%
my_music_df.to_csv('my_music.csv', index=False)

print("DataFrame exported to CSV successfully.")
# Out:
# DataFrame exported to CSV successfully.
